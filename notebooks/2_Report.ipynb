# %%
import socket
s = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
s.connect(("8.8.8.8", 80))
print(s.getsockname()[0])
s.close()
# Out:
# 172.28.0.12

# %%
# !uv pip install google-colab-selenium
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 91 packages in 706ms
# Prepared 7 packages in 446ms
# Installed 7 packages in 55ms
#  + google-colab-selenium==1.0.16
#  + jedi==0.19.2
#  + outcome==1.3.0.post0
#  + selenium==4.38.0
#  + trio==0.32.0
#  + trio-websocket==0.12.2
#  + wsproto==1.3.1

# %%
#type: ignore
import google_colab_selenium as gs

# Create a driver instance (headless mode is default)
driver = gs.Chrome()

# Navigate to a website
driver.get('https://www.google.com')

# Print the page title (example usage)
print(driver.title)

# Quit the drive
driver.quit()
# Out:
#             <div class="spinner-container">
#                 <div class="spinner" id="83e61de8-06ae-4a4e-a0ea-28fe2867a8a3-circle"></div>
#                 <div class="spinner-text" id="83e61de8-06ae-4a4e-a0ea-28fe2867a8a3-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="c5e7bbbd-6ac0-4a0f-9554-de5a5ea096cc-circle"></div>
#                 <div class="spinner-text" id="c5e7bbbd-6ac0-4a0f-9554-de5a5ea096cc-text">Downloading Google Chrome</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
#             <div class="spinner-container">
#                 <div class="spinner" id="e6dbc5dd-1453-423d-859b-6cf8fc82999e-circle"></div>
#                 <div class="spinner-text" id="e6dbc5dd-1453-423d-859b-6cf8fc82999e-text">Initializing Chromedriver</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
#                 }
#
#                 .spinner-container {
#                     display: flex;
#                     align-items: center;
#                     margin-bottom: 3px;
#                 }
#
#                 .spinner {
#                     border: 3px solid rgba(0, 0, 0, 0.1);
#                     border-left-color: lightblue;
#                     border-radius: 50%;
#                     width: 12px;
#                     height: 12px;
#                     animation: spin 1s linear infinite;
#                 }
#
#                 .spinner-text {
#                     padding-left: 6px;
#                 }
#             </style>
# Google
