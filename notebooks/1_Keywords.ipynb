# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path

import pandas as pd
import polars as pl
from tqdm.notebook import tqdm

import job_search.config as conf
import job_search.dataset as dataset
import job_search.jobs as jobs
import job_search.ai as ai
import job_search.resume as res
import job_search.utils as utils
from job_search.utils import path_names
from job_search.config import P_DICT
import aw
utils.jupyter_css_style()
# Out:
#         <!-- https://stackoverflow.com/questions/71534901/make-tqdm-bar-dark-in-vscode-jupyter-notebook -->
#         <style>
#         .cell-output-ipywidget-background {
#             background-color: transparent !important;
#         }
#         :root {
#             --jp-widgets-color: var(--vscode-editor-foreground);
#             --jp-widgets-font-size: var(--vscode-editor-font-size);
#         }
#         </style>

# %% [markdown]
# ## Keywords

# %%
# jobs_df = jobs.load_jobs(overwrite=True)
jobs2026 = jobs.load_jobs2026()
jobs2026[jobs2026['company_name'].isna()]
# Out:
#      company_name                                              title  \
# 416          None                                 Lead Data Engineer
# 418          None         Machine Learning Engineer, Computer Vision
# 419          None                     Director Data Science (780826)
# 420          None                        Data Scientist / Researcher
# 421          None  Senior DevOps Engineer - Security, Observabili...
# ...           ...                                                ...
# 1459         None          Senior Data Scientist, Rider New Products
# 1460         None  Machine Learning Research Scientist ($120k-180...
# 1461         None                               Founding AI Engineer
# 1463         None                     Lead Machine Learning Engineer
# 1464         None                     AI and ML HPC Cluster Engineer
#
#                estimated_publish_date  \
# 416         2026-02-16 17:00:00+00:00
# 418  2026-02-16 10:00:58.373000+00:00
# ...

# %%
# P_dict = utils.paths(conf.P_DICT).iloc[0]
# pkl_dict = jobs.load_pkl('42b5jzu6om9x90pd')
# pkl_dict = jobs.load_pkl('0bbzw1b0ey0mf4u0')
pkl_dict = jobs.load_pkl('okuw2t4sktjcjwgy')
pkl_dict
# Out:
# {'props': {'pageProps': {'job': {'id': 'oraclecloud___egsd.fa.us2___21017',
#     'board_token': 'egsd.fa.us2',
#     'source': 'oraclecloud',
#     'apply_url': 'https://egsd.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX/requisitions/job/21017',
#     'source_and_board_token': 'oraclecloud_egsd.fa.us2',
#     'job_information': {'title': 'Lead Data Engineer',
#      'job_title_raw': 'Lead Data Engineer',
# ...

# %% [markdown]
# ## anywidget

# %%
# <script src="https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4"></script>

# %%
import anywidget
import traitlets

class CounterWidget(anywidget.AnyWidget):
    # Widget front-end JavaScript code
    _esm = """
    function render({ model, el }) {
      let button = document.createElement("button");
      button.innerHTML = `count is ${model.get("value")}`;
      button.addEventListener("click", () => {
        model.set("value", model.get("value") + 1);
        model.save_changes();
      });
      model.on("change:value", () => {
        button.innerHTML = `count is ${model.get("value")}`;
      });
      el.appendChild(button);
    }
    export default { render };
    """
    # Stateful property that can be accessed by JavaScript & Python
    value = traitlets.Int(0).tag(sync=True)

# %%
CounterWidget()
# Out:
# CounterWidget()
