# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path

import pandas as pd
import polars as pl
from tqdm.notebook import tqdm

import job_search.config as conf
import job_search.dataset as dataset
import job_search.jobs as jobs
import job_search.ai as ai
import job_search.resume as res
import job_search.utils as utils
from job_search.utils import path_names
from job_search.config import P_DICT
import aw
utils.jupyter_css_style()
# Out:
#         <!-- https://stackoverflow.com/questions/71534901/make-tqdm-bar-dark-in-vscode-jupyter-notebook -->
#         <style>
#         .cell-output-ipywidget-background {
#             background-color: transparent !important;
#         }
#         :root {
#             --jp-widgets-color: var(--vscode-editor-foreground);
#             --jp-widgets-font-size: var(--vscode-editor-font-size);
#         }
#         </style>

# %% [markdown]
# ## Keywords

# %%
jobs_df = jobs.load_jobs()
# jobs_df
# Out:
# Saving: /home/alex/Dev/job-search/data/cache/jobs.parquet

# %%
# jobs_df = jobs.load_jobs(overwrite=True)
jobs2026 = jobs.load_jobs2026()
jobs2026
# Out:
#                   company_name  \
# 0                         TSMC
# 1                 Eitacies Inc
# 2          Foundation Robotics
# 3                    Intuitive
# 4                          KLA
# ...                        ...
# 1473  Jack & Jill/External ATS
# 1474                 MLabs Ltd
# 1475                     Crowe
# 1476                    Nvidia
# 1477                Capitalone
#
#                                                   title  \
# 0               Data Engineer (7426) (San Jose, CA, US)
# 1                    DevOps Engineer : Pulumi & AWS ECS
# 2                              AI Engineer  (VLM & VLA)
# 3       Future Opportunity -- Machine Learning Engineer
# 4                                    Senior AI Engineer
# ...                                                 ...
# 1473  Machine Learning Research Scientist ($120k-180...
# 1474                               Founding AI Engineer
# 1475                               AI Security Engineer
# ...

# %%
all_keywords = jobs_df['_md'].str.extractall(r'\b[a-z]+ ((?:[A-Z][-A-Za-z0-9]* ?)+)').reset_index().drop_duplicates(subset=['level_0', 0])[0].str.strip()
all_keywords.pipe(aw.vcounts, cutoff=200, vmax=all_keywords.nunique())
# Out:
# <style type="text/css">
# #T_2212b_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 22.9%, transparent 22.9%);
# }
# #T_2212b_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 13.4%, transparent 13.4%);
# }
# #T_2212b_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 11.1%, transparent 11.1%);
# }
# #T_2212b_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 7.8%, transparent 7.8%);
# }
# #T_2212b_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 6.1%, transparent 6.1%);
# }
# #T_2212b_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 4.4%, transparent 4.4%);
# }
# #T_2212b_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 4.3%, transparent 4.3%);
# }
# #T_2212b_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 4.2%, transparent 4.2%);
# }
# #T_2212b_row8_col2 {
#   width: 10em;
# ...

# %%
'S3' in set(all_keywords)
# Out:
# True

# %% [markdown]
# ## anywidget

# %%
# <script src="https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4"></script>

# %%
import anywidget
import traitlets

class CounterWidget(anywidget.AnyWidget):
    # Widget front-end JavaScript code
    _esm = """
    function render({ model, el }) {
      let button = document.createElement("button");
      button.innerHTML = `count is ${model.get("value")}`;
      button.addEventListener("click", () => {
        model.set("value", model.get("value") + 1);
        model.save_changes();
      });
      model.on("change:value", () => {
        button.innerHTML = `count is ${model.get("value")}`;
      });
      el.appendChild(button);
    }
    export default { render };
    """
    # Stateful property that can be accessed by JavaScript & Python
    value = traitlets.Int(0).tag(sync=True)

# %%
CounterWidget()
# Out:
# CounterWidget()
