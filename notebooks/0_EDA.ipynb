# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path

import pandas as pd
import polars as pl
from tqdm.notebook import tqdm

import job_search.dataset as dataset
import job_search.company as com
import job_search.resume as res
import job_search.utils as utils
from job_search.config import P_ROOT, P_JOBS, P_URLS, P_PROCESSED
from job_search.utils import path_names

import aw
utils.jupyter_css_style()
# Out:
#         <!-- https://stackoverflow.com/questions/71534901/make-tqdm-bar-dark-in-vscode-jupyter-notebook -->
#         <style>
#         .cell-output-ipywidget-background {
#             background-color: transparent !important;
#         }
#         :root {
#             --jp-widgets-color: var(--vscode-editor-foreground);
#             --jp-widgets-font-size: var(--vscode-editor-font-size);
#         }
#         </style>

# %%
# P_job_list = []

# jobs_paths = pd.Series([p for p in P_JOBS.glob('*.md')])
# for P_job in (pbar := tqdm(jobs_paths)):
#     # pbar.set_description(P_job.name)
#     if os.stat(P_job).st_size == 0:
#         P_job_list.append(P_job)
#         P_url = P_URLS / f"{P_job.stem}.html"
#         print(f'"{P_url}"')
#         if P_url.exists():
#             P_url.unlink()
#         P_job.unlink()

# %%
QUERY_LIST = [
    DS_NORCAL := 'DS_NorCal',
    HEALTH := 'Healthcare',
    SF := 'SF',
    DS_REMOTE := 'DS_Remote',
    # DS_SOCAL := 'DS_SoCal',
    # DS_SEATTLE := 'DS_Seattle',
    # DS_NY := 'DS_NY',
    # DS_MIDWEST := 'DS_Midwest',
    # DS_DC := 'DS_DC',
    # SW := 'SW',
    # SW_REMOTE := 'SW_Remote',
]
STEM = 'Healthcare'
_date = com.now(time=False)
# _date = "2025-10-12"
# _date = "2025-11-06"
P_save_dict = {stem: P_PROCESSED / (f'{_date}/{stem}/{stem}.html') for stem in QUERY_LIST}
P_companies_dict = {stem: P_save_dict[stem].parents[3] / f"cache/{stem}_company_urls" for stem in QUERY_LIST}
P_query_dict = {stem: P_save_dict[stem].parents[3] / f"queries/{stem}.txt" for stem in QUERY_LIST}
P_save = P_save_dict[STEM]
P_companies = P_companies_dict[STEM]
P_query = P_query_dict[STEM]

# %%
# jdf = com.load_jdf(P_save)
# cdf = com.load_cdf(P_companies)
# jdf_dict = {stem: com.load_jdf(P_save_dict[stem]) for stem in QUERY_LIST}
# cdf_dict = {stem: com.load_cdf(P_companies_dict[stem]) for stem in QUERY_LIST}
df_dict = {stem: com.load_df(P_save_dict[stem]).to_pandas() for stem in QUERY_LIST}
dfc_dict = {stem: com.load_dfc(P_save_dict[stem]).to_pandas() for stem in QUERY_LIST}

# %%
df = pd.concat(df_dict).drop_duplicates(subset='hash').pipe(pl.DataFrame)
dfc = df.group_by('company').agg([
    pl.len(),
    pl.col('title').implode(),
    pl.col('company_summary').first(),
    pl.col('hours').min().alias('days') // 24,
    pl.col('bay').pipe(com.pl_reduce_list),
    pl.col('location').pipe(com.pl_reduce_list),
    pl.col('skills').pipe(com.pl_reduce_list),
    # pl.col('onsite').pipe(com.pl_enum_min, df['onsite'].dtype),
    # pl.col('full_time').pipe(com.pl_enum_max, df['full_time'].dtype),
    pl.col('lower').min(),
    pl.col('median').mean().round(2),
    pl.col('upper').max(),
    # pl.col('url2').n_unique(),
]).to_pandas()
df = df.to_pandas()
df_hash_set = set(df['hash'])

# %%
print(f"{'ALL':12}: {len(df):,} jobs among {len(dfc):,} companies")
for stem in QUERY_LIST:
    print(f"{stem:12}: {len(df_dict[stem]):,} jobs among {len(dfc_dict[stem]):,} companies")
# ALL         : 3,648 jobs among 1,769 companies
# DS_NorCal   : 767 jobs among 404 companies
# Healthcare  : 930 jobs among 627 companies
# SF          : 1,193 jobs among 634 companies
# DS_Remote   : 1,582 jobs among 859 companies
# Out:
# ALL         : 3,712 jobs among 1,784 companies
# DS_NorCal   : 969 jobs among 586 companies
# Healthcare  : 502 jobs among 283 companies
# SF          : 977 jobs among 556 companies
# DS_Remote   : 2,208 jobs among 1,223 companies

# %%
P_urls_df_parquet = com.P_DATA / 'cache' / f'P_urls_df_{_date}.parquet'
if not P_urls_df_parquet.exists():
    com.path_df(P_URLS).to_parquet(P_urls_df_parquet)
urls_df = pd.read_parquet(P_urls_df_parquet).query('stsize > 0').sort_values('ctime', ascending=False).drop_duplicates('hash').reset_index(drop=True)
urls_df['company'] = urls_df['name'].str.split(' - ', n=1).str[0]
for stem in QUERY_LIST:
    urls_df[stem] = urls_df['hash'].isin(set(df_dict[stem]['hash']))
urls_df = urls_df.sort_values(QUERY_LIST, ascending=False, kind='stable').reset_index(drop=True)
urls_df['DS'] = urls_df['DS_NorCal'] | urls_df['DS_Remote']
urls_df['ALL'] = urls_df['hash'].isin(set(df['hash']))
companies_df = urls_df.drop_duplicates('company').reset_index(drop=True)

# %%
# aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in QUERY_LIST], QUERY_LIST)
# aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in QUERY_LIST[:3]], QUERY_LIST[:3])
# aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in QUERY_LIST[:2]], QUERY_LIST[:2])
aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in ['DS', HEALTH]], ['DS', HEALTH])
#  	DS	Healthcare	Size	%
# 1	-	-	2735	100.0
# 2	Yes	-	1852	67.7
# 3	-	Yes	929	34.0
# 4	Yes	Yes	46	1.7
# Out:
# <style type="text/css">
# #T_c7880_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 100.0%, transparent 100.0%);
# }
# #T_c7880_row1_col0, #T_c7880_row2_col1, #T_c7880_row3_col0, #T_c7880_row3_col1 {
#   background-color: green;
# }
# #T_c7880_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 84.7%, transparent 84.7%);
# }
# #T_c7880_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 17.1%, transparent 17.1%);
# }
# #T_c7880_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.8%, transparent 1.8%);
# }
# </style>
# <table id="T_c7880">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7880_level0_col0" class="col_heading level0 col0" >DS</th>
#       <th id="T_c7880_level0_col1" class="col_heading level0 col1" >Healthcare</th>
#       <th id="T_c7880_level0_col2" class="col_heading level0 col2" >Size</th>
#       <th id="T_c7880_level0_col3" class="col_heading level0 col3" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7880_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c7880_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_c7880_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_c7880_row0_col2" class="data row0 col2" >2932</td>
#       <td id="T_c7880_row0_col3" class="data row0 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_c7880_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c7880_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_c7880_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_c7880_row1_col2" class="data row1 col2" >2484</td>
#       <td id="T_c7880_row1_col3" class="data row1 col3" >84.7</td>
#     </tr>
#     <tr>
#       <th id="T_c7880_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c7880_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_c7880_row2_col1" class="data row2 col1" >Yes</td>
#       <td id="T_c7880_row2_col2" class="data row2 col2" >502</td>
#       <td id="T_c7880_row2_col3" class="data row2 col3" >17.1</td>
#     </tr>
#     <tr>
#       <th id="T_c7880_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c7880_row3_col0" class="data row3 col0" >Yes</td>
#       <td id="T_c7880_row3_col1" class="data row3 col1" >Yes</td>
#       <td id="T_c7880_row3_col2" class="data row3 col2" >54</td>
#       <td id="T_c7880_row3_col3" class="data row3 col3" >1.8</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

P_DICT = P_JOBS.parent / 'dicts'
P_DICT.mkdir(exist_ok=True)

industries_list = []
# _companies_hash_names = list(companies_df.query('ALL')[['hash', 'name']].iterrows())
_hash_names = list(urls_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_hash_names):
    P_dict = P_DICT / f'{name}.pkl'
    if P_dict.exists():
        continue
    next_data_dict = com.viewhash(hash)
    with open(P_dict, 'wb') as f:
        pickle.dump(next_data_dict, f)
# Out:
#   0%|          | 0/3647 [00:00<?, ?it/s]

# %%
all_dsize_list = []
_hash_names = list(urls_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_hash_names):
    P_dict = P_DICT / f'{name}.pkl'
    all_dsize_list.append(os.path.getsize(P_dict))
# Out:
#   0%|          | 0/3647 [00:00<?, ?it/s]

# %%
all_urls_df = urls_df.query('ALL').copy()
all_urls_df['dsize'] = all_dsize_list

# %%
industries_list = []
_hash_names = list(companies_df.query('ALL')[['hash', 'name']].iterrows())
# _hash_names = list(urls_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_hash_names):
    next_data_dict = com.hash2dict(hash)
    try:
        industries = next_data_dict['props']['pageProps']['job']['v5_processed_company_data']['industries']
    except KeyError:
        industries = None
    industries_list.append(industries)
# Out:
#   0%|          | 0/1776 [00:00<?, ?it/s]
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Avispa - 11h.elqqytqcx05h4r9z.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Outschool - 12h.79x6x52ey5cndj96.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Blue Yonder - 2mo.0syhcg0w6sqlyusr.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Acubed - AI Engineer – LLM,RAG.7wq9509zoojuo633.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Weave - AI Research Scientist.vwugdze68nj3j5hp.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Owner.com - Staff Product Data Scientist, Risk and Payments.bxq6d49uwhpyighn.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Trunk Tools - NLP Engineer.wepeuneok4ur4p3w.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Toma - Prompt Engineer & Support Specialist (AI_LLM SaaS).moxtzpqc7lwhhw45.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/TIFIN - Staff ML Engineer, Applied AI.xwqe0vjq9j19czf9.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Stitch Fix Annex - Data Scientist - Recommendation Algorithms.nyfmm6qvgofdob78.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Sourcegraph - ML Engineer [IC3].kmfn6viuaqjxlbds.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Scout Motors - Lead DevOps Engineer.thw05sg1z3pmhkte.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Samsung Research America - Senior Staff AI Research Engineer, On-Device Personal Intelligence.4n8uwawp8mzfttuu.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Samaya AI - Applied Scientist (ML), MTV.4v2eiet7x6uuo113.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Revi - Senior Backend Engineer (AI-First).ri3v06ndo5f12jcy.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Redwood Credit Union - Cloud Data Engineer.ipgwcj4r5ynelr8l.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Ready - DevOps Engineer.8uyauw9jfel5yt8g.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Phizenix - ML Infrastructure Engineer.uhj03d1hd70deag7.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Peregrine Technologies - Manager, BI + Analytics Engineer.q68124rpa093yp2e.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Pacific Fusion - DevOps Engineer.kszz105g78kwldfp.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/PTC - Principal, DevOps Engineer.ow5jorx9zewq6o5q.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/
html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/HF Sinclair Corporation _ Home - Senior Data Scientist (Remote US, US).n83upkrcirjj9jsn.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Dusty Robotics - Senior AI Agent Engineer.hq8b47r61me73bmk.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Daydream - Data Analytics & Insights Engineer.3jfhdp2475nayl7q.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Contexture - Junior Data Engineer.6odcbwp8yomo38tn.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Cengage Learning - Sr Data Scientist.ve0p0wfkpkr54yt4.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Care Continuity - Data Engineer.55ku9x3w22pe1z0v.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Shutterstock - Data Engineer, Analytics.pj9os18k123i9q7e.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Finn Partners - AI Solutions Engineer - Remote.qdc1c5cy55n2rq4r.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Securitas - Senior AI Infrastructure Engineer.2bdpozje564becm6.html.pkl
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/dicts/Manifest Cyber Public - Senior Backend Application Engineer - AI.uu7txbkbs06r25hq.html.pkl

# %%
import pickle
P1_dict = com.P_DICT / f"{companies_df.query('ALL').iloc[0]['name']}.pkl"
with open(P1_dict, 'rb') as f:
    next_data_dict = pickle.load(f)
# next_data_dict

# %%
companies_df['industries'] = pd.Series(industries_list)

# %%
companies_df['industries'].dropna().explode().drop_duplicates().reset_index(drop=True).to_csv('industries.txt', header=False, index=False)
companies_df.query('Healthcare')['industries'].dropna().explode().drop_duplicates().reset_index(drop=True).to_csv('healthcare_industries.txt', header=False, index=False)

# %%
for hash in urls_df.query('company == "Genentech" and DS')['hash']:
    print(com.viewhash(hash)['props']['pageProps']['job']['v5_processed_company_data']['industries'])
# Out:
# ['Biotechnology Companies', 'Medical Organizations', 'Pharmaceutical Companies', 'Health Care Companies']
# ['Biotechnology Companies', 'Medical Organizations', 'Pharmaceutical Companies', 'Health Care Companies']
# ['Biotechnology Companies', 'Medical Organizations', 'Pharmaceutical Companies', 'Health Care Companies']

# %% [markdown]
# ## END

# %%
import json
import sys
import pickle

import job_search.config as conf
from job_search.config import P_CACHE, P_DICT, P_QUERIES, _date

# %%
P_query = P_QUERIES / 'DS.txt'
P_save = dataset.main0(P_query)
jdf = dataset.load_jdf(P_save)
# Out:
# 2025-11-19 15:17:12,697 - INFO - /mnt/c/Users/alexa/Dev/Companies/data/processed/2025-11-19/DS/DS.html already exists...

# %%
# P_job_data_list = P_CACHE / f'job_data_list_{_date}.pkl'
# with open(P_job_data_list, 'rb') as f:
#     job_data_list = pickle.load(f)

# %%
## Takes ...
# P_DICT size is 848 MB (as of 11/13/25 (Thursday))
# P_dict_list = [p for p in conf.P_DICT.glob("*.pkl")]
# Out: 18756
P_dict_list = [p for p in P_DICT.glob("*.pkl") if os.stat(p).st_size > 5]
len(P_dict_list)
# Out: 18520

# job_data_list = []
# for path in tqdm(P_dict_list):
#     with open(path, 'rb') as f:
#         job_data = pickle.load(f)
#     job_data_list.append(job_data)

# P_job_data_list = P_CACHE / f'job_data_list_{_date}.pkl'
# with open(P_job_data_list, 'wb') as f:
#     pickle.dump(job_data_list, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# 20776

# %%
job_data_list = []
for path in tqdm(P_dict_list):
    with open(path, 'rb') as f:
        job_data = pickle.load(f)
    job_data_list.append(job_data)

P_job_data_list = P_CACHE / f'job_data_list_{_date}.pkl'
with open(P_job_data_list, 'wb') as f:
    pickle.dump(job_data_list, f, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|          | 0/20776 [00:00<?, ?it/s]

# %%
_ctime = [os.path.getctime(p) for p in P_dict_list]
_ctime = pd.Series(_ctime).pipe(pd.to_datetime, unit='s').dt.floor('s')

# %%
job_series = pd.Series([d['props']['pageProps'].get('job', None) for d in job_data_list])
V5_JOB = 'v5_processed_job_data'
V5_COMP = 'v5_processed_company_data'
JOB_INFO = 'job_information'
job_v5 = job_series.str[V5_JOB]
job_comp = job_series.str[V5_COMP]
job_info = job_series.str[JOB_INFO]
_est_pub_date = job_v5.str['estimated_publish_date'].str[:10].pipe(pd.to_datetime)
_location = job_v5.str['formatted_workplace_location'].str.replace(', California', '').str.replace(', United States', '')
_id = [p.name.removesuffix('.html.pkl') for p in P_dict_list]

job_df = pd.DataFrame({
    '_id': _id,
    '_ctime': _ctime,
    '_est_pub_date': _est_pub_date,
    'title': job_info.str['title'],
    '_loc': _location,
    'yearly_min_compensation': job_v5.str['yearly_min_compensation'],
    'yearly_max_compensation': job_v5.str['yearly_max_compensation'],
    'workplace_type': job_v5.str['workplace_type'],
    'commitment': job_v5.str['commitment'],
    'company_name': job_v5.str['company_name'],
    'company_tagline': job_v5.str['company_tagline'],
    '_yoe': job_v5.str['min_industry_and_role_yoe'],
    '_mgmt': job_v5.str['min_management_and_leadership_yoe'],
    'requirements_summary': job_v5.str['requirements_summary'],
    'technical_tools': job_v5.str['technical_tools'],
    '_hash': job_series.str['requisition_id'],
    'collapse_key': job_series.str['collapse_key'],
    '_geoloc': job_series.str['_geoloc']
})

# %%
comp_df = pd.DataFrame({
    '_id': _id,
    'company_name': job_v5.str['company_name'],
    # 'company_tagline': job_v5.str['company_tagline'],
    'image_url': job_comp.str['image_url'],
    'website': job_comp.str['website'],
    'tagline': job_comp.str['tagline'],
    'is_non_profit': job_comp.str['is_non_profit'],
    'stock_symbol': job_comp.str['stock_symbol'],
    'collapse_key': job_series.str['collapse_key'],
    'year_founded': job_comp.str['year_founded'],
    'num_employees': job_comp.str['num_employees'],
    'industries': job_comp.str['industries'].apply(lambda x: tuple(x) if x else tuple()),
    'activities': job_comp.str['activities'].apply(lambda x: tuple(x) if x else tuple()),
    'latest_investment_amount': job_comp.str['latest_investment_amount'],
    'latest_investment_year': job_comp.str['latest_investment_year'],
    'latest_investment_series': job_comp.str['latest_investment_series'],
    'investors': job_comp.str['investors'].apply(lambda x: tuple(x) if x else tuple()),
    'parent_company': job_comp.str['parent_company'],
    'headquarters_country': job_comp.str['headquarters_country'],
    'linkedin_url': job_comp.str['linkedin_url'],
})
comp_df.nunique()
# Out:
# _id                         20776
# company_name                 5591
# image_url                    4363
# website                      4962
# tagline                      6863
# is_non_profit                   2
# stock_symbol                  795
# collapse_key                 5280
# year_founded                  196
# num_employees                1534
# industries                   1359
# activities                   6169
# latest_investment_amount      695
# latest_investment_year         36
# latest_investment_series       25
# investors                    2466
# parent_company                779
# headquarters_country           62
# linkedin_url                 4372
# dtype: int64

# %%
from markdownify import markdownify as md
src_df = pd.DataFrame({
    '_id': _id,
    '_ctime': _ctime,
    '_est_pub_date': _est_pub_date,
    'title': job_info.str['title'],
    'job_title_raw': job_info.str['job_title_raw'],
    'description': job_info.str['description'],
    'stripped_description': job_info.str['stripped_description'],
    'viewedByUsers': job_info.str['viewedByUsers'],
    'appliedFromUsers': job_info.str['appliedFromUsers'],
    '_hash': job_series.str['requisition_id'],
})
# src_df['_md'] = src_df['description'].fillna('').map(md)

# %%
N = job_df.shape[0]  # 20776
# N = 18_520
_perc = lambda x: print(f"{x.sum():,} of {N:,} ({100*x.mean():.1f}%)")
# _perc_N = lambda x: print(f"{x:,} of {N:,} ({100*x/N:.1f}%)")
# _perc_N(df['company_name'].isna().sum())
_perc(job_df['_hash'].isna())
# Out:
# 465 of 20,776 (2.2%)

# %%
# df['collapse_key'].nunique()
# any(df['collapse_key'] == "Z3JuaHNlX19fMTB4Z2Vub21pY3NfX18xMHggR2Vub21pY3NfX18xMHhnZW5vbWljcy5jb")
job_df[(job_df['company_name'] == "Genentech")].T
# Out:
#                                                                       6991
# _id                      Genentech - Principal Supply Chain Data Scient...
# _ctime                                                 2025-11-11 23:50:39
# _est_pub_date                                          2025-08-06 00:00:00
# title                                Principal Supply Chain Data Scientist
# _loc                                                  Louisville, Kentucky
# yearly_min_compensation                                           127100.0
# yearly_max_compensation                                           236100.0
# workplace_type                                                      Onsite
# commitment                                                     [Full Time]
# company_name                                                     Genentech
# company_tagline          A biotechnology company dedicated to pursuing ...
# _yoe                                                                  10.0
# _mgmt                                                                  NaN
# requirements_summary     Over 10 years of experience in supply chain an...
# technical_tools          [Python, SQL, Tableau, Machine Learning, Stati...
# _hash                                                     swk4x1c3zudzq3x3
# collapse_key             61c65203f4f03bfcd120a413a545c47cfe3226da3f3184...
# _geoloc                                [{'lon': -85.7594, 'lat': 38.2542}]

# %%
_position = job_df['_id'].str.rsplit('.', n=1).str[0]
job_df['hash'] = job_df['_id'].str.rsplit('.', n=1).str[1]

# %%
__DS_regex = r"(?:data|\bml\b|machine learning|\bai\b|artificial intelligence|\bnlp\b|statistical|\bbi\b|business intelligence|devops|mlops).+(?:engineer|scientist|science|programmer)"
_sw_mask = job_df['title'].fillna('').str.contains(r'software.+engineer', case=False)
__DS_mask = job_df['title'].fillna('').str.contains(__DS_regex, case=False)
_DS_mask = __DS_mask & ~_sw_mask
_perc(_DS_mask)
# Out:
# 6,149 of 20,776 (29.6%)

# %%
ds_mask = job_df['title'].fillna('').str.contains(r'data.+scien', case=False)
ml_mask = job_df['title'].fillna('').str.contains(r'\bml\b|machine.+learning', case=False)
ai_mask = job_df['title'].fillna('').str.contains(r'\bai\b|artificial.+intelligence', case=False)
nlp_mask = job_df['title'].fillna('').str.contains(r'\bnlp\b|natural.+lang.+process', case=False)
_eng_mask = job_df['title'].fillna('').str.contains(r'engineer', case=False)

_health_industries = []
bay_mask = job_df['_bay'].notna()
health_mask = comp_df['industries'].apply(set) & pd.Series([_health_industries]*len(job_df))
yoe_mask = job_df['_yoe'].fillna(0) < 7
_45d_mask = job_df['_days'].fillna(0) <= 45
remote_mask = job_df['workplace_type'] == "Remote"
yoe_45d_mask = yoe_mask & _45d_mask
bay_remote_mask = bay_mask | remote_mask
DS_mask = _DS_mask & bay_remote_mask & yoe_45d_mask
DS_health_mask = _DS_mask & health_mask & bay_remote_mask & yoe_45d_mask

# %%
_DS_set = job_df[_DS_mask]['_hash'].pipe(set)
bay_set = job_df[bay_mask]['_hash'].pipe(set)
health_set = job_df[health_mask]['_hash'].pipe(set)
yoe_set = job_df[yoe_mask]['_hash'].pipe(set)
_45d_set = job_df[_45d_mask]['_hash'].pipe(set)
remote_set = job_df[remote_mask]['_hash'].pipe(set)
yoe_45d_set = yoe_set & _45d_set
bay_remote_set = bay_set | remote_set

DS_set = _DS_set & bay_remote_set & yoe_45d_set
DS_health_set = _DS_set & health_set & bay_remote_set & yoe_45d_set

# %%
aw.displays(
    aw.combo_sizes([bay_remote_set, yoe_45d_set, _DS_set, health_set], ['Bay_Remote', 'yoe_45d', 'DS', 'Health']),
    aw.combo_sizes2([bay_remote_set, yoe_45d_set, _DS_set, health_set], ['Bay_Remote', 'yoe_45d', 'DS', 'Health']),
)
# Out:
# <style type="text/css">
# #T_b8897_row0_col0, #T_b8897_row0_col1, #T_b8897_row0_col2, #T_b8897_row0_col3, #T_b8897_row0_col4, #T_b8897_row1_col1, #T_b8897_row1_col2, #T_b8897_row1_col3, #T_b8897_row1_col4, #T_b8897_row2_col0, #T_b8897_row2_col2, #T_b8897_row2_col3, #T_b8897_row2_col4, #T_b8897_row3_col0, #T_b8897_row3_col1, #T_b8897_row3_col3, #T_b8897_row3_col4, #T_b8897_row4_col2, #T_b8897_row4_col3, #T_b8897_row4_col4, #T_b8897_row5_col1, #T_b8897_row5_col3, #T_b8897_row5_col4, #T_b8897_row6_col0, #T_b8897_row6_col1, #T_b8897_row6_col2, #T_b8897_row6_col4, #T_b8897_row7_col0, #T_b8897_row7_col3, #T_b8897_row7_col4, #T_b8897_row8_col1, #T_b8897_row8_col2, #T_b8897_row8_col4, #T_b8897_row9_col3, #T_b8897_row9_col4, #T_b8897_row10_col0, #T_b8897_row10_col2, #T_b8897_row10_col4, #T_b8897_row11_col0, #T_b8897_row11_col1, #T_b8897_row11_col4, #T_b8897_row12_col2, #T_b8897_row12_col4, #T_b8897_row13_col1, #T_b8897_row13_col4, #T_b8897_row14_col0, #T_b8897_row14_col4, #T_b8897_row15_col4 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 100.0%, transparent 100.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row1_col0, #T_b8897_row2_col1, #T_b8897_row3_col2, #T_b8897_row4_col0, #T_b8897_row4_col1, #T_b8897_row5_col0, #T_b8897_row5_col2, #T_b8897_row6_col3, #T_b8897_row7_col1, #T_b8897_row7_col2, #T_b8897_row8_col0, #T_b8897_row8_col3, #T_b8897_row9_col0, #T_b8897_row9_col1, #T_b8897_row9_col2, #T_b8897_row10_col1, #T_b8897_row10_col3, #T_b8897_row11_col2, #T_b8897_row11_col3, #T_b8897_row12_col0, #T_b8897_row12_col1, #T_b8897_row12_col3, #T_b8897_row13_col0, #T_b8897_row13_col2, #T_b8897_row13_col3, #T_b8897_row14_col1, #T_b8897_row14_col2, #T_b8897_row14_col3, #T_b8897_row15_col0, #T_b8897_row15_col1, #T_b8897_row15_col2, #T_b8897_row15_col3 {
#   background-color: green;
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 69.6%, transparent 69.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 50.6%, transparent 50.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 34.7%, transparent 34.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 28.9%, transparent 28.9%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 22.0%, transparent 22.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 15.2%, transparent 15.2%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 14.2%, transparent 14.2%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 8.4%, transparent 8.4%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 8.0%, transparent 8.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 7.6%, transparent 7.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 5.0%, transparent 5.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 3.9%, transparent 3.9%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row13_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 3.0%, transparent 3.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row14_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 2.4%, transparent 2.4%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_b8897_row15_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.3%, transparent 1.3%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_b8897" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8897_level0_col0" class="col_heading level0 col0" >Bay_Remote</th>
#       <th id="T_b8897_level0_col1" class="col_heading level0 col1" >yoe_45d</th>
#       <th id="T_b8897_level0_col2" class="col_heading level0 col2" >DS</th>
#       <th id="T_b8897_level0_col3" class="col_heading level0 col3" >Health</th>
#       <th id="T_b8897_level0_col4" class="col_heading level0 col4" >Size</th>
#       <th id="T_b8897_level0_col5" class="col_heading level0 col5" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8897_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b8897_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_b8897_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_b8897_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_b8897_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_b8897_row0_col4" class="data row0 col4" >17,065</td>
#       <td id="T_b8897_row0_col5" class="data row0 col5" >100</td>
#     </tr>
#     <tr>
#       <th id="T_b8897_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b8897_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_b8897_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_b8897_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_b8897_row1_col3" class="data row1 col3" >-</td>
#       <td id="T_b8897_row1_col4" class="data row1 col4" >11,885</td>
#       <td id="T_b8897_row1_col5" class="data row1 col5" >69.65</td>
#     </tr>
#     <tr>
#       <th id="T_b8897_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b8897_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_b8897_row2_col1" class="data row2 col1" >Yes</td>
#       <td id="T_b8897_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_b8897_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_b8897_row2_col4" class="data row2 col4" >8,641</td>
#       <td id="T_b8897_row2_col5" class="data row2 col5" >50.64</td>
#     </tr>
#     <tr>
#       <th id="T_b8897_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b8897_row3_col0" class="data row3 col0" >-</td>
#       <td id="T_b8897_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_b8897_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_b8897_row3_col3" class="data row3 col3" >-</td>
#       <td id="T_b8897_row3_col4" class="data row3 col4" >5,916</td>
#       <td id="T_b8897_row3_col5" class="data row3 col5" >34.67</td>
#     </tr>
#     <tr>
#       <th id="T_b8897_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b8897_row4_col0" class="data row4 col0" >Yes</td>
#       <td id="T_b8897_row4_col1" class="data row4 col1" >Yes</td>
#       <td id="T_b8897_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_b8897_row4_col3" class="data row4 col3" >-</td>
#       <td id="T_b8897_row4_col4" class="data row4 col4" >4,933</td>
#       <td id="T_b8897_row4_col5" class="data row4 col5" >28.91</td>
#     </tr>
#     <tr>
#       <th id="T_b8897_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b8897_row5_col0" class="data row5 col0" >Yes</td>
#       <td id="T_b8897_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_b8897_row5_col2" class="data row5 col2" >Yes</td>
#       <td id="T_b8897_row5_col3" class="data row5 col3" >-</td>
#       <td id="T_b8897_row5_col4" class="data row5 col4" >3,761</td>
#       <td id="T_b8897_row5_col5" class="data row5 col5" >22.04</td>
#     </tr>
#     <tr>
#       <th id="T_b8897_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b8897_row6_col0" class="data row6 col0" >-</td>
#       <td id="T_b8897_row6_col1" class="data row6 co

# %%
# aw.displays(
#     aw.combo_sizes([bay_remote_set, yoe_45d_set, _DS_set, health_set], ['Bay_Remote', 'yoe_45d', 'DS', 'Health']),
#     aw.combo_sizes2([bay_remote_set, yoe_45d_set, _DS_set, health_set], ['Bay_Remote', 'yoe_45d', 'DS', 'Health']),
# )
# Out:
# <style type="text/css">
# #T_966ce_row0_col0, #T_966ce_row0_col1, #T_966ce_row0_col2, #T_966ce_row0_col3, #T_966ce_row0_col4, #T_966ce_row1_col1, #T_966ce_row1_col2, #T_966ce_row1_col3, #T_966ce_row1_col4, #T_966ce_row2_col0, #T_966ce_row2_col2, #T_966ce_row2_col3, #T_966ce_row2_col4, #T_966ce_row3_col0, #T_966ce_row3_col1, #T_966ce_row3_col3, #T_966ce_row3_col4, #T_966ce_row4_col2, #T_966ce_row4_col3, #T_966ce_row4_col4, #T_966ce_row5_col1, #T_966ce_row5_col3, #T_966ce_row5_col4, #T_966ce_row6_col0, #T_966ce_row6_col1, #T_966ce_row6_col2, #T_966ce_row6_col4, #T_966ce_row7_col0, #T_966ce_row7_col3, #T_966ce_row7_col4, #T_966ce_row8_col3, #T_966ce_row8_col4, #T_966ce_row9_col1, #T_966ce_row9_col2, #T_966ce_row9_col4, #T_966ce_row10_col0, #T_966ce_row10_col2, #T_966ce_row10_col4, #T_966ce_row11_col0, #T_966ce_row11_col1, #T_966ce_row11_col4, #T_966ce_row12_col2, #T_966ce_row12_col4, #T_966ce_row13_col1, #T_966ce_row13_col4, #T_966ce_row14_col0, #T_966ce_row14_col4, #T_966ce_row15_col4 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 100.0%, transparent 100.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row1_col0, #T_966ce_row2_col1, #T_966ce_row3_col2, #T_966ce_row4_col0, #T_966ce_row4_col1, #T_966ce_row5_col0, #T_966ce_row5_col2, #T_966ce_row6_col3, #T_966ce_row7_col1, #T_966ce_row7_col2, #T_966ce_row8_col0, #T_966ce_row8_col1, #T_966ce_row8_col2, #T_966ce_row9_col0, #T_966ce_row9_col3, #T_966ce_row10_col1, #T_966ce_row10_col3, #T_966ce_row11_col2, #T_966ce_row11_col3, #T_966ce_row12_col0, #T_966ce_row12_col1, #T_966ce_row12_col3, #T_966ce_row13_col0, #T_966ce_row13_col2, #T_966ce_row13_col3, #T_966ce_row14_col1, #T_966ce_row14_col2, #T_966ce_row14_col3, #T_966ce_row15_col0, #T_966ce_row15_col1, #T_966ce_row15_col2, #T_966ce_row15_col3 {
#   background-color: green;
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 72.7%, transparent 72.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 52.0%, transparent 52.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 33.5%, transparent 33.5%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 32.5%, transparent 32.5%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 22.7%, transparent 22.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 15.3%, transparent 15.3%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 13.8%, transparent 13.8%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 8.8%, transparent 8.8%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 8.7%, transparent 8.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row10_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 8.1%, transparent 8.1%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 4.7%, transparent 4.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row12_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 4.2%, transparent 4.2%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row13_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 3.0%, transparent 3.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row14_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 2.4%, transparent 2.4%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_966ce_row15_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.4%, transparent 1.4%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_966ce" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_966ce_level0_col0" class="col_heading level0 col0" >Bay_Remote</th>
#       <th id="T_966ce_level0_col1" class="col_heading level0 col1" >yoe_45d</th>
#       <th id="T_966ce_level0_col2" class="col_heading level0 col2" >DS</th>
#       <th id="T_966ce_level0_col3" class="col_heading level0 col3" >Health</th>
#       <th id="T_966ce_level0_col4" class="col_heading level0 col4" >Size</th>
#       <th id="T_966ce_level0_col5" class="col_heading level0 col5" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_966ce_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_966ce_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_966ce_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_966ce_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_966ce_row0_col3" class="data row0 col3" >-</td>
#       <td id="T_966ce_row0_col4" class="data row0 col4" >15,346</td>
#       <td id="T_966ce_row0_col5" class="data row0 col5" >100</td>
#     </tr>
#     <tr>
#       <th id="T_966ce_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_966ce_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_966ce_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_966ce_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_966ce_row1_col3" class="data row1 col3" >-</td>
#       <td id="T_966ce_row1_col4" class="data row1 col4" >11,164</td>
#       <td id="T_966ce_row1_col5" class="data row1 col5" >72.75</td>
#     </tr>
#     <tr>
#       <th id="T_966ce_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_966ce_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_966ce_row2_col1" class="data row2 col1" >Yes</td>
#       <td id="T_966ce_row2_col2" class="data row2 col2" >-</td>
#       <td id="T_966ce_row2_col3" class="data row2 col3" >-</td>
#       <td id="T_966ce_row2_col4" class="data row2 col4" >7,979</td>
#       <td id="T_966ce_row2_col5" class="data row2 col5" >51.99</td>
#     </tr>
#     <tr>
#       <th id="T_966ce_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_966ce_row3_col0" class="data row3 col0" >-</td>
#       <td id="T_966ce_row3_col1" class="data row3 col1" >-</td>
#       <td id="T_966ce_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_966ce_row3_col3" class="data row3 col3" >-</td>
#       <td id="T_966ce_row3_col4" class="data row3 col4" >5,146</td>
#       <td id="T_966ce_row3_col5" class="data row3 col5" >33.53</td>
#     </tr>
#     <tr>
#       <th id="T_966ce_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_966ce_row4_col0" class="data row4 col0" >Yes</td>
#       <td id="T_966ce_row4_col1" class="data row4 col1" >Yes</td>
#       <td id="T_966ce_row4_col2" class="data row4 col2" >-</td>
#       <td id="T_966ce_row4_col3" class="data row4 col3" >-</td>
#       <td id="T_966ce_row4_col4" class="data row4 col4" >4,995</td>
#       <td id="T_966ce_row4_col5" class="data row4 col5" >32.55</td>
#     </tr>
#     <tr>
#       <th id="T_966ce_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_966ce_row5_col0" class="data row5 col0" >Yes</td>
#       <td id="T_966ce_row5_col1" class="data row5 col1" >-</td>
#       <td id="T_966ce_row5_col2" class="data row5 col2" >Yes</td>
#       <td id="T_966ce_row5_col3" class="data row5 col3" >-</td>
#       <td id="T_966ce_row5_col4" class="data row5 col4" >3,490</td>
#       <td id="T_966ce_row5_col5" class="data row5 col5" >22.74</td>
#     </tr>
#     <tr>
#       <th id="T_966ce_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_966ce_row6_col0" class="data row6 col0" >-</td>
#       <td id="T_966ce_row6_col1" class="data row6 co

# %%
_DS_df = job_df[_DS_mask].sort_values(['_est_pub_date', '_ctime'], ascending=False).drop_duplicates('_hash')
DS_df = job_df[DS_mask].sort_values(['_est_pub_date', '_ctime'], ascending=False).drop_duplicates('_hash')
DS_health_df = job_df[DS_health_mask].sort_values(['_est_pub_date', '_ctime'], ascending=False).drop_duplicates('_hash')
_DS_df.shape[0], DS_df.shape[0], DS_health_df.shape[0]
# Out: (5146, 1343, 215)
# Out: (5916, 1362, 222)
# Out:
# (5916, 1362, 222)

# %%
aw.displays(
    DS_df['company_name'].pipe(aw.vcounts),
    DS_health_df['company_name'].pipe(aw.vcounts),
)
# Out:
# <style type="text/css">
# #T_9f238_row0_col0, #T_9f238_row0_col1, #T_9f238_row1_col0, #T_9f238_row1_col1, #T_9f238_row2_col0, #T_9f238_row2_col1, #T_9f238_row3_col0, #T_9f238_row3_col1, #T_9f238_row4_col0, #T_9f238_row4_col1, #T_9f238_row5_col0, #T_9f238_row5_col1, #T_9f238_row6_col0, #T_9f238_row6_col1, #T_9f238_row7_col0, #T_9f238_row7_col1, #T_9f238_row8_col0, #T_9f238_row8_col1, #T_9f238_row9_col0, #T_9f238_row9_col1, #T_9f238_row10_col0, #T_9f238_row10_col1, #T_9f238_row11_col0, #T_9f238_row11_col1, #T_9f238_row12_col0, #T_9f238_row12_col1, #T_9f238_row13_col0, #T_9f238_row13_col1, #T_9f238_row14_col0, #T_9f238_row14_col1, #T_9f238_row15_col0, #T_9f238_row15_col1, #T_9f238_row16_col0, #T_9f238_row16_col1, #T_9f238_row17_col0, #T_9f238_row17_col1, #T_9f238_row18_col0, #T_9f238_row18_col1, #T_9f238_row19_col0, #T_9f238_row19_col1, #T_9f238_row20_col0, #T_9f238_row20_col1 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.6%, transparent 1.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.3%, transparent 1.3%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.0%, transparent 1.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row3_col2, #T_9f238_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.9%, transparent 0.9%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row5_col2, #T_9f238_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.8%, transparent 0.8%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row7_col2, #T_9f238_row8_col2, #T_9f238_row9_col2, #T_9f238_row10_col2, #T_9f238_row11_col2, #T_9f238_row12_col2, #T_9f238_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.7%, transparent 0.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row14_col2, #T_9f238_row15_col2, #T_9f238_row16_col2, #T_9f238_row17_col2, #T_9f238_row18_col2, #T_9f238_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.6%, transparent 0.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_9f238_row20_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 84.1%, transparent 84.1%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_9f238" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f238_level0_col0" class="col_heading level0 col0" >company_name</th>
#       <th id="T_9f238_level0_col1" class="col_heading level0 col1" >N</th>
#       <th id="T_9f238_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f238_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9f238_row0_col0" class="data row0 col0" >Google</td>
#       <td id="T_9f238_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_9f238_row0_col2" class="data row0 col2" >1.63</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9f238_row1_col0" class="data row1 col0" >Adobe</td>
#       <td id="T_9f238_row1_col1" class="data row1 col1" >18</td>
#       <td id="T_9f238_row1_col2" class="data row1 col2" >1.33</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9f238_row2_col0" class="data row2 col0" >Capital One</td>
#       <td id="T_9f238_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_9f238_row2_col2" class="data row2 col2" >1.04</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9f238_row3_col0" class="data row3 col0" >Generalmotors</td>
#       <td id="T_9f238_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_9f238_row3_col2" class="data row3 col2" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9f238_row4_col0" class="data row4 col0" >UnitedHealth Group</td>
#       <td id="T_9f238_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_9f238_row4_col2" class="data row4 col2" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9f238_row5_col0" class="data row5 col0" >Netflix</td>
#       <td id="T_9f238_row5_col1" class="data row5 col1" >11</td>
#       <td id="T_9f238_row5_col2" class="data row5 col2" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_9f238_row6_col0" class="data row6 col0" >Reducto</td>
#       <td id="T_9f238_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_9f238_row6_col2" class="data row6 col2" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_9f238_row7_col0" class="data row7 col0" >CapitalOne</td>
#       <td id="T_9f238_row7_col1" class="data row7 col1" >10</td>
#       <td id="T_9f238_row7_col2" class="data row7 col2" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_9f238_row8_col0" class="data row8 col0" >Walmart</td>
#       <td id="T_9f238_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_9f238_row8_col2" class="data row8 col2" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_9f238_row9_col0" class="data row9 col0" >Experian</td>
#       <td id="T_9f238_row9_col1" class="data row9 col1" >10</td>
#       <td id="T_9f238_row9_col2" class="data row9 col2" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_9f238_row10_col0" class="data row10 col0" >Jerry.ai</td>
#       <td id="T_9f238_row10_col1" class="data row10 col1" >10</td>
#       <td id="T_9f238_row10_col2" class="data row10 col2" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_9f238_row11_col0" class="data row11 col0" >Nvidia</td>
#       <td id="T_9f238_row11_col1" class="data row11 col1" >9</td>
#       <td id="T_9f238_row11_col2" class="data row11 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_9f238_row12_col0" class="data row12 col0" >Centene</td>
#       <td id="T_9f238_row12_col1" class="data row12 col1" >9</td>
#       <td id="T_9f238_row12_col2" class="data row12 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_9f238_row13_col0" class="data row13 col0" >Humana</td>
#       <td id="T_9f238_row13_col1" class="data row13 col1" >9</td>
#       <td id="T_9f238_row13_col2" class="data row13 col2" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_9f238_row14_col0" class="data row14 col0" >Roblox</td>
#       <td id="T_9f238_row14_col1" class="data row14 col1" >8</td>
#       <td id="T_9f238_row14_col2" class="data row14 col2" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_9f238_row15_col0" class="data row15 col0" >MLabs Ltd</td>
#       <td id="T_9f238_row15_col1" class="data row15 col1" >8</td>
#       <td id="T_9f238_row15_col2" class="data row15 col2" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_9f238_row16_col0" class="data row16 col0" >Anthropic</td>
#       <td id="T_9f238_row16_col1" class="data row16 col1" >8</td>
#       <td id="T_9f238_row16_col2" class="data row16 col2" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_9f238_level0_row17" class="row_heading level0 r

# %%
aw.displays(
    # _DS_df['technical_tools'].explode().pipe(aw.vcounts, cutoff=30),
    DS_df['technical_tools'].explode().pipe(aw.vcounts, cutoff=30),
    DS_health_df['technical_tools'].explode().pipe(aw.vcounts, cutoff=30),
)
# Out:
# <style type="text/css">
# #T_69f33_row0_col0, #T_69f33_row0_col1, #T_69f33_row1_col0, #T_69f33_row1_col1, #T_69f33_row2_col0, #T_69f33_row2_col1, #T_69f33_row3_col0, #T_69f33_row3_col1, #T_69f33_row4_col0, #T_69f33_row4_col1, #T_69f33_row5_col0, #T_69f33_row5_col1, #T_69f33_row6_col0, #T_69f33_row6_col1, #T_69f33_row7_col0, #T_69f33_row7_col1, #T_69f33_row8_col0, #T_69f33_row8_col1, #T_69f33_row9_col0, #T_69f33_row9_col1, #T_69f33_row10_col0, #T_69f33_row10_col1, #T_69f33_row11_col0, #T_69f33_row11_col1, #T_69f33_row12_col0, #T_69f33_row12_col1, #T_69f33_row13_col0, #T_69f33_row13_col1, #T_69f33_row14_col0, #T_69f33_row14_col1, #T_69f33_row15_col0, #T_69f33_row15_col1, #T_69f33_row16_col0, #T_69f33_row16_col1, #T_69f33_row17_col0, #T_69f33_row17_col1, #T_69f33_row18_col0, #T_69f33_row18_col1, #T_69f33_row19_col0, #T_69f33_row19_col1, #T_69f33_row20_col0, #T_69f33_row20_col1, #T_69f33_row21_col0, #T_69f33_row21_col1, #T_69f33_row22_col0, #T_69f33_row22_col1, #T_69f33_row23_col0, #T_69f33_row23_col1, #T_69f33_row24_col0, #T_69f33_row24_col1, #T_69f33_row25_col0, #T_69f33_row25_col1, #T_69f33_row26_col0, #T_69f33_row26_col1, #T_69f33_row27_col0, #T_69f33_row27_col1, #T_69f33_row28_col0, #T_69f33_row28_col1, #T_69f33_row29_col0, #T_69f33_row29_col1, #T_69f33_row30_col0, #T_69f33_row30_col1 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 8.6%, transparent 8.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 5.1%, transparent 5.1%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 3.0%, transparent 3.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 2.3%, transparent 2.3%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.8%, transparent 1.8%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row5_col2, #T_69f33_row6_col2, #T_69f33_row7_col2, #T_69f33_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.7%, transparent 1.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.6%, transparent 1.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.4%, transparent 1.4%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row11_col2, #T_69f33_row12_col2, #T_69f33_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.3%, transparent 1.3%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row14_col2, #T_69f33_row15_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.2%, transparent 1.2%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row16_col2, #T_69f33_row17_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.0%, transparent 1.0%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row18_col2, #T_69f33_row19_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.8%, transparent 0.8%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row20_col2, #T_69f33_row21_col2, #T_69f33_row22_col2, #T_69f33_row23_col2, #T_69f33_row24_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.7%, transparent 0.7%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row25_col2, #T_69f33_row26_col2, #T_69f33_row27_col2, #T_69f33_row28_col2, #T_69f33_row29_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 0.6%, transparent 0.6%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_69f33_row30_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 53.1%, transparent 53.1%);
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_69f33" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69f33_level0_col0" class="col_heading level0 col0" >technical_tools</th>
#       <th id="T_69f33_level0_col1" class="col_heading level0 col1" >N</th>
#       <th id="T_69f33_level0_col2" class="col_heading level0 col2" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69f33_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_69f33_row0_col0" class="data row0 col0" >Python</td>
#       <td id="T_69f33_row0_col1" class="data row0 col1" >1,073</td>
#       <td id="T_69f33_row0_col2" class="data row0 col2" >8.6</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_69f33_row1_col0" class="data row1 col0" >SQL</td>
#       <td id="T_69f33_row1_col1" class="data row1 col1" >631</td>
#       <td id="T_69f33_row1_col2" class="data row1 col2" >5.05</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_69f33_row2_col0" class="data row2 col0" >AWS</td>
#       <td id="T_69f33_row2_col1" class="data row2 col1" >378</td>
#       <td id="T_69f33_row2_col2" class="data row2 col2" >3.03</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_69f33_row3_col0" class="data row3 col0" >PyTorch</td>
#       <td id="T_69f33_row3_col1" class="data row3 col1" >286</td>
#       <td id="T_69f33_row3_col2" class="data row3 col2" >2.29</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_69f33_row4_col0" class="data row4 col0" >TensorFlow</td>
#       <td id="T_69f33_row4_col1" class="data row4 col1" >227</td>
#       <td id="T_69f33_row4_col2" class="data row4 col2" >1.82</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_69f33_row5_col0" class="data row5 col0" >Docker</td>
#       <td id="T_69f33_row5_col1" class="data row5 col1" >215</td>
#       <td id="T_69f33_row5_col2" class="data row5 col2" >1.72</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_69f33_row6_col0" class="data row6 col0" >Kubernetes</td>
#       <td id="T_69f33_row6_col1" class="data row6 col1" >214</td>
#       <td id="T_69f33_row6_col2" class="data row6 col2" >1.71</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_69f33_row7_col0" class="data row7 col0" >Azure</td>
#       <td id="T_69f33_row7_col1" class="data row7 col1" >208</td>
#       <td id="T_69f33_row7_col2" class="data row7 col2" >1.67</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_69f33_row8_col0" class="data row8 col0" >Snowflake</td>
#       <td id="T_69f33_row8_col1" class="data row8 col1" >206</td>
#       <td id="T_69f33_row8_col2" class="data row8 col2" >1.65</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_69f33_row9_col0" class="data row9 col0" >Spark</td>
#       <td id="T_69f33_row9_col1" class="data row9 col1" >197</td>
#       <td id="T_69f33_row9_col2" class="data row9 col2" >1.58</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_69f33_row10_col0" class="data row10 col0" >Terraform</td>
#       <td id="T_69f33_row10_col1" class="data row10 col1" >174</td>
#       <td id="T_69f33_row10_col2" class="data row10 col2" >1.39</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_69f33_row11_col0" class="data row11 col0" >R</td>
#       <td id="T_69f33_row11_col1" class="data row11 col1" >161</td>
#       <td id="T_69f33_row11_col2" class="data row11 col2" >1.29</td>
#     </tr>
#     <tr>
#       <th id="T_69f33_level0_row12" cla

# %%
DL_mask = job_df['technical_tools'].apply(lambda x: bool(set(x) & {'PyTorch', 'TensorFlow', 'LangChain', 'LLMs', 'JAX', 'Keras', 'Hugging Face'}) if x else False)
_perc(DL_mask)
# Out:
# 2,342 of 20,776 (11.3%)

# %%
hash = "8w6m7h1f6lz3ybv0"
(job_df.query('_hash == @hash')[['technical_tools']])
# Out:
#                           technical_tools
# 10634  [Python, R, Tableau, Hadoop, Epic]

# %%
_merged_df = pd.merge(job_df, src_df, on=['_id', '_hash', '_ctime', '_est_pub_date', 'title'])
merged_df = pd.merge(_merged_df, comp_df, on=['_id', 'company_name', 'collapse_key'])

# %%
from IPython.display import display
COLS = ['_id', '_ctime', '_est_pub_date', 'title', '_loc', 'yearly_min_compensation', 'yearly_max_compensation',
    'workplace_type', 'commitment', 'company_name', 'company_tagline', '_yoe', '_mgmt', 'requirements_summary',
    'technical_tools',
    # '_hash',
    '_bay', '_days', 'website', 'tagline', 'is_non_profit', 'year_founded', 'num_employees',
    'industries', 'latest_investment_amount', 'latest_investment_year', 'latest_investment_series', 'investors',
    'parent_company', 'headquarters_country', 'linkedin_url'
]
def viewhash(hash):
    from IPython.display import HTML
    row_df = merged_df.query('_hash == @hash').sort_values(['_est_pub_date', '_ctime'], ascending=False)
    row = row_df.iloc[0]

    # display(row_df.drop(columns=['description', 'stripped_description']).T.style)
    display(row_df[COLS].T.dropna().style)
    print(com.viewjob(hash))
    # display(HTML(row['description']))
    print()
    print(md(row['description']))

viewhash("jvtqcgnyftowpgt5")
# Out:
# <style type="text/css">
# </style>
# <table id="T_712e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_712e5_level0_col0" class="col_heading level0 col0" >14762</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_712e5_level0_row0" class="row_heading level0 row0" >_id</th>
#       <td id="T_712e5_row0_col0" class="data row0 col0" >Pomelo Care - Data Scientist, Care Intelligence (San Francisco, hybrid).jvtqcgnyftowpgt5</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row1" class="row_heading level0 row1" >_ctime</th>
#       <td id="T_712e5_row1_col0" class="data row1 col0" >2025-11-11 19:30:37</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row2" class="row_heading level0 row2" >_est_pub_date</th>
#       <td id="T_712e5_row2_col0" class="data row2 col0" >2025-11-10 00:00:00</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row3" class="row_heading level0 row3" >title</th>
#       <td id="T_712e5_row3_col0" class="data row3 col0" >Data Scientist, Care Intelligence (San Francisco, hybrid)</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row4" class="row_heading level0 row4" >_loc</th>
#       <td id="T_712e5_row4_col0" class="data row4 col0" >San Francisco</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row5" class="row_heading level0 row5" >yearly_min_compensation</th>
#       <td id="T_712e5_row5_col0" class="data row5 col0" >140000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row6" class="row_heading level0 row6" >yearly_max_compensation</th>
#       <td id="T_712e5_row6_col0" class="data row6 col0" >160000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row7" class="row_heading level0 row7" >workplace_type</th>
#       <td id="T_712e5_row7_col0" class="data row7 col0" >Hybrid</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row8" class="row_heading level0 row8" >commitment</th>
#       <td id="T_712e5_row8_col0" class="data row8 col0" >['Full Time']</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row9" class="row_heading level0 row9" >company_name</th>
#       <td id="T_712e5_row9_col0" class="data row9 col0" >Pomelo Care</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row10" class="row_heading level0 row10" >company_tagline</th>
#       <td id="T_712e5_row10_col0" class="data row10 col0" >AI-driven care platform for maternal health.</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row11" class="row_heading level0 row11" >_yoe</th>
#       <td id="T_712e5_row11_col0" class="data row11 col0" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row12" class="row_heading level0 row12" >requirements_summary</th>
#       <td id="T_712e5_row12_col0" class="data row12 col0" >6+ years in data science with product focus; 3+ years in healthcare; SQL and Python proficiency; AI product prototyping; cross-functional collaboration.</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row13" class="row_heading level0 row13" >technical_tools</th>
#       <td id="T_712e5_row13_col0" class="data row13 col0" >['SQL', 'Python', 'Looker', 'Tableau', 'Metabase', 'dbt', 'Airflow', 'Snowflake']</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row14" class="row_heading level0 row14" >_bay</th>
#       <td id="T_712e5_row14_col0" class="data row14 col0" >('San Francisco',)</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row15" class="row_heading level0 row15" >_days</th>
#       <td id="T_712e5_row15_col0" class="data row15 col0" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row16" class="row_heading level0 row16" >website</th>
#       <td id="T_712e5_row16_col0" class="data row16 col0" >pomelocare.com</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row17" class="row_heading level0 row17" >tagline</th>
#       <td id="T_712e5_row17_col0" class="data row17 col0" >AI-driven care platform for maternal health.</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row18" class="row_heading level0 row18" >is_non_profit</th>
#       <td id="T_712e5_row18_col0" class="data row18 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row19" class="row_heading level0 row19" >year_founded</th>
#       <td id="T_712e5_row19_col0" class="data row19 col0" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row20" class="row_heading level0 row20" >num_employees</th>
#       <td id="T_712e5_row20_col0" class="data row20 col0" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row21" class="row_heading level0 row21" >industries</th>
#       <td id="T_712e5_row21_col0" class="data row21 col0" >('Home Health Care', 'Medical Organizations', 'Health Care Companies')</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row22" class="row_heading level0 row22" >latest_investment_amount</th>
#       <td id="T_712e5_row22_col0" class="data row22 col0" >46000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row23" class="row_heading level0 row23" >latest_investment_year</th>
#       <td id="T_712e5_row23_col0" class="data row23 col0" >2024.000000</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row24" class="row_heading level0 row24" >latest_investment_series</th>
#       <td id="T_712e5_row24_col0" class="data row24 col0" >Series B</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row25" class="row_heading level0 row25" >investors</th>
#       <td id="T_712e5_row25_col0" class="data row25 col0" >('Andreessen Horowitz', 'BoxGroup', 'Operator Partners', 'SV Angel', 'First Round Capital', 'Allen & Company', 'Puneet Singh', 'Adam Boehler', 'Stripes')</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row26" class="row_heading level0 row26" >headquarters_country</th>
#       <td id="T_712e5_row26_col0" class="data row26 col0" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_712e5_level0_row27" class="row_heading level0 row27" >linkedin_url</th>
#       <td id="T_712e5_row27_col0" class="data row27 col0" >linkedin.com/company/pomelo-care</td>
#     </tr>
#   </tbody>
# </table>
# https://hiring.cafe/viewjob/jvtqcgnyftowpgt5
#
# ### About us
#
# [Pomelo Care](http://www.pomelocare.com) is a multi-disciplinary team of clinicians, engineers and problem solvers who are passionate about improving care for moms and babies. We are transforming outcomes for pregnant people and babies with evidence-based pregnancy and newborn care at scale. Our technology-driven care platform enables us to engage patients early, conduct individualized risk assessments for poor pregnancy outcomes, and deliver coordinated, personalized virtual care throughout pregnancy, NICU stays, and the first postpartum year. We measure ourselves by reductions in preterm births, NICU admissions, c-sections and maternal mortality; we improve outcomes and reduce healthcare spend.
#
# ### Role Description
#
# **Your North Star**: Enable AI product development through data modeling, measurement, and data-driven insights
#
# We're looking to bring on an experienced data scientist to join a team developing AI-powered products across our platform. As a data scientist on the Care Intelligence team, you will design, build, and optimize intelligent systems that enhance our clinical programs, drive patient engagement, and create new capabilities for our care teams and patients.
#
# * Become an expert in Pomelo’s business model and patient experience, identifying opportunities for AI product development
# * Complete exploratory analyses to inform development of AI features, such as conversation topic categorization and patient journey segmentations
# * Contribute to the development of AI-powered features and products, such as content generation, clinical decision support, and automated workflows
# * Define and implement quantitative metrics and measurement frameworks to measure the quality and impact of AI-generated content and workflows
# * Execute comprehensive analyses to measure AI product performance, conduct A/B tests, and quantify the impact of AI-driven features on clinical and business outcomes
#
# **Who you are**
#
# You are an AI-focused data scientist and product thinker who is passionate about applying technology to healthcare challenges, and excited to work at a startup. Specifically,
#
# * You have 6+ years professional experience in a data science role with a focus on product development
# * You have 3+ years professional experience working in healthcare or regulated industries
# * Expert proficiency in both SQL and Python
# * Proven experience with AI product prototyping, leveraging LLMs and model evaluation
# * Passionate about improving maternal health outcomes through innovative AI solutions
# * Demonstrated ability to scope and implement solutions to complex, ambiguous problems across multiple domains
# * Excited to work cross-functionally with technical and non-technical teams, effectively communicating technical capabilities and limitations to diverse stakeholders
#
# **Bonus points if you have any of the following**
#
# * Experience with AI model development including fine-tuning, prompt engineering, model evaluation and building production AI applications
# * Background in healthcare AI, clinical decision support, or medical NLP
# * Experience with data visualization and dashboarding tools (e.g., Looker, Tableau, Metabase)
# * Experience working with modern data stack tools (e.g., dbt, Airflow, Snowflake)
#
# ### Why you should join our team
#
# By joining Pomelo, you will get in on the ground floor of a fast-moving, well-funded, and mission-driven startup that always puts the patient first. You will learn, grow and be challenged -- and have fun with your team while doing it.
#
# We strive to create an environment where employees from all backgrounds are respected. We also offer:
#
# * Competitive healthcare benefits
# * Generous equity compensation
# * Unlimited vacation
#
# At Pomelo, we are committed to hiring the best team to improve outcomes for all mothers and babies, regardless of their background. We need diverse perspectives to reflect the diversity of problems we face and the population we serve. We look to hire people from a variety of backgrounds, including but not limited to race, age, sexual orientation, gender identity and expression, national origin, religion, disability, and veteran status.
#
# *Our salary ranges are based on paying competitively for our company’s size and industry, and are one part of the total compensation package that also includes equity, benefits, and other opportunities at Pomelo Care. In accordance with New York City, Colorado, California, and other applicable laws, Pomelo Care is required to provide a reasonable estimate of the compensation range for this role. Individual pay decisions are ultimately based on a number of factors, including qualifications for the role, experience level, skillset, geography, and balancing internal equity. Given that this role is open to candidates of different skill levels, determining a salary range is challenging. A reasonable estimate of the current salary range is $140,000 to $160,000. We expect most candidates to fall in the middle of the range. We also believe that your personal needs and preferences should be taken into consideration, so we allow some choice between equity and cash.*
#
# ### **Potential Fraud Warning**
#
# *Please be cautious of potential recruitment fraud. With the increase of remote work and digital hiring, phishing and job scams are on the rise with malicious actors impersonating real employees and sending fake job offers in an effort to collect personal or financial information.*
#
# *Pomelo Care will never ask you to pay a fee or download software as part of the interview process with our company. Pomelo Care will also never ask for your personal banking or other financial information until after you have signed an offer of employment and completed onboarding paperwork that is provided by our People Operations team. All official communication with Pomelo Care People Operations team will come from domain email addresses ending in @pomelocare.com.*
#
# *If you receive a message that seems suspicious, we encourage you to pause communication and contact us directly at [careers@pomelocare.com](mailto:careers@pomelocare.com)  to confirm its legitimacy. For your safety, we also recommend applying only through our official [Careers](https://www.pomelocare.com/careers) page. If you believe you have been the victim of a scam or identity theft, please contact your local law enforcement agency or another trusted authority for guidance.*
