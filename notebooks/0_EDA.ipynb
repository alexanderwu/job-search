# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup

# %%
import os
from pathlib import Path

import pandas as pd
import polars as pl
from tqdm.notebook import tqdm

import job_search.dataset as dataset
import job_search.company as com
import job_search.resume as res
import job_search.utils as utils
from job_search.config import P_ROOT, P_JOBS, P_URLS, P_PROCESSED
from job_search.utils import path_names

import aw
utils.jupyter_css_style()
# Out:
#         <!-- https://stackoverflow.com/questions/71534901/make-tqdm-bar-dark-in-vscode-jupyter-notebook -->
#         <style>
#         .cell-output-ipywidget-background {
#             background-color: transparent !important;
#         }
#         :root {
#             --jp-widgets-color: var(--vscode-editor-foreground);
#             --jp-widgets-font-size: var(--vscode-editor-font-size);
#         }
#         </style>

# %%
# P_job_list = []

# jobs_paths = pd.Series([p for p in P_JOBS.glob('*.md')])
# for P_job in (pbar := tqdm(jobs_paths)):
#     # pbar.set_description(P_job.name)
#     if os.stat(P_job).st_size == 0:
#         P_job_list.append(P_job)
#         P_url = P_URLS / f"{P_job.stem}.html"
#         print(f'"{P_url}"')
#         if P_url.exists():
#             P_url.unlink()
#         P_job.unlink()

# %%
QUERY_LIST = [
    DS_NORCAL := 'DS_NorCal',
    HEALTH := 'Healthcare',
    SF := 'SF',
    DS_REMOTE := 'DS_Remote',
    # DS_SOCAL := 'DS_SoCal',
    # DS_SEATTLE := 'DS_Seattle',
    # DS_NY := 'DS_NY',
    # DS_MIDWEST := 'DS_Midwest',
    # DS_DC := 'DS_DC',
    # SW := 'SW',
    # SW_REMOTE := 'SW_Remote',
]
STEM = 'Healthcare'
# _date = com.now(time=False)
# _date = "2025-10-12"
_date = "2025-11-06"
P_save_dict = {stem: P_PROCESSED / (f'{_date}/{stem}/{stem}.html') for stem in QUERY_LIST}
P_companies_dict = {stem: P_save_dict[stem].parents[3] / f"cache/{stem}_company_urls" for stem in QUERY_LIST}
P_query_dict = {stem: P_save_dict[stem].parents[3] / f"queries/{stem}.txt" for stem in QUERY_LIST}
P_save = P_save_dict[STEM]
P_companies = P_companies_dict[STEM]
P_query = P_query_dict[STEM]

# %%
# jdf = com.load_jdf(P_save)
# cdf = com.load_cdf(P_companies)
# jdf_dict = {stem: com.load_jdf(P_save_dict[stem]) for stem in QUERY_LIST}
# cdf_dict = {stem: com.load_cdf(P_companies_dict[stem]) for stem in QUERY_LIST}
df_dict = {stem: com.load_df(P_save_dict[stem]).to_pandas() for stem in QUERY_LIST}
dfc_dict = {stem: com.load_dfc(P_save_dict[stem]).to_pandas() for stem in QUERY_LIST}

# %%
df = pd.concat(df_dict).drop_duplicates(subset='hash').pipe(pl.DataFrame)
dfc = df.group_by('company').agg([
    pl.len(),
    pl.col('title').implode(),
    pl.col('company_summary').first(),
    pl.col('hours').min().alias('days') // 24,
    pl.col('bay').pipe(com.pl_reduce_list),
    pl.col('location').pipe(com.pl_reduce_list),
    pl.col('skills').pipe(com.pl_reduce_list),
    # pl.col('onsite').pipe(com.pl_enum_min, df['onsite'].dtype),
    # pl.col('full_time').pipe(com.pl_enum_max, df['full_time'].dtype),
    pl.col('lower').min(),
    pl.col('median').mean().round(2),
    pl.col('upper').max(),
    # pl.col('url2').n_unique(),
]).to_pandas()
df = df.to_pandas()
df_hash_set = set(df['hash'])

# %%
print(f"{'ALL':12}: {len(df):,} jobs among {len(dfc):,} companies")
for stem in QUERY_LIST:
    print(f"{stem:12}: {len(df_dict[stem]):,} jobs among {len(dfc_dict[stem]):,} companies")
# ALL         : 3,548 jobs among 1,778 companies
# DS_NorCal   : 956 jobs among 583 companies
# Healthcare  : 499 jobs among 327 companies
# SF          : 903 jobs among 526 companies
# DS_Remote   : 2,149 jobs among 1,208 companies
# Out:
# ALL         : 3,648 jobs among 1,769 companies
# DS_NorCal   : 767 jobs among 404 companies
# Healthcare  : 930 jobs among 627 companies
# SF          : 1,193 jobs among 634 companies
# DS_Remote   : 1,582 jobs among 859 companies

# %%
P_urls_df_parquet = com.P_DATA / 'cache' / 'P_urls_df.parquet'
# com.path_df(P_URLS).to_parquet(P_urls_df_parquet)
# urls_df = pd.read_parquet('P_urls_df.parquet').query('stsize > 0').sort_values('ctime', ascending=False).drop_duplicates('hash').reset_index(drop=True)
urls_df = pd.read_parquet(P_urls_df_parquet).query('stsize > 0').sort_values('ctime', ascending=False).drop_duplicates('hash').reset_index(drop=True)
urls_df['company'] = urls_df['name'].str.split(' - ', n=1).str[0]
for stem in QUERY_LIST:
    urls_df[stem] = urls_df['hash'].isin(set(df_dict[stem]['hash']))
urls_df = urls_df.sort_values(QUERY_LIST, ascending=False, kind='stable').reset_index(drop=True)
urls_df['DS'] = urls_df['DS_NorCal'] | urls_df['DS_Remote']
urls_df['ALL'] = urls_df['hash'].isin(set(df['hash']))
companies_df = urls_df.drop_duplicates('company').reset_index(drop=True)

# %%
# aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in QUERY_LIST], QUERY_LIST)
# aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in QUERY_LIST[:3]], QUERY_LIST[:3])
# aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in QUERY_LIST[:2]], QUERY_LIST[:2])
aw.combo_sizes([set(urls_df.query(stem)['hash']) for stem in ['DS', HEALTH]], ['DS', HEALTH])
# Out:
# <style type="text/css">
# #T_e8fc7_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 100.0%, transparent 100.0%);
# }
# #T_e8fc7_row1_col0, #T_e8fc7_row2_col1, #T_e8fc7_row3_col0, #T_e8fc7_row3_col1 {
#   background-color: green;
# }
# #T_e8fc7_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 67.7%, transparent 67.7%);
# }
# #T_e8fc7_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 34.0%, transparent 34.0%);
# }
# #T_e8fc7_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #543b66 1.7%, transparent 1.7%);
# }
# </style>
# <table id="T_e8fc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8fc7_level0_col0" class="col_heading level0 col0" >DS</th>
#       <th id="T_e8fc7_level0_col1" class="col_heading level0 col1" >Healthcare</th>
#       <th id="T_e8fc7_level0_col2" class="col_heading level0 col2" >Size</th>
#       <th id="T_e8fc7_level0_col3" class="col_heading level0 col3" >%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8fc7_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e8fc7_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_e8fc7_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_e8fc7_row0_col2" class="data row0 col2" >2735</td>
#       <td id="T_e8fc7_row0_col3" class="data row0 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_e8fc7_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e8fc7_row1_col0" class="data row1 col0" >Yes</td>
#       <td id="T_e8fc7_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_e8fc7_row1_col2" class="data row1 col2" >1852</td>
#       <td id="T_e8fc7_row1_col3" class="data row1 col3" >67.7</td>
#     </tr>
#     <tr>
#       <th id="T_e8fc7_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_e8fc7_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_e8fc7_row2_col1" class="data row2 col1" >Yes</td>
#       <td id="T_e8fc7_row2_col2" class="data row2 col2" >929</td>
#       <td id="T_e8fc7_row2_col3" class="data row2 col3" >34.0</td>
#     </tr>
#     <tr>
#       <th id="T_e8fc7_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e8fc7_row3_col0" class="data row3 col0" >Yes</td>
#       <td id="T_e8fc7_row3_col1" class="data row3 col1" >Yes</td>
#       <td id="T_e8fc7_row3_col2" class="data row3 col2" >46</td>
#       <td id="T_e8fc7_row3_col3" class="data row3 col3" >1.7</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pickle

P_DICT = P_JOBS.parent / 'dicts'
P_DICT.mkdir(exist_ok=True)

industries_list = []
# _companies_hash_names = list(companies_df.query('ALL')[['hash', 'name']].iterrows())
_hash_names = list(urls_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_hash_names):
    P_dict = P_DICT / f'{name}.pkl'
    if P_dict.exists():
        continue
    next_data_dict = com.viewhash(hash)
    with open(P_dict, 'wb') as f:
        pickle.dump(next_data_dict, f)
# Out:
#   0%|          | 0/3647 [00:00<?, ?it/s]

# %%
all_dsize_list = []
_hash_names = list(urls_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_hash_names):
    P_dict = P_DICT / f'{name}.pkl'
    all_dsize_list.append(os.path.getsize(P_dict) )
# Out:
#   0%|          | 0/3647 [00:00<?, ?it/s]

# %%
all_urls_df = urls_df.query('ALL').copy()
all_urls_df['dsize'] = all_dsize_list

# %%
# all_urls_df.query('dsize < 162')

# %%
com.viewjob('kbu3hmc6a47mojfe')
# Out:
# 'https://hiring.cafe/viewjob/kbu3hmc6a47mojfe'

# %%
# import json
# import lxml
# identifier = all_urls_df.query('dsize < 162').iloc[3]['name'].removesuffix('.html')
# hash = identifier.rsplit('.', 1)[-1]
# url = com.VIEW_JOB_HTTPS + hash
# # html_source = dataset.requests_get(url).content
# html_source = dataset.selenium_get(url)
# root = lxml.html.fromstring(html_source)
# _next_data = root.xpath("//script[@id='__NEXT_DATA__']")[0]
# next_data_dict = json.loads(_next_data.text_content())

# %%
# verbose=True
# P_url = P_URLS / f"{identifier}.html"
# if verbose:
#     print(f'Writing to {P_url}')
# with open(P_url, 'w', encoding='utf-8') as f:
#     f.write(html_source)
# Out:
# Writing to /mnt/c/Users/alexa/Dev/Companies/data/cache/urls/Compass Group Careers - SENIOR DATA ENGINEER (REMOTE) (Chicago, IL, US, REMOTE).btwpoqpu1wic3xxi.html

# %%
next_data_dict
# Out:
# {'props': {'pageProps': {'job': {'id': 'successfactors___eu___merckgroup___1252210501',
#     'board_token': 'eu_merckgroup',
#     'source': 'successfactors',
#     'apply_url': 'https://jobs.vibrantm.com/job/Boston-Lead-Data-Scientist-Commercial-%28Seaport-MA%29-Mass-02210/1252210501/',
#     'source_and_board_token': 'successfactors_eu_merckgroup',
#     'job_information': {'title': 'Lead Data Scientist - Commercial (Seaport MA) (Boston, Massachusetts, US, 02210)',
#      'job_title_raw': 'Lead Data Scientist - Commercial (Seaport MA) (Boston, Massachusetts, US, 02210)',
#      'description': '<p style="text-align:justify">\xa0</p>\r\n\r\n<p><span style="font-size:12.0px"><span style="font-family:Verdana, Geneva, sans-serif">Work Your Magic with us!\xa0<span style="color:#ffffff">Start your next chapter and join EMD Serono.</span></span></span></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><span style="font-size:12.0px"><span style="font-family:Verdana, Geneva, sans-serif">Ready to explore, break barriers, and discover more? We know you’ve got big plans – so do we! Our colleagues across the globe love innovating with science and technology to enrich people’s lives with our solutions in Healthcare, Life Science, and Electronics. Together, we dream big and are passionate about caring for our rich mix of people, customers, patients, and planet. That\'s why we are always looking for curious minds that see themselves imagining the unimaginable with us. \xa0</span></span></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><span style="font-size:12.0px"><span style="font-family:Verdana, Geneva, sans-serif">United As One for Patients, our purpose in Healthcare is to help create, improve and prolong lives. We develop medicines, intelligent devices and innovative technologies in therapeutic areas such as Oncology, Neurology and Fertility. Our teams work together across 6 continents with passion and relentless curiosity in order to help patients at every stage of life. Joining our Healthcare team is becoming part of a diverse, inclusive and flexible working culture, presenting great opportunities for personal development and career advancement across the globe.</span></span></p>\r\n\r\n<p>\xa0</p>\r\n\r\n<p><span style="font-size:12.0px"><span style="font-family:Verdana, Geneva, sans-serif">This role does not offer sponsorship for work authorization. External applicants must be eligible to work in the US.\xa0</span></span></p>\r\n\r\n<p style="text-align:justify">\xa0</p>\r\n<p style="margin:0.0in 0.0in 8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif"><strong>Your Role:</strong></p>\r\n<p style="margin:0.0in 0.0in 8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif">At EMD Serono, data drives everything we do to bring innovative medicines to patients faster. As a Lead Data Scientist, you will shape commercial and medical strategies by analyzing complex datasets and applying advanced analytics and machine learning to generate actionable insights that optimize decisions, uncover opportunities, and improve patient outcomes.</p>\r\n<p style="margin:0.0in 0.0in 8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif"><strong>Key Responsibilities</strong></p>\r\n<ul style="margin-top:0.0in;margin-bottom:0.0in" type="disc">\r\n<li style="margin-top:0.0in;margin-right:0.0in;margin-bottom:8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif"><strong>Collaborate Across Teams</strong>: Partner with Commercial, Medical, and IT teams to identify high-impact problems and deliver analytics solutions aligned with business goals.</li>\r\n<li style="margin-top:0.0in;margin-right:0.0in;margin-bottom:8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif"><strong>Lead Advanced Analytics</strong>: Design, validate, and interpret supervised (regression, classification) and unsupervised models (clustering, dimensionality reduction) to drive decision-making and identify new opportunities.</li>\r\n<li style="margin-top:0.0in;margin-right:0.0in;margin-bottom:8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif"><strong>Causal Inference Expertise</strong>: Apply causal inference to experimental and observational data to optimize strategy and resource allocation.</li>\r\n<li style="margin-top:0.0in;margin-right:0.0in;margin-bottom:8.0pt;line-height:115%;font-size:12.0pt;font-family:Aptos, sans-serif"><strong>Scalable AI/ML Solutions</strong>: Build scalable AI/ML pipelines for large, high-dimensional datasets.</li>\r\n<li style="margin-top:0.0in;margin-right:0.0i ...
#      'stripped_description': "\n\nWork Your Magic with us!\xa0Start your next chapter and join EMD Serono.\n\n\n\nReady to explore, break barriers, and discover more? We know you’ve got big plans – so do we! Our colleagues across the globe love innovating with science and technology to enrich people’s lives with our solutions in Healthcare, Life Science, and Electronics. Together, we dream big and are passionate about caring for our rich mix of people, customers, patients, and planet. That's why we are always looking for curious minds that see themselves imagining the unimaginable with us. \xa0\n\n\n\nUnited As One for Patients, our purpose in Healthcare is to help create, improve and prolong lives. We develop medicines, intelligent devices and innovative technologies in therapeutic areas such as Oncology, Neurology and Fertility. Our teams work together across 6 continents with passion and relentless curiosity in order to help patients at every stage of life. Joining our Healthcare team is becoming part of a diverse, inclusive and flexible working culture, presenting great opportunities for personal development and career advancement across the globe.\n\n\n\nThis role does not offer sponsorship for work authorization. External applicants must be eligible to work in the US.\xa0\n\n\nYour Role:\nAt EMD Serono, data drives everything we do to bring innovative medicines to patients faster. As a Lead Data Scientist, you will shape commercial and medical strategies by analyzing complex datasets and applying advanced analytics and machine learning to generate actionable insights that optimize decisions, uncover opportunities, and improve patient outcomes.\nKey Responsibilities\n\nCollaborate Across Teams: Partner with Commercial, Medical, and IT teams to identify high-impact problems and deliver analytics solutions aligned with business goals.\nLead Advanced Analytics: Design, validate, and interpret supervised (regression, classification) and unsupervised models (clustering, dimensionality reduction) to drive decision-making and identify new opportunities.\nCausal Inference Expertise: Apply causal inference to experimental and observational data to optimize strategy and resource allocation.\nScalable AI/ML Solutions: Build scalable AI/ML pipelines for large, high-dimensional datasets.\nMentorship and Leadership: Mentor junior data scientists and foster a culture of excellence.\nHealthcare Expertise: Leverage deep knowledge of US healthcare and pharma commercial landscapes, including claims, EMR data, to deliver impactful solutions.\nCommunication and Influence: Translate complex analytical findings into clear, actionable business recommendations for diverse stakeholders.\n\n\nWho You Are\nMinimum Qualifications:\n\nMaster’s degree in Statistics, Data Science, Mathematics, Physics, Econometrics, Operations Research, a related quantitative field, or equivalent work experience.\n4+ years of experience as a data scientist in a commercial setting (pharma preferred).\nStrong expertise in supervised/unsupervised learning, causal inference, hypothesis testing, scalable ML pipelines, and feature engineering.\nProficiency in Python (pandas, scikit-learn), SQL, Git, Linux, AWS; experience with large healthcare datasets (claims data a plus) and parquet files.\n\n\nExperience deploying Python-based machine learning models in production using containers and/or shell scripting.\n\n\nPreferred Qualifications:\n\n6 or more years of work experience as a data scientist in a commercial setting (pharma preferred) with a Master’s degree, or\n4+ years with a PhD degree.\nPrior experience with marketing mix models (especially in pharma).\nUS healthcare and pharma commercial expertise strongly preferred.\n\n\nDemonstrated ability to leverage genAI tools and techniques for extracting features from text in a commercial context.\nSolid business acumen and ability to prioritize high-impact problems aligned with strategic objectives.\nStrong communication skill ...
#      'viewedByUsers': ['7CXIvLjsHVdPMmD7ylmc6soV3Du1',
#       'VFv6r6v9StWISkqml1qnycL8z5O2',
#       'CVuvjHzs9EP6UwbQyXFBtS6KiTL2'],
#      'savedFromUsers': ['Czu1TvWoKPcRjQ5w4GHS9VPdiPH3'],
#      'appliedFromUsers': ['7CXIvLjsHVdPMmD7ylmc6soV3Du1',
#       'VFv6r6v9StWISkqml1qnycL8z5O2'],
#      'hiddenFromUsers': ['sIB2Eneeu7fwINpXCTEXk7SFdZ92']},
#     'v5_processed_job_data': {'core_job_title': 'Data Scientist',
#      'requirements_summary': 'Master’s in a quantitative field; 4+ years data science experience in a commercial setting (pharma preferred); strong ML, causal inference, Python, SQL; healthcare data experience; production-model deployment; strong communication.',
#      'technical_tools': ['Python', 'SQL', 'Git', 'Linux', 'AWS'],
#      'technical_tools_synonyms': ['python',
#       'python scripting',
#       'python 3',
#       'python programming',
#       'scientific python',
#       'python applications',
#       'python programming language',
#       'python3',
#       'python scripts',
#       'python script',
#       'programming (python)',
#       'cpython',
#       'python (programming language)',
#       'python software development',
#       'scripting languages (python)',
#       'software development - python',
#       'phyton',
#       'python 3.x',
#       'sql',
#       'relational databases',
#       'databases',
#       'sql databases',
#       'microsoft sql',
#       'ms-sql',
#       'sql server',
#       'mssql',
#       'sql dbs',
#       'ms sql',
#       'rdbms',
#       'ms sql server',
#       'db sql',
#       'oracle sql',
#       'microsoft sql server',
#       'database',
#       'oracle sql server',
#       'ansi sql',
#       'sql database server',
#       'sql database',
#       'sqlserver',
#       'postgres sql',
#       'sql developer',
#       'database skills',
#       'ms sql database',
#       'sql studio',
#       'sql oracle',
#       'sql scripts',
#       'sql server mssql',
#       'my sql',
#       'ms-sql server',
#       'sql (postgres)',
#       'sql-server',
#       'msql',
#       'ms sql-server',
#       'sql analytics',
#       'sql programming',
#       'rdbms sql',
#       'ms/sql',
#       'structured query language',
#       'sql standard',
#       'sql servers',
#       'ms sqlserver',
#       't/sql',
#       'microsoft sqlserver',
#       'microsoft sql database',
#       'sql express',
#       'sql database infrastructure',
#       'sql lite',
#       'sql query',
#       'sql dba',
#       'advanced sql',
#       'sql language',
#       'sql/rdbms',
#       'sql database administration',
#       'oracle/sql',
#       'sql database management',
#       'sql management tools',
#       'msft sql',
#       'system query language (sql)',
#       'sql scripting',
#       'structured query language (sql)',
#       'sql reports',
#       'sql server database',
#       'sql query writing',
#       'sql anywhere',
#       'basic sql',
#       'sql server db',
#       'ms sql databases',
#       'sql db',
#       'sql procedures',
#       'sql command/server',
#       'mssql database',
#       'microsoft sql databases',
#       'database sql',
#       'sql client',
#       'sql queries',
#       'sql+',
#       'non-stop sql',
#       'nonstop sql',
#       'sql script',
#       'sql dw',
#       'sql (programming language)',
#       'database/sql',
#       'sql/mysql',
#       'sql data server',
#       'windows sql',
#       'sql database management systems',
#       'managed sql',
#       'sql-based databases',
#       'oracle database sql',
#       'open sql',
#       'sql server databases',
#       'ansi-sql',
#       'sql editor',
#       'db skills',
#       'sql query language',
#       'ms sql db',
#       'native sql',
#       'standard sql',
#       'sql dml',
#       'sql viewpoint',
#       'sql proficiency',
#       'sql (mysql)',
#       'git',
#       'github',
#       'gitlab',
#       'gitflow',
#       'git hub',
#       'git lab',
#       'git actions',
#       'git client',
#       'git enterprise',
#       'gitlab/git version control system',
#       'version control (git)',
#       'git version control',
#       'git/gitlab',
#       'git clients',
#       'git ci',
#       'git flow',
#       'gitlabs',
#       'git-hub',
#       'git operations',
#       'git workflow',
#       'gits',
#       'git ecosystem',
#       'git (version control system)',
#       'bitbucket/git',
#       'git/version control software',
#       'git configuration management',
#       'libgit',
#       'gitrepo',
#       'linux',
#       'unix',
#       'linux kernel',
#       'unix/linux',
#       'linux os',
#       'linux command line',
#       'gnu/linux',
#       'linux debian',
#       'ubuntu',
#       'linux servers',
#       'linux operating systems',
#       'red hat linux',
#       'linux/unix',
#       'linux operating system',
#       'redhat linux',
#       'linux administration',
#       'ubuntu linux',
#       'linux shell',
#       'unix systems',
#       'linux command line tools',
#       'linux networking',
#       'linux cli',
#       'linux systems',
#       'linux-os',
#       'linux server',
#       'debian linux',
#       'linux systems administration',
#       'unix-based systems',
#       'redhat/linux',
#       'linux bash',
#       'linux scripting',
#       'linux ubuntu',
#       'unix/linux operating system',
#       'os/linux',
#       'linux-based operating systems',
#       'linux workstation',
#       'lunix operating system',
#       'linux based systems',
#       'debian-based linux',
#       'linux system security',
#       '*nix systems',
#       'linux distributions',
#       'unix/linux os',
#       'linux server technologies',
#       'linux o/s',
#       'linux red hat',
#       'linux red hat 6',
#       'linux red hat 7',
#       'linux-based os',
#       'linux shell scripts',
#       'linux/unix command line',
#       'linux server administration',
#       'linux operating system management',
#       'rhel linux',
#       'linux vm',
#       'zlinux',
#       'linux internals',
#       'linux server management',
#       'linux technologies',
#       'linux kernel software',
#       'linux programming',
#       'linux shell tools',
#       'linux shells',
#       'linux security',
#       'linux command-line',
#       'linux/bash',
#       'unix/linux systems',
#       'java linux',
#       'enterprise linux',
#       'linux server operating systems',
#       'linux/unix server',
#       'linux environment',
#       'linux red hat enterprise',
#       'linux/aix/unix',
#       'linux commands',
#       'z/linux',
#       'unix-based os',
#       'linux suse',
#       'suse linux',
#       'unix system',
#       'linux bash shell',
#       'linux scripts',
#       '*nix servers',
#       'linux os administration',
#       'unix-based operating systems',
#       'centos linux',
#       '*nix',
#       'linux/unix operating systems',
#       'debian gnu/linux',
#       'red hat/centos linux',
#       'linux system administration',
#       'linux os management',
#       'os linux',
#       'linuxsuse',
#       'microsoft/linux servers',
#       'linux redhat',
#       'linux rhel',
#       'linux-based systems',
#       'linux/unix command line tools',
#       'linux-unix',
#       'linux virtual machines',
#       'unix/linux servers',
#       'linux/gnu',
#       'linux development',
#       'unix / linux',
#       'linux management',
#       'unix-like os',
#       'unix_linux',
#       'ubuntu linux server',
#       'linux os/kernel',
#       'gnu linux',
#       'linux/unix shell',
#       'linux applications',
#       'aws',
#       'aws iam',
#       'aws s3',
#       'aws lambda',
#       'aws rds',
#       'amazon web services',
#       'aws cloud',
#       'aws ecs',
#       'ec2',
#       'amazon ec2',
#       'amazon s3',
#       'aws services',
#       'amazon aws',
#       'aws cloud services',
#       'aws cloudwatch',
#       'aws cloud security tooling',
#       'aws govcloud',
#       'aws networking',
#       'aws cli',
#       'aws security',
#       'aws insight',
#       'aws tools',
#       'aws ec2',
#       'cloud security (aws)',
#       'cloud (aws)',
#       'aws networking services',
#       'aws eks',
#       'aws vpc',
#       'amazon web services (aws)',
#       'aws cloud wan',
#       'aws pipelines',
#       'cloud (aws or azure)',
#       'aws big data services',
#       'aws mwaa',
#       'aws data services',
#       'aws cloud technologies',
#       'cloud aws',
#       'aws serverless',
#       'aws devops',
#       'aws center',
#       'amazon aws ecs',
#       'amazon aws s3',
#       'aws sdks',
#       'aws api',
#       'amazon web service (aws)',
#       'aws gov cloud',
#       'aws infrastructure',
#       'aws cloud native',
#       'aws code tools',
#       'aws cloudwan',
#       'amazon elastic compute cloud',
#       'aws il6',
#       'amazon cloud services',
#       'amazon cloud technologies',
#       'aws cloud security services',
#       'aws console',
#       'amazon cloud platform',
#       'aws functions',
#       'amazon cloud',
#       'aws cloud systems',
#       'aws database',
#       'aws ace',
#       'aws sdk',
#       'aws cloud data services',
#       'aws ml',
#       'aws cloud iam',
#       'aws cloud platform',
#       'aws cloud infrastructure',
#       'aws ebs',
#       'aws sct',
#       'aws compute',
#       'aws cloud computing',
#       'aws data analytics',
#       'aws developer tools',
#       'aws cloud tools',
#       'aws standards',
#       'aws architecture',
#       'aws storage services',
#       'aws sdlf',
#       'aws security services',
#       'cloud (aws or gcp)',
#       'aws associate',
#       'aws reporting',
#       'aws beanstalk',
#       'aws database services',
#       'cloud technologies (aws)',
#       'aws cloud monitoring',
#       'aws kubernetes',
#       'aws lambdas',
#       'aws applications',
#       'csp (aws)',
#       'aws cloud computing foundation',
#       'amazon cloud hosting',
#       'aws-cli',
#       'aws native services',
#       'aws cloud service',
#       'aws cloud architectures',
#       'aws technologies',
#       'aws big data',
#       'aws platform',
#       'aws solutions architect',
#       'cloud/aws',
#       'aws data & ai',
#       'aws storage s3',
#       'cloud - aws',
#       'aws platforms',
#       'aws storage',
#       'aws cloud storage',
#       'aws administration',
#       'aws cloud operations',
#       'aws development',
#       'aws cloud management',
#       'aws elastic compute service',
#       'cloud platforms (aws/azure)',
#       '" cloud services (aws',
#       'cloud (aws/azure)',
#       'aws-eks'],
#      'licenses_or_certifications': [],
#      'licenses_or_certifications_synonyms': [],
#      'associates_degree_requirement': 'Not Mentioned',
#      'associates_degree_fields_of_study': [],
#      'bachelors_degree_requirement': 'Required',
#      'bachelors_degree_fields_of_study': [],
#      'masters_degree_requirement': 'Required',
#      'masters_degree_fields_of_study': ['Statistics',
#       'Data Science',
#       'Mathematics',
#       'Physics',
#       'Econometrics',
#       'Operations Research'],
#      'doctorate_degree_requirement': 'Not Mentioned',
#      'doctorate_degree_fields_of_study': [],
#      'licenses_or_certifications_not_mentioned': True,
#      'min_industry_and_role_yoe': 4,
#      '401k_matching': False,
#      'is_min_industry_and_role_yoe_not_mentioned': False,
#      'min_management_and_leadership_yoe': None,
#      'is_min_management_and_leadership_yoe_not_mentioned': True,
#      'job_category': 'Data and Analytics',
#      'role_activities': ['Collaborate Across Teams',
#       'Lead Advanced Analytics',
#       'Causal Inference Expertise'],
#      'commitment': ['Full Time'],
#      'role_type': 'Individual Contributor',
#      'seniority_level': 'Senior Level',
#      'workplace_countries': ['US'],
#      'boundless_workplace_states': [],
#      'boundless_workplace_countries': [],
#      'boundless_workplace_continents': [],
#      'workplace_continents': ['North America'],
#      'workplace_states': ['Massachusetts, US'],
#      'workplace_cities': ['Boston, Massachusetts, US'],
#      'workplace_counties': ['Suffolk County, Massachusetts, US'],
#      'workplace_type': 'Hybrid',
#      'workplace_physical_environment': 'Office',
#      'oral_communication_level': 'High',
#      'physical_labor_intensity': 'Low',
#      'physical_position': 'Sitting',
#      'computer_usage': 'High',
#      'cognitive_demand': 'High',
#      'air_travel_requirement': 'None',
#      'land_travel_requirement': 'None',
#      'morning_shift_work': 'Not Indicated',
#      'evening_shift_work': 'Not Indicated',
#      'overnight_work': 'Not Indicated',
#      'formatted_workplace_location': 'Boston, Massachusetts, United States',
#      'on_call_requirement': 'None',
#      'weekend_availability_required': False,
#      'holiday_availability_required': False,
#      'generous_paid_time_off': False,
#      'four_day_work_week': False,
#      'overtime_required': False,
#      'is_workplace_worldwide_ok': False,
#      'language_requirements': ['English'],
#      'num_language_requirements': 1,
#      'number_of_workplace_cities': 1,
#      'number_of_workplace_counties': 1,
#      'number_of_workplace_states': 1,
#      'number_of_workplace_countries': 1,
#      'number_of_workplace_continents': 1,
#      'yearly_max_compensation': 213200,
#      'yearly_min_compensation': 142100,
#      'monthly_max_compensation': 17766.666666666668,
#      'monthly_min_compensation': 11841.666666666666,
#      'weekly_max_compensation': 4100,
#      'weekly_min_compensation': 2732.6923076923076,
#      'hourly_max_compensation': 102.5,
#      'hourly_min_compensation': 68.3173076923077,
#      'bi-weekly_min_compensation': 5465.384615384615,
#      'bi-weekly_max_compensation': 8200,
#      'daily_min_compensation': 546.5384615384615,
#      'daily_max_compensation': 820,
#      'estimated_publish_date': '2025-09-28T15:29:43.706Z',
#      'estimated_publish_date_millis': 1759073383706,
#      'fair_chance': False,
#      'visa_sponsorship': False,
#      'relocation_assistance': False,
#      'military_veterans': False,
#      'tuition_reimbursement': False,
#      'retirement_plan': False,
#      'generous_parental_leave': False,
#      'is_high_school_required': True,
#      'is_driver_license_required': False,
#      'is_compensation_transparent': True,
#      'listed_compensation_currency': 'USD',
#      'listed_compensation_frequency': 'Yearly',
#      'security_clearance': 'None',
#      'position_employer_type': 'External Position',
#      'company_name': 'VibrantM',
#      'company_website': 'vibrantm.com',
#      'company_sector_and_industry': 'Healthcare',
#      'company_activities': ['Healthcare', 'Information Technology'],
#      'company_tagline': 'Global healthcare company focused on medicines and devices.',
#      'associates_degree_fields_of_study_synonyms': [],
#      'bachelors_degree_fields_of_study_synonyms': [],
#      'masters_degree_fields_of_study_synonyms': ['statistics',
#       'biostatistics',
#       'applied statistics',
#       'statistical analysis',
#       'advanced statistics',
#       'education statistics',
#       'economic statistics',
#       'computational statistics',
#       'data statistical analysis',
#       'social statistics',
#       'medical statistics',
#       'statistical programming',
#       'business statistics',
#       'measurement and statistics',
#       'industrial statistics',
#       'statistical analyses',
#       'mathematical statistics',
#       'statistical field',
#       'applied stats',
#       'statistical data analysis',
#       'mathematics and statistics',
#       'statistical',
#       'statistical sciences',
#       'bio-statistics',
#       'social science with statistical methods',
#       'statistics for development',
#       'data science',
#       'data analytics',
#       'data management',
#       'data/information science',
#       'data engineering',
#       'data',
#       'data & ai',
#       'data analysis',
#       'data/systems',
#       'data sciences',
#       'data science/analysis',
#       'big data',
#       'data and analytics',
#       'data visualization',
#       'data/computer science',
#       'big data technology',
#       'data strategy',
#       'applied data analytics',
#       'data science/analytics',
#       'environmental data science',
#       'data & analytics',
#       'data analytics engineering',
#       'information/data science',
#       'data decisioning',
#       'data development',
#       'data solutioning',
#       'big data analytics',
#       'data analytic',
#       'data/analytics',
#       'data/modeling science',
#       'mathematics/data science',
#       'data processing/analytics/science',
#       'data design',
#       'data expertise',
#       'large data analysis',
#       'computer/data sciences',
#       'data/analytics/security',
#       'mathematics',
#       'math',
#       'computational math',
#       'applied mathematics',
#       'math education',
#       'mathematics education',
#       'history of math',
#       'computational mathematics',
#       'applied math',
#       'financial mathematics',
#       'mathematical',
#       'maths',
#       'mathematical sciences',
#       'advanced mathematics',
#       'math sciences',
#       'business mathematics',
#       'engineering mathematics',
#       'mathematical science',
#       'mathematical economics',
#       'theoretical math',
#       'mathematics with concentration in computer science',
#       'math/science',
#       'mathematics engineering',
#       'mathematical engineering',
#       'applied maths',
#       'business math',
#       'physics',
#       'applied physics',
#       'physical sciences',
#       'physical science',
#       'chemical physics',
#       'theoretical physics',
#       'engineering physics',
#       'experimental physics',
#       'modern physics',
#       'computational physics',
#       'technical physics',
#       'condensed matter physics',
#       'physics-chemistry',
#       'particle physics',
#       'nuclear physics',
#       'solid state physics',
#       'physics education',
#       'numerical physics',
#       'physics engineering',
#       'astrophysics',
#       'electro physics',
#       'space physics',
#       'electro-physics',
#       'quantum physics',
#       'plasma physics',
#       'materials physics',
#       'material physics',
#       'econometrics',
#       'economics',
#       'quantitative economics',
#       'applied econometrics',
#       'financial econometrics',
#       'econometry',
#       'economic-statistical',
#       'economic modeling',
#       'operations research',
#       'operations management',
#       'operations',
#       'operational research',
#       'operational research/analysis',
#       'operation research',
#       'operations planning',
#       'operations management/research'],
#      'doctorate_degree_fields_of_study_synonyms': [],
#      'company_activities_synonyms': ['healthcare',
#       'healthcare technology',
#       'healthcare solutions',
#       'health technology',
#       'healthcare administration',
#       'healthcare services',
#       'health services',
#       'healthcare marketing',
#       'healthtech',
#       'healthcare software',
#       'healthcare clinics',
#       'healthcare innovation',
#       'healthcare benefits',
#       'healthcare it',
#       'healthcare education',
#       'healthcare communication',
#       'health care',
#       'online healthcare',
#       'medical services',
#       'providing healthcare',
#       'providing health services',
#       'providing healthcare services',
#       'providing health care',
#       'health care services',
#       'health care policy',
#       'health care support',
#       'providing health care services',
#       'healthcare support',
#       'providing medical services',
#       'operating healthcare facilities',
#       'public health care',
#       'healthcare planning',
#       'health care management',
#       'health policy',
#       'supporting health care',
#       'healthcare financing',
#       'health data',
#       'healthcare data',
#       'healthcare data management',
#       'transforming healthcare',
#       'healthcare improvement',
#       'healthcare expertise',
#       'medical care',
#       'healthcare research',
#       'healthcare products',
#       'healthcare management',
#       'healthcare consulting',
#       'healthcare communications',
#       'healthcare delivery',
#       'business development in healthcare',
#       'healthcare engagement',
#       'healthcare provider',
#       'healthcare marketplace',
#       'healthcare advertising',
#       'healthcare intelligence',
#       'providing healthcare solutions',
#       'improving healthcare',
#       'healthcare building',
#       'healthcare access',
#       'healthcare provision',
#       'healthcare innovations',
#       'health information',
#       'healthcare guidance',
#       'healthcare startup',
#       'healthcare collaboration',
#       'healthcare leadership',
#       'healthcare platform',
#       'healthcare software solutions',
#       'healthcare consultancy',
#       'healthcare technology solutions',
#       'healthcare interventions',
#       'healthcare practice',
#       'multi-specialty healthcare',
#       'healthcare plans',
#       'improving health care',
#       'health care access',
#       'healthcare operations',
#       'providing health',
#       'health',
#       'healthcare infrastructure',
#       'healthcare sales',
#       'health systems',
#       'healthcare insights',
#       'healthcare partnerships',
#       'healthcare system',
#       'hospital',
#       'integrated healthcare',
#       'senior healthcare',
#       'providing comprehensive healthcare',
#       'supporting healthcare providers',
#       'health system',
#       'community healthcare',
#       'healthcare assistance',
#       'healthcare systems',
#       'healthcare facility',
#       'health care systems',
#       'health care system',
#       'hospital care',
#       'healthcare organization',
#       'healthcare support services',
#       'healthcare coverage',
#       'healthcare strategy',
#       'offering health services',
#       'delivering healthcare services',
#       'integrated healthcare provider',
#       'nonprofit healthcare',
#       'hospitals',
#       'providing integrated healthcare services',
#       'health care provision',
#       'delivering healthcare solutions',
#       'healthcare recovery',
#       'healthcare network',
#       'healthcare facilities',
#       'managing healthcare services',
#       'supporting healthcare organizations',
#       'health care solutions',
#       'healthcare promotion',
#       'healthcare programs',
#       'health care network',
#       'providing healthcare products and services',
#       'managing health care',
#       'health care delivery',
#       'health system services',
#       'health care organization',
#       'providing health-care services',
#       'health care administration',
#       'healthcare association',
#       'health organization',
#       'retail healthcare',
#       'healthcare retail',
#       'healthcare distribution',
#       'healthcare representation',
#       'providing health-related services',
#       'offering healthcare solutions',
#       'patient-focused healthcare',
#       'medical care services',
#       'integrated health care',
#       'providing integrated healthcare',
#       'healthcare transactions',
#       'providing specialized healthcare',
#       'providing specialized health care',
#       'specialized healthcare',
#       'specialized health care',
#       'healthcare service',
#       'providing healthcare professionals',
#       'offering healthcare support',
#       'healthcare engineering',
#       'health care professionals',
#       'healthcare evaluation',
#       'health care team',
#       'health care consulting',
#       'delivering healthcare',
#       'medical',
#       'healthcare advisory',
#       'healthcare safety',
#       'health care technology',
#       'healthcare information',
#       'healthcare solution',
#       'direct healthcare services',
#       'developing healthcare products',
#       'creating healthcare solutions',
#       'healthcare supply',
#       'healthcare equipment',
#       'health facilities',
#       'integrating healthcare services',
#       'offering health-related services',
#       'offering healthcare services',
#       'providing healthcare support',
#       'healthcare center',
#       'non-profit healthcare services',
#       'health-related services',
#       'medical healthcare services',
#       'services for healthcare providers',
#       'providing medical health services',
#       'primary healthcare',
#       'healthcare community',
#       'healthcare contracting',
#       'outpatient healthcare',
#       'healthcare reporting',
#       'supporting healthcare initiatives',
#       'providing healthcare access',
#       'processing healthcare services',
#       'government healthcare',
#       'healthcare agency',
#       'specialized healthcare services',
#       'healthcare group',
#       'providing comprehensive healthcare services',
#       'health care education',
#       'healthcare clinic',
#       'comprehensive healthcare services',
#       'health facility',
#       'healthcare oversight',
#       'health operations',
#       'healthcare management services',
#       'e-commerce healthcare services',
#       'health and wellness care',
#       'healthcare analysis',
#       'offering health care',
#       'supporting health care services',
#       'offering various healthcare services',
#       'supporting healthcare operations',
#       'supporting healthcare services',
#       'supporting healthcare',
#       'offering health care services',
#       'conducting healthcare programs',
#       'advancing healthcare',
#       'healthcare provider management',
#       'healthcare applications',
#       'family healthcare',
#       'healthcare maintenance',
#       'health care programs',
#       'health service',
#       'manufacturing healthcare products',
#       'providing health care solutions',
#       'health care facilities',
#       'healthcare implementation',
#       'health care research',
#       'healthcare policy',
#       'providing quality healthcare',
#       'health care products',
#       'healthcare outreach',
#       'healthcare supervision',
#       'healthcare practices',
#       'healthcare it services',
#       'healthcare facility services',
#       'healthcare manufacturing',
#       'healthcare division',
#       'delivering healthcare support',
#       'healthcare and medical',
#       'quality healthcare services',
#       'patient healthcare services',
#       'therapeutic healthcare services',
#       'health care infrastructure',
#       'providing healthcare products',
#       'healthcare technologies',
#       'supporting healthcare programs',
#       'developing healthcare solutions',
#       'providing personal healthcare',
#       'healthcare service management',
#       'healthcare business support',
#       'healthcare professional services',
#       'implementing healthcare services',
#       'healthcare system management',
#       'delivering health care',
#       'healthcare outcomes',
#       'healthcare and research',
#       'research and healthcare services',
#       'healthcare products distribution',
#       'health care guidance',
#       'independent healthcare',
#       'retail health care',
#       'health company',
#       'delivering healthcare products',
#       'offering a range of healthcare services',
#       'health and medical',
#       'health & medical',
#       'healthcare financial services',
#       'healthcare collaborations',
#       'healthcare product supply',
#       'healthcare partnership',
#       'private healthcare',
#       'providing advanced healthcare',
#       'producing healthcare products',
#       'healthcare careers',
#       'healthcare technology development',
#       'consumer health care',
#       'healthcare business',
#       'quality healthcare',
#       'innovations in healthcare',
#       'improving healthcare solutions',
#       'healthcare treatments',
#       'providing healthcare technology',
#       'health care retail',
#       'non-profit healthcare',
#       'healthcare initiatives',
#       'healthcare contributions',
#       'developing healthcare programs',
#       'healthcare technology services',
#       'multidisciplinary healthcare',
#       'healthcare investment',
#       'medical activities',
#       'healthcare savings',
#       'providing specialized healthcare services',
#       'information technology',
#       'technology services',
#       'providing it services',
#       'it services',
#       'it company',
#       'information technology management',
#       'information technology services',
#       'information services',
#       'information technology support',
#       'information systems',
#       'information technology solutions',
#       'it management',
#       'data technology',
#       'information technology consulting',
#       'internet technology',
#       'it and tech services',
#       'it systems',
#       'information system management',
#       'it products',
#       'providing information technology solutions',
#       'managing information technology systems',
#       'it service',
#       'supporting information technology',
#       'information technology operations',
#       'information technology instruction',
#       'global information technology',
#       'information technology infrastructure',
#       'it industry',
#       'information technology architecture',
#       'information technologies',
#       'information technology outsourcing',
#       'information and communication technology']},
#     'v5_processed_company_data': {'name': 'Merck',
#      'image_url': 'https://kg.diffbot.com/image/api/get?fetch=yes&urls=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FFvup%3Eq%5D3%5Cbi_%3DDe7DV9G6o6e%3A.W8J,g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FGvvn%3ErS%3EPn%7BEbB%3B7y%40.pGT',
#      'subsidiaries': ['Merck',
#       'Versum Materials',
#       'Merck Serono',
#       'Seven Seas',
#       'AZ Electronic Materials',
#       'Merck India',
#       'Merck Chemicals',
#       'Merck (United Kingdom)',
#       'Merck SL'],
#      'parent_company': None,
#      'website': 'merckgroup.com',
#      'linkedin_url': None,
#      'industries': ['Biotechnology Companies',
#       'Medical Organizations',
#       'Pharmaceutical Companies',
#       'Health Care Companies'],
#      'activities': ['pharmaceutical industry',
#       'chemical industry',
#       'pharmaceutical company',
#       'enterprise',
#       'manufacture of pharmaceutical preparations',
#       'management of companies and enterprises',
#       'pharmaceutical manufacturing',
#       'pharmaceutical laboratories'],
#      'tagline': "The Merck Group, branded and commonly known as Merck, is a German multinational science and technology company headquartered in Darmstadt, with about 60,000 employees and a presence in 66 countries. The group includes around 250 companies; the main company is Merck KGaA in Germany. The company is divided into three business lines: Healthcare, Life Sciences and Electronics. Merck was founded in 1668 and is the world's oldest operating chemical and pharmaceutical company, as well as one of the largest pharmaceutical companies globally.",
#      'is_non_profit': False,
#      'is_public_company': True,
#      'is_dissolved': False,
#      'is_acquired': False,
#      'num_employees': 57580,
#      'year_founded': 1850,
#      'headquarters_country': 'Germany',
#      'total_funding_amount': None,
#      'total_funding_currency': None,
#      'latest_investment_amount': None,
#      'latest_investment_currency': None,
#      'latest_investment_year': None,
#      'latest_investment_series': None,
#      'investors': [],
#      'stock_exchange': 'Frankfurt Stock Exchange (FSX)',
#      'stock_symbol': 'MRK',
#      'latest_revenue': 17534000000,
#      'latest_revenue_currency': 'EUR',
#      'latest_revenue_year': 2020},
#     '_geoloc': [{'lat': 42.3601, 'lon': -71.0589}],
#     'requisition_id': 'kbu3hmc6a47mojfe',
#     'collapse_key': 'ba56c724d1458c8e691ba36a02814ea7feb821a4bfff456d03d524011a2a05b8',
#     'is_expired': False,
#     'v7_processed_job_data': {'estimated_post_date': '2025-09-28T15:29:43.706Z',
#      'schedule_requirements': {'shifts': {'on_call_requirement': 'None',
#        'holiday_availability_required': False,
#        'weekend_availability_required': False,
#        'overtime_required': False,
#        'shift_types_available': []},
#       'travel': {'land_travel_requirement': 'None',
#        'air_travel_requirement': 'None'}},
#      'embedding_text_explicit': 'Job Title: Lead Data Scientist, Senior Data Scientist - Commercial Analytics, Data Science Lead, Head of Data Science - Commercial. Skills: Python, Py, Python (pandas, scikit-learn), SQL, SQL Queries, Git, GitHub, Version Control, Linux, Unix, AWS, Amazon Web Services, Healthcare data, Claims Data, EMR Data, Electronic Medical Records, Supervised learning, Unsupervised learning, Causal inference, ML pipelines, Machine Learning Pipelines, Feature engineering, Model deployment, Production ML, Containerization, Containers, Docker, Kubernetes, Big data, GenAI tools, Generative AI, GenAI. Majors: Statistics, Data Science, Mathematics, Physics, Econometrics, Operations Research',
#      'education': {'explicit': [{'fields_of_study': ['Statistics',
#          'Data Science',
#          'Mathematics',
#          'Physics',
#          'Econometrics',
#          'Operations Research'],
#         'degree_type': 'Masters',
#         'requirement': 'Required'}],
#       'inferred': [{'fields_of_study': ['Data Science', 'Statistics'],
#         'degree_type': 'Masters'},
#        {'fields_of_study': ['Applied Mathematics', 'Machine Learning'],
#         'degree_type': 'Masters'},
#        {'fields_of_study': ['Business Analytics'], 'degree_type': 'Masters'}]},
#      'work_arrangement': {'workplace_type': 'Hybrid',
#       'individual_contributor_or_people_manager': 'Individual Contributor',
#       'commitment': ['Full Time'],
#       'workplace_locations': [{'continent': 'North America',
#         'country_code': 'US',
#         'city': 'Boston',
#         'kind': 'city',
#         'county': 'Suffolk County',
#         'geographic_coordinates': {'lon': -71.0589, 'lat': 42.3601},
#         'state': 'Massachusetts'}]},
#      'original_job_description_language': 'en',
#      'credentials': {'explicit': [], 'inferred': []},
#      'diversity_hiring': {'military_veterans': False, 'fair_chance': False},
#      'embedding_inferred_vector': [0.012708475,
#       0.021609815,
#       0.053992093,
#       -0.052348103,
#       -0.024443535,
#       0.022561599,
#       -0.0035069983,
#       -0.014428175,
#       0.007792729,
#       -0.012221768,
#       0.020582322,
#       -0.052304838,
#       -0.040083073,
#       0.026087524,
#       0.023729697,
#       0.053343147,
#       -0.015163644,
#       0.0048346287,
#       0.018246125,
#       0.06372625,
#       0.01927362,
#       0.027147466,
#       0.01411452,
#       0.01927362,
#       0.04845444,
#       -0.009755783,
#       -0.028575141,
#       0.011140196,
#       0.022886071,
#       0.025676528,
#       0.012686844,
#       -0.019868484,
#       -0.032057803,
#       0.021836946,
#       0.032728378,
#       -0.002974324,
#       0.0052294023,
#       -0.026649943,
#       -0.0011829698,
#       -0.012384003,
#       5.1332438e-05,
#       -0.016537242,
#       0.024638219,
#       0.077527106,
#       0.007019405,
#       -0.033723425,
#       -0.021425948,
#       -0.06389929,
#       0.01848407,
#       0.039845124,
#       -0.0012012213,
#       -0.03605962,
#       0.009112247,
#       0.029418768,
#       0.012557055,
#       0.012005453,
#       0.0466374,
#       0.012751739,
#       -0.00877696,
#       -0.034026265,
#       0.0294404,
#       0.030457078,
#       0.021934288,
#       0.03335569,
#       0.00033393546,
#       -0.026585048,
#       -0.030716656,
#       -0.0053402637,
#       -0.03662204,
#       -0.034134425,
#       0.015325881,
#       -0.010366871,
#       0.027428675,
#       0.020885162,
#       -0.0026011816,
#       -0.037119564,
#       -0.032252487,
#       0.006694933,
#       -0.051742423,
#       -0.026736468,
#       -0.020225404,
#       0.020950057,
#       0.045642354,
#       -0.0075277435,
#       0.00014643476,
#       -0.01818123,
#       0.025698159,
#       -0.064851075,
#       -0.025200635,
#       -0.039239444,
#       0.0026728357,
#       -0.01509875,
#       -0.017034765,
#       -0.011248353,
#       -0.004304658,
#       0.029245716,
#       0.010967144,
#       -0.009171734,
#       -0.0546843,
#       0.040147968,
#       -0.031170916,
#       -0.009014905,
#       0.040277753,
#       -0.0037260167,
#       0.013541286,
#       -0.0010464212,
#       -0.044906884,
#       -0.064980865,
#       0.026779732,
#       0.035994727,
#       -0.069307156,
#       0.011324063,
#       -0.009669257,
#       -0.017618814,
#       -0.048324652,
#       -0.024768006,
#       -0.015964009,
#       -0.013195183,
#       -0.016493978,
#       -0.022020813,
#       0.0056998865,
#       0.059097115,
#       0.014676937,
#       -0.06783622,
#       -0.015455669,
#       0.014092888,
#       0.010729197,
#       -0.06861495,
#       0.03004608,
#       -0.014839172,
#       0.0006891644,
#       0.00930693,
#       0.009014905,
#       -0.04205153,
#       0.007554783,
#       -0.062125515,
#       -0.0095719155,
#       -0.009150102,
#       -0.05706376,
#       -0.01863549,
#       0.01734842,
#       0.026714837,
#       -0.014601227,
#       0.05035801,
#       -0.015509748,
#       -0.023859486,
#       0.007717019,
#       0.035194363,
#       -0.005113133,
#       0.006808498,
#       -0.014330834,
#       0.012200136,
#       -0.057323337,
#       0.00414783,
#       0.0317117,
#       -0.007987412,
#       0.010680527,
#       0.019684616,
#       -0.013195183,
#       -0.049882118,
#       0.034891523,
#       0.009766598,
#       0.002425426,
#       0.045815405,
#       -0.03391811,
#       -0.010902249,
#       -0.0015371847,
#       0.0156828,
#       -0.012816632,
#       -0.035172734,
#       -0.034329105,
#       -0.042570688,
#       0.022799546,
#       -0.0057377415,
#       0.050184958,
#       -0.010994183,
#       0.007381731,
#       0.0036827538,
#       0.007695387,
#       0.012643581,
#       -0.044171415,
#       -0.003671938,
#       -0.016385822,
#       -0.01674274,
#       0.010356056,
#       0.009945058,
#       -0.006073029,
#       0.007754874,
#       0.0061271074,
#       0.007381731,
#       0.007019405,
#       0.026974415,
#       0.04174869,
#       0.011518746,
#       -0.006657078,
#       0.012091979,
#       0.0018711202,
#       0.0004806237,
#       0.025827948,
#       0.012167689,
#       0.008155055,
#       -0.028142512,
#       0.006840945,
#       0.029548557,
#       -0.014006362,
#       0.0164399,
#       0.0016683254,
#       0.016093796,
#       -0.035367414,
#       -0.04754592,
#       0.027774777,
#       -0.010155965,
#       0.006770643,
#       0.05442472,
#       -0.045642354,
#       -0.018992411,
#       -0.02468148,
#       -0.04006144,
#       0.0164399,
#       0.034913156,
#       -0.031884752,
#       0.037119564,
#       -0.035994727,
#       -0.01479591,
#       -0.024097431,
#       0.0017359236,
#       0.01016678,
#       -0.01249216,
#       0.012135242,
#       -0.01876528,
#       -0.00938264,
#       -0.02931061,
#       -0.0036530106,
#       0.011048262,
#       -0.06402908,
#       -0.03993165,
#       -0.04784876,
#       0.03573515,
#       0.03718446,
#       -0.030262394,
#       -0.0006002727,
#       0.032295752,
#       0.03679509,
#       0.019836036,
#       0.025005953,
#       0.000625622,
#       0.03688162,
#       -0.054381456,
#       -0.0040450804,
#       0.014849989,
#       0.04066712,
#       -0.0313656,
#       0.016580503,
#       -0.02855351,
#       -0.019554827,
#       -0.034805,
#       -0.020041537,
#       -0.008885117,
#       -0.030305658,
#       0.024140695,
#       -0.020755373,
#       0.035929833,
#       0.005553874,
#       -0.02172879,
#       -0.05511693,
#       0.013638628,
#       0.06662486,
#       -0.026109157,
#       -0.017445762,
#       -0.05217505,
#       -0.023361962,
#       0.012827449,
#       -0.0067868666,
#       0.0026052373,
#       -0.065802865,
#       -0.027688252,
#       0.025200635,
#       -0.014849989,
#       0.030435447,
#       -0.03657878,
#       0.007781913,
#       -0.023124017,
#       0.026714837,
#       -0.020257851,
#       -0.042376004,
#       0.018927516,
#       -0.008760736,
#       -0.05676092,
#       -0.046421085,
#       0.02838046,
#       0.0043695522,
#       -0.07817605,
#       -0.0013289821,
#       -0.08232929,
#       -0.012254215,
#       -0.0041992045,
#       0.058231857,
#       0.03376669,
#       -0.030889707,
#       -0.033853214,
#       0.02736378,
#       -0.0064353556,
#       -0.016342558,
#       -0.009025721,
#       0.025698159,
#       -0.0022442627,
#       -0.019468302,
#       -0.039239444,
#       -0.007754874,
#       -0.049536012,
#       0.00070504996,
#       -0.011269984,
#       0.06299078,
# ...
#       0.034322012,
#       -0.029751899,
#       0.01720717,
#       -0.0111598475,
#       -0.009319107,
#       0.010929034,
#       -0.023289112,
#       0.043716136,
#       -0.023496846,
#       -0.016641675,
#       -0.02725911,
#       0.0007126376,
#       0.00652049,
#       -0.044916365,
#       -0.026174286,
#       -0.003291982,
#       0.024327775,
#       0.047086015,
#       -0.021211788,
#       -0.01920371,
#       0.035845384,
#       0.0020210634,
#       -0.0017368739,
#       0.022677457,
#       -0.0100634815,
#       0.0033958482,
#       -0.0547952,
#       0.02003464,
#       0.040923286,
#       0.018638214,
#       -0.027120622,
#       0.021304114,
#       -0.018453564,
#       -0.025781902,
#       -0.057611126,
#       0.00016661872,
#       -0.013848828,
#       -0.010398162,
#       0.014922112,
#       -0.0011951828,
#       0.010317377,
#       0.0039036386,
#       -0.040438578,
#       -0.02790539,
#       -0.0039036386,
#       0.041892707,
#       -0.030744398,
#       -0.07201391,
#       -0.050271247,
#       -0.024166206,
#       0.008626666,
#       0.01953839,
#       0.002088865,
#       -0.019388359,
#       -0.0019821136,
#       0.0034131592,
#       -0.027420681,
#       0.04161573,
#       -0.054425895,
#       -0.00076601334,
#       -0.00065854064,
#       0.011679178,
#       -0.027351435,
#       -0.022331236,
#       0.015372199,
#       -0.006116566,
#       -0.040600147,
#       -0.076214716,
#       -0.011788815,
#       0.006070403,
#       -0.080461696,
#       0.003162149,
#       -0.0431391,
#       0.0042094667,
#       -0.009601855,
#       0.017588012,
#       0.042723637,
#       0.007888062,
#       -0.006589734,
#       0.03023661,
#       0.0054962537,
#       -0.02760533,
#       -0.029821144,
#       0.031067539,
#       -0.016445484,
#       -0.016341617,
#       -0.028851725,
#       0.0057790005,
#       -0.03762265,
#       -0.031182945,
#       -0.0012103299,
#       0.0547952,
#       -0.03796887,
#       -0.041754216,
#       -0.007755344,
#       -0.00035505655,
#       -0.00802078,
#       0.009099835,
#       -0.03279864,
#       -0.038730558,
#       -0.015164467,
#       0.038592067,
#       -0.05668787,
#       -0.03789963,
#       -0.005138492,
#       -0.011673409,
#       0.037507243,
#       0.0051413774,
#       -0.08235437,
#       0.026658995,
#       0.007818818,
#       -0.006099255,
#       -0.021050218,
#       0.010317377,
#       0.015256792,
#       -0.026797483,
#       0.03494521,
#       -0.0061454177,
#       -0.019619174,
#       -0.047686134,
#       -0.020888649,
#       -0.03540684,
#       -0.027351435,
#       0.018291995,
#       0.046347413,
#       0.01086556,
#       0.038938288,
#       -0.0033323744,
#       -0.02559725,
#       -0.037991952,
#       -0.021534927,
#       -0.03145992,
#       0.050455898,
#       -0.046670552,
#       -0.014171967,
#       -0.008805547,
#       -0.042169683,
#       0.019976934,
#       -0.037161022,
#       -0.030421259,
#       0.0045585725,
#       -0.0023716118,
#       0.0062146615,
#       0.009434515,
#       0.017645715,
#       -0.08313913,
#       -0.064443216,
#       0.040669393,
#       -0.005314488,
#       0.034160443,
#       -0.03323719,
#       -0.020196209,
#       -0.022088882,
#       -0.030028876,
#       -0.023046758,
#       -0.008568962,
#       0.008084253,
#       -0.020715538,
#       0.024789402,
#       0.004694176,
#       0.05004043,
#       -0.019446064,
#       -0.032867886,
#       -0.011084833,
#       0.045885783,
#       -0.012406242,
#       0.010432784,
#       -0.018384319,
#       -0.023658415,
#       -0.00037615438,
#       -0.0097057205,
#       0.024650915,
#       0.043946948,
#       0.0015680913,
#       0.003678595,
#       0.05618008,
#       0.011234862,
#       0.020011557,
#       0.020957893,
#       -0.034529746,
#       -0.01788807,
#       0.009244093,
#       -0.02760533,
#       0.03145992,
#       0.030213527,
#       0.0014151771,
#       0.015568391,
#       -0.022388939,
#       -0.043508403,
#       0.022492805,
#       -0.020150045,
#       0.029844224,
#       -0.008886332,
#       0.0061800396,
#       0.0025057723,
#       0.008251593,
#       0.049671132,
#       -0.027720738,
#       0.017484145,
#       0.008961346,
#       -0.022885188,
#       -0.020184668,
#       0.011061751,
#       -0.01703406,
#       0.038869046,
#       0.049671132,
#       -0.041684974,
#       0.0006661142,
#       0.01855743,
#       -0.032844804,
#       0.010323147,
#       0.047501482,
#       -0.020530889,
#       -0.041107938,
#       0.007911143,
#       -0.0013747847,
#       0.005129837,
#       -0.03397579,
#       -0.00935373,
#       -0.01470284,
#       0.018915191,
#       -0.0053895023,
#       0.00468552,
#       -0.050409734,
#       -0.009751883,
#       -0.0041200262,
#       -0.019503767,
#       -0.0013430478,
#       -0.023000596,
#       0.03379114,
#       -0.00094128755,
#       -0.017611094,
#       0.020138504,
#       -0.041384917,
#       -0.029128702,
#       0.031136783,
#       -0.010963656,
#       0.017253332,
#       0.040369336,
#       0.00493076,
#       0.03312178,
#       -0.003410274,
#       0.038730558,
#       -0.03344492,
#       -0.0072129313,
#       0.009047901,
#       -0.015510688,
#       0.012360079,
#       -0.0041344524,
#       0.03741492,
#       0.0068667107,
#       0.006035781,
#       0.02460475,
#       0.0040046195,
#       0.015129845,
#       -0.00015868449,
#       -0.023439143,
#       0.016433943,
#       0.045908865,
#       0.001454127,
#       0.02407388,
#       -0.027005216,
#       0.04879404,
#       -0.002684653,
#       -0.03579922,
#       -0.022504346,
#       0.017576471,
#       -0.00040825192,
#       0.0170456,
#       -0.016295455,
#       -0.01387191,
#       0.07058286,
#       -0.010005779,
#       -0.019319115,
#       0.048701715,
#       -0.017010977,
#       0.014472025,
#       -0.036560908,
#       -0.01870746,
#       0.0645817,
#       -0.04145416,
#       0.022169666,
#       0.030582828,
#       0.0184074,
#       -0.0155568505,
#       -0.02543568,
#       0.048701715,
#       -0.023796903,
#       0.01739182,
#       0.022608213,
#       0.03639934,
#       -0.001990769,
#       -0.013283335,
#       0.0151875485,
#       0.009451825,
#       -0.027974633,
#       0.023935392,
#       -0.010779005,
#       0.0035718437,
#       -0.0064570163,
#       -0.01036931,
#       -0.01886903,
#       0.024466263,
#       -0.027536087,
#       -0.049763456,
#       -0.039099857,
#       -0.037161022,
#       0.03762265,
#       -0.03914602,
#       0.0100634815,
#       0.021269493,
#       -0.008972887,
#       0.0008641092,
#       -0.030790562,
#       -0.0046884054,
#       0.021696499,
#       -0.04496253,
#       -0.052717872,
#       0.01787653,
#       0.0040046195,
#       0.05031741,
#       0.008297756,
#       0.032983292,
#       -0.011933073,
#       0.005383732,
#       0.002120602,
#       -0.022712078,
#       -0.0063069873,
#       0.03939992,
#       0.060242403,
#       -0.061950427,
#       0.022481265,
#       0.011027129,
#       0.0034477813,
#       0.015406822,
#       -0.03226777,
#       -0.023289112,
#       -0.006035781,
#       -0.012787085,
#       0.058395892,
#       -0.026520506,
#       0.009469137,
#       0.01973458,
#       -0.0063762316,
#       0.0264051,
#       0.009630706,
#       -0.05848822,
#       -0.016468566,
#       -0.02977498,
#       -0.0068955626,
#       -0.006803237,
#       -0.029174864,
#       -0.010525109,
#       0.022781322,
#       0.019953854,
#       0.0030727088,
#       -0.0144374035,
#       0.027651494,
#       -0.0039411457,
#       -0.022423562,
#       -0.042100437,
#       -0.014968275,
#       0.010911723,
#       -0.01653781,
#       -0.0033554556,
#       0.006785926,
#       0.046093516,
#       0.0129832765,
#       0.021627253,
#       0.010259674,
#       -0.041246425,
#       -0.00246538,
#       -0.0058367043,
#       0.0075880038,
#       -0.008811317,
#       0.0006798188,
#       -0.03928451,
#       -0.015418362,
#       -0.008707451,
#       0.0122677535,
#       -0.025135623,
#       0.016260833,
#       -0.0006899169,
#       -0.02525103,
#       0.01886903,
#       0.022273533,
#       0.03981538,
#       0.03157533,
#       -0.015314496,
#       -0.0069013326,
#       -0.012498568,
#       -0.0027986174,
#       -0.025643414,
#       0.0028216988,
#       -0.003594925,
#       -0.007738033,
#       -0.01786499,
#       0.022608213,
#       -0.00869014,
#       0.012060021,
#       -0.014506647,
#       0.009659558,
#       0.022919811,
#       0.02559725,
#       -0.018788245,
#       0.010998278,
#       -0.017345658,
#       -0.032867886,
#       -0.009561462,
#       -0.022481265,
#       0.015591472,
#       0.025481844,
#       -0.025504926,
#       0.034160443,
#       -0.02458167,
#       0.009076753,
#       -0.001365408,
#       0.019849988,
#       0.031344514,
#       0.005467402,
#       0.00088646926,
#       -0.0074206637,
#       -0.003594925,
#       0.05004043,
#       -0.011909992,
#       -0.0033208337,
#       0.022388939,
#       -0.02707446,
#       -0.004379692,
#       -0.049347993,
#       -0.00417773,
#       0.015129845,
#       -0.0022475494,
#       -0.0075591523,
#       -0.009659558,
#       0.011090604,
#       -0.032175444,
#       0.016353158,
#       0.004648013,
#       -0.035383757,
#       -0.0032804413,
#       -0.01703406,
#       -0.021177167,
#       0.008753614,
#       0.009117145,
#       0.018326616,
#       0.03296021,
#       0.02827469,
#       0.02207734,
#       -0.061765775,
#       0.0151875485,
#       0.06573577,
#       0.022215828,
#       -0.011817667,
#       -0.046093516,
#       -0.008436245,
#       -0.008620895,
#       0.020519348,
#       0.026543587,
#       0.0033006375,
#       0.015499147,
#       -0.022942891,
#       -0.022769783,
#       0.017691879,
#       -0.020138504,
#       0.03411428,
#       0.033167943,
#       0.041523404,
#       0.004711487,
#       0.028643994,
#       -0.011407972,
#       -0.004786501,
#       -0.02091173,
#       0.020611674,
#       0.007374501,
#       -0.0113502685,
#       0.029174864,
#       0.0011562329,
#       -0.08484715,
#       -0.061627287,
#       0.0028808448,
#       -0.0054298947,
#       -0.0210733,
#       -0.026151204,
#       0.019353738,
#       -0.004497984,
#       0.0028029452,
#       0.034206606,
#       0.007536071,
#       -0.021223329,
#       -0.004215237,
#       -0.018580511,
#       -0.029821144,
#       0.01819967,
#       -0.033214107,
#       0.007795736,
#       -0.0028779597,
#       0.009890372,
#       -0.04482404,
#       -0.035383757,
#       0.005051937,
#       -0.014772084,
#       -0.011794586,
#       0.0012110511,
#       0.01703406,
#       -0.00023802674,
#       0.010888642,
#       -0.0051269517,
#       -0.01856897,
#       0.029890388,
#       -0.0066762893,
#       0.015349118,
#       -0.021465683,
#       0.01639932,
#       -0.01738028,
#       -0.005796312,
#       0.0026803254,
#       -0.0014858638,
#       0.007905372,
#       -0.026220448,
#       -0.050917525,
#       -0.0040709786,
#       -0.0010054826,
#       -0.01736874,
#       -0.02357763,
#       0.018961353,
#       0.025343357,
#       -0.0013567524,
#       -0.03291405,
#       0.01387191,
#       0.006837859,
#       0.02642818,
#       -0.017172547,
#       0.02792847,
#       -0.03863823,
#       0.018176587,
#       -0.025043298,
#       0.0026240645,
#       0.0032660153,
#       0.024120042,
#       0.05821124,
#       0.0048355493,
#       0.05285636,
#       0.0052798656,
#       -0.039838463,
#       0.020657836,
#       0.021673417,
#       -0.010138497,
#       -0.008493948,
#       -0.012579353,
#       -0.024096962,
#       0.03279864,
#       -0.022388939,
#       0.022654375,
#       0.025504926,
#       0.023312194,
#       0.0017556275,
#       -0.035937708,
#       0.036699396,
#       0.043531485,
#       -0.011407972,
#       0.020854028,
#       0.0024466263,
#       -0.040277008,
#       0.026058879,
#       0.025828065,
#       -0.024350857,
#       -0.031690735,
#       -0.013641096,
#       -0.030352015,
#       0.022054259,
#       0.008442015,
#       0.008880561,
#       0.03413736,
#       -0.0043277587,
#       0.053456478,
#       -0.0511945,
#       0.0011288237,
#       0.011356039,
#       -0.012556271,
#       0.051425315,
#       -0.005813623,
#       0.0034218146,
#       0.06605891,
#       0.01388345,
#       -0.042446658,
#       0.044200845,
#       -0.040000033,
#       0.0045037544,
#       0.051009852,
#       -0.015326037,
#       -0.0151760075,
#       0.028690156,
#       -0.018799784,
#       -0.03356033,
#       -0.008759384,
#       0.022354318,
#       -0.006035781,
#       -0.009290256,
#       0.030582828,
#       -0.027305273,
#       -0.01606464,
#       -0.013064061,
#       0.021615712,
#       0.016676297,
#       0.02356609,
#       0.0027120623,
#       -0.03561457,
#       -0.022758242,
#       0.04011544,
#       0.025458762,
#       0.010571272,
#       -0.00011865272,
#       0.0031390677,
#       -0.036030035,
#       -0.014749002,
#       0.022585131,
#       -0.014345078,
#       0.016099263,
#       -0.0011764291,
#       0.004065208,
#       -0.021846527,
#       0.004111371,
#       -0.002590885,
#       -0.017010977,
#       0.009480677,
#       0.019849988,
#       -0.004535491,
#       -0.01889211,
#       -0.002401906,
#       0.03912294,
#       -0.017530309,
#       -0.024858646,
#       -0.00055359246,
#       0.049532644,
#       0.0023023677,
#       0.012960196,
#       0.026451262,
#       0.0048009274,
#       -0.01724179,
#       0.008205431,
#       0.036560908,
#       -0.03457591,
#       0.026497426,
#       -0.02372766,
#       0.0065955045,
#       0.012290835,
#       0.013768043,
#       -0.005487598,
#       0.038268927,
#       -0.03492213,
#       -0.0011656097,
#       0.019249871,
#       0.01320255,
#       -0.010553962,
#       -0.039053697,
#       0.03429893,
#       0.00027932078,
#       -0.032036956,
#       0.00043241523,
#       -0.011690719,
#       -0.002263418,
#       -0.002347088,
#       0.013456445,
#       -0.015949234,
#       0.02559725,
#       0.03764573,
#       -0.012948655,
#       0.023185248,
#       0.024627833,
#       0.0464859,
#       -0.0155568505,
#       -0.02642818,
#       -0.0004313333,
#       0.048701715,
#       -0.014656677,
#       -0.00011171027,
#       0.021638794,
#       -0.02642818,
#       0.02474324,
#       -0.009399892,
#       -0.041223347,
#       -0.022342777,
#       -0.017218709,
#       -0.019596092,
#       -0.0407848,
#       0.007836129,
#       0.041938867,
#       0.008343919,
#       0.015591472,
#       -0.013271794,
#       0.007841899,
#       0.008632436,
#       -0.012440864,
#       0.019930772,
#       -0.0254126,
#       0.014910572,
#       0.016480105,
#       -0.03623777,
#       0.017253332,
#       -0.0104212435,
#       0.010386622,
#       0.021788822,
#       0.023866147,
#       -0.011759964,
#       -0.00836123,
#       -0.027628412,
#       -0.008776695,
#       -0.0023903656,
#       0.042169683,
#       0.030282771,
#       -0.008909413,
#       0.016687838,
#       0.0058424743,
#       0.0028678614,
#       -0.01819967,
#       0.010467406,
#       -0.012060021,
#       -0.006249284,
#       -0.02956725,
#       0.021546468,
#       0.015060601,
#       -0.015406822,
#       0.012163888,
#       -0.0155337695,
#       0.030628992,
#       0.019861529,
#       0.020761702,
#       -0.023254491,
#       0.016849408,
#       -0.019596092,
#       0.027351435,
#       -0.0041431077,
#       -0.049578805,
#       -0.0048355493,
#       0.032867886,
#       0.028228529,
#       0.006589734,
#       -0.03591463,
#       -0.012833248,
#       -0.019353738,
#       -0.020588592,
#       0.01589153,
#       -0.012729381,
#       -0.015429903,
#       0.0008359788,
#       0.018315075,
#       0.006653208,
#       -0.027282191,
#       0.014472025,
#       -0.007005199,
#       0.04498561,
#       0.025089461,
#       -0.00443451,
#       -0.025758822,
#       -0.006099255,
#       -0.0136988,
#       -0.005603005,
#       0.052902523,
#       0.038038116,
#       0.03307562,
#       0.03944608,
#       0.00401616,
#       0.0030957903,
#       -0.0048355493,
#       -0.007882291,
#       -0.012140806,
#       0.022527426,
#       0.0431391,
#       0.04514718,
#       -0.0027899619,
#       -0.01723025,
#       -0.0070802136,
#       0.022331236,
#       -0.019942313,
#       -0.007986157,
#       -0.009076753,
#       0.046255086,
#       -0.013075602,
#       ...],
#      'experience_requirements': {'min_years_breakdown': {'industry_and_role_yoe': 4,
#        'management_and_leadership_yoe': None},
#       'seniority_level': 'Senior Level',
#       'security_clearance': 'None',
#       'language_requirements': [],
#       'is_driver_license_required': False,
#       'requirements_summary': '4+ years as a data scientist in a commercial setting; pharma experience preferred; strong ML and healthcare data experience.'}},
#     'objectID': 'successfactors___eu___merckgroup___1252210501'},
#    'validThrough': '2025-12-07T07:35:28.009Z'},
#   '__N_SSG': True},
#  'page': '/viewjob/[requisitionId]',
#  'query': {'requisitionId': 'kbu3hmc6a47mojfe'},
#  'buildId': 'wV_Ursx5Dp68WPUTHcLIm',
#  'isFallback': False,
#  'isExperimentalCompile': False,
#  'gsp': True,
#  'scriptLoader': []}

# %%
# # driver = webdriver.Chrome()
# wait = WebDriverWait(driver, 2)
# driver.get(url)
# # scroll_bottom(driver, wait_time=1)
# scroll_bottom(driver, wait_time=2)
# try:
#     wait.until(EC.visibility_of_element_located((By.XPATH, ".//article")))
# except:
#     pass
# # body = wait.until(EC.visibility_of_element_located((By.XPATH, "/body")))
# # outerHTML = body.get_attribute("outerHTML")
# html_source = driver.page_source
# driver.close()
# return html_source

# %%
# P_dict = P_DICT / '.html - Data Engineer (Full-Time, Remote, North Carolina Based).50umz32anguv5vqm.html.pkl'
# P_dict = P_DICT / 'ServiceNow - Machine Learning Engineer.i97q9xrdrj5z8fyv.html.pkl'
# P_dict = P_DICT / 'West Monroe Partners - Senior Architect, Data Engineering.9j42rn5lyt5iedmx.html.pkl'
# P_dict = P_DICT / 'ZOLL Medical - Sr. Full Stack C# Web Engineer.4a4lcct6bduu5ggp.html.pkl'
# P_dict = P_DICT / 'Zoom Video Communications - Senior DevOps Engineer.ei1jvk839tp9jxbx.html.pkl'
# P_dict = P_DICT / 'Zscaler - Staff Business Systems Analyst - Payroll (Dayforce).ypr52oglemuqnfs3.html.pkl'
# P_dict = P_DICT / 'Compass Group Careers - SENIOR DATA ENGINEER (REMOTE) (Chicago, IL, US, REMOTE).btwpoqpu1wic3xxi.html.pkl'
os.path.getsize(P_dict)
# Out:
# 162

# %%
P_dict = P_DICT / 'Pave - Senior Software Engineer - Developer Platform.eqycwz7yximfioga.html.pkl'
os.path.getsize(P_dict)
# Out:
# 5

# %%
com.viewjob('eqycwz7yximfioga')
# Out:
# 'https://hiring.cafe/viewjob/eqycwz7yximfioga'

# %%
com.viewhash('eqycwz7yximfioga')
# {'props': {'pageProps': {}},
#  'page': '/expired',
#  'query': {},
#  'buildId': '6cuzqR8szBSTdjAZfdv53',
#  'nextExport': True,
#  'autoExport': True,
#  'isFallback': False,
#  'scriptLoader': []}
# Out:
# {}

# %%
industries_list = []
_hash_names = list(companies_df.query('ALL')[['hash', 'name']].iterrows())
# _hash_names = list(urls_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_hash_names):
    next_data_dict {}
    P_dict = P_DICT / f'{name}.pkl'
    if P_dict.exists():
    try:
        next_data_dict = com.viewhash(hash)
        with open(P_dict, 'wb') as f:
            pickle.dump(next_data_dict, f)
        industries_list.append(next_data_dict['props']['pageProps']['job']['v5_processed_company_data']['industries'])
    except:
        pass
        # print(hash)
        industries_list.append(None)
# Out:
# 0

# %%
P1_dict = P_DICT / f"{companies_df.query('ALL').iloc[0]['name']}.pkl"
with open(P1_dict, 'rb') as f:
    next_data_dict = pickle.load(f)
next_data_dict
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[24], line 3
#       1 P1_dict = P_DICT / f"{companies_df.query('ALL').iloc[0]['name']}.pkl"
#       2 with open(P1_dict, 'rb') as f:
# ----> 3     next_data_dict = pickle.load(f)
#       4 next_data_dict
#
# EOFError: Ran out of input

# %%
with open(P_dict, 'rb') as f:
    next_data_dict = pickle.load(f)
# next_data_dict
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 with open(P_dict, 'rb') as f:
# ----> 2     next_data_dict = pickle.load(f)
#       3 next_data_dict
#
# EOFError: Ran out of input

# %%
companies_df['industries'] = pd.Series(industries_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 companies_df['industries'] = industries_list
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/pandas/core/frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/pandas/core/frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/pandas/core/frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File ~/miniconda3/envs/py312/lib/python3.12/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (1768) does not match length of index (5661)

# %%
len(companies_df.query('ALL'))
# Out:
# 1768

# %%
_companies_hash_names = list(companies_df.query('ALL')[['hash', 'name']].iterrows())
for _, (hash, name) in tqdm(_companies_hash_names):
    try:
        P_dict = P_DICT / f'{name}.pkl'
        if P_dict.exists():
            with open(P_dict, 'rb') as f:
                next_data_dict = pickle.load(f)
        else:
            next_data_dict = com.viewhash(hash)
            with open(P_dict, 'wb') as f:
                pickle.dump(next_data_dict)
        industries_list.append(next_data_dict['props']['pageProps']['job']['v5_processed_company_data']['industries'])
    except:
        # print(hash)
        industries_list.append(None)

# %%
industries_list = []
for hash in tqdm(companies_df['hash']):
    try:
        industries_list.append(industries := com.viewhash(hash)['props']['pageProps']['job']['v5_processed_company_data']['industries'])
    except:
        print(hash)
        industries_list.append(None)
# Out:
#   0%|          | 0/5661 [00:00<?, ?it/s]
# bGV2ZXJfX19haWRhc2hfX181ZjZmNzEyMy1lMDMyLTRhYjgtYjUzYi0zOGM0ZGQ2ZDJkNzI=
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/tqdm/_monitor.py", line 84, in run
#     instance.refresh(nolock=True)
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/tqdm/std.py", line 1347, in refresh
#     self.display()
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#     ^^^^^^^^^^^
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/alexa/miniconda3/envs/py312/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# LookupError: <ContextVar name='shell_parent' at 0x74fd20e8d0d0>
# 5nqteafdf0imidg8
# Z3JuaHNlX19fZmx5emlwbGluZV9fXzQxMTMyNzUwMDM=
# cp83i7yafz4irxbz
# xr4okiyprkdmbhsm
# r4qee724xtk4jubs
# m7pstw8hpysya58w
# 1g33d5cy3i0o4daw
# oiv8tb6xj2w9cbvf
# 2terfi2gn5mkiokf
# 8a77b0136psll9ok
# 4a4lcct6bduu5ggp
# dXRpcHJvX19fbmV0MTAwNV9fX2IyMmFjZDM3LTA4ZGQtY2JjMC0yOTVhLWRjMTU0ZWEzZmI5M19fXzliNjU4NmEyLTdmOGQtNDJjMS05YzQxLTdmZWNkYTFiZDg3OQ==
# 9565hfgfspbw3t8g
# Z3JuaHNlX19fbW9kZXJuaGVhbHRoX19fNzcwNTg4NDAwMg==
# 9fh0ragiegkf5bvz
# jozky4sk2k5yt7a8
# yny69gnz35tzvl8d
# eqycwz7yximfioga
# jqp5uc14t0ex5yxp
# ds4vj3la8cxmt5xy
# bcghhn25j074fq7r
# ukluij76xkk215iq
# d2eut16ibz2p2bvw
# iqbloc9ec5gjug99
# bo3ljb7hu9yvmy40
# io7icdyrwcvpu1ii
# wql54v9agtvyn9hs
# ajw7jcmz9rpbfs7a
# gaiif3a6sgapmktw
# bGV2ZXJfX19ib3NvbmFpX19fYTY0MTkzOTUtYWIwZS00M2M0LThhN2ItYTNhZjEzMzQ4NmYw
# YnJlZXp5X19fbm9ydGgtd2luZC1ncm91cF9fXzdjMTM0MTA1YTQ3Yw==
# g4xhiamhtnxbbvue
# n1sgo0f8h7k75j0x
# 3uo6yl31b4vc8zlt
# gm42kapy4biba64t
# ra7sqk6agfqjdkbb
# fdye24t6umdo6ow8
# wuweyyj9hqhu86tb
# wxsp7d3meabtdhwa
# 8zkb11bpcj7f2vxs
# o49h906j7oc7x7oy
# jseewgbc3lb7y474
# j9x3xy4l38c4of0g
# ougnwafrwd83dd73
# kusk8h13jhhit4y2
# bc9jpjcjm0scn461
# 49qgkxw6vhrta86q
# Z3JuaHNlX19fYWNjdXdlYXRoZXJfX183MjQ1NTA3
# ljnk6nlrsdcb1dky
# 50umz32anguv5vqm
# YnJlZXp5X19fZG96dWtpX19fNmEyMGQ2NTU3MGU4
# lq33yo5zcxae3v47

# %%
for hash in urls_df.query('company == "Genentech" and DS')['hash']:
    print(com.viewhash(hash)['props']['pageProps']['job']['v5_processed_company_data']['industries'])
# Out:
# ['Biotechnology Companies', 'Medical Organizations', 'Pharmaceutical Companies', 'Health Care Companies']
# ['Biotechnology Companies', 'Medical Organizations', 'Pharmaceutical Companies', 'Health Care Companies']
# ['Biotechnology Companies', 'Medical Organizations', 'Pharmaceutical Companies', 'Health Care Companies']

# %% [markdown]
# ## Keywords

# %%
# df_dict[STEM].head()['hash'].apply(com.viewhash)

# %%
com.viewhash('diudfs6trmpabwjn')['props']['pageProps']['job']#.keys()
# Out:
# {'id': 'workday___roche-wd3-rog-a2o-gene___medical-data---analytics-engineer_202510-127004-1',
#  'board_token': 'roche-wd3-rog-a2o-gene',
#  'source': 'workday',
#  'apply_url': 'https://roche.wd3.myworkdayjobs.com/rog-a2o-gene/job/South-San-Francisco/Medical-Data---Analytics-Engineer_202510-127004-1',
#  'source_and_board_token': 'workday_roche-wd3-rog-a2o-gene',
#  'job_information': {'title': 'Medical Data & Analytics Engineer',
#   'job_title_raw': 'Medical Data & Analytics Engineer',
#   'description': '<p><span>A healthier future. It’s what drives us to innovate. To continuously advance science and ensure everyone has access to the healthcare they need today and for generations to come. Creating a world where we all have more time with the people we love.\xa0</span></p><p></p><p><b>The Opportunity</b></p><p><span>The Medical Data &amp; Analytics Engineer plays a crucial role in accelerating evidence generation, decision-making, and innovation within USM and beyond, by bridging medical data strategy, engineering, and analytics. This position demands profound technical expertise in clinical data, real-world data (RWD), and scientific literature, coupled with strategic acumen in medical data use cases and their innovative applications.</span></p><p>\xa0</p><p><span>As a systems thinker and a strong collaborator across the R&amp;D enterprise, this individual will contribute to evolving the USM data ecosystem, aligning it with global digital, data, and AI initiatives from Product Development (PD) and early Research and Development (REDs). This role is pivotal in leveraging clinical and real-world data assets to deliver scientific and business value across USM, ultimately making a meaningful impact on patients.</span></p><p></p><p><b>Key Responsibilities</b></p><ul><li><p><span>Assess medical data sources (e.g., clinical trial, RWD, scientific literature) required for medical insights related to clinical trials and evidence planning, and lead the acquisition, transformation, and integration of new data sources into enterprise platforms (when needed).\xa0\xa0</span></p></li><li><p><span>Collaborate with data scientists, statisticians, and clinicians to provide analytic-ready datasets for clinical, RWE, and scientific literature, fostering strong partnerships with Medical, Clinical &amp; RWD functions globally.</span></p></li><li><p><span>Define and evolve the Medical Operations data strategy to support medical affairs in partnership with other EG and E4A teams. Represent USM on global strategic initiatives related to data foundation, data capabilities, and analytics.</span></p></li><li><p><span>Translate scientific and business questions into medical data requirements, tools, and data platforms needed to deliver medical insights for trial design, operational strategy, and evidence planning.</span></p></li><li><p><span>Influence R&amp;D enterprise data governance, stewardship, and policies, providing thought leadership on emerging trends including AI/ML applications, data linkage, digital health integration, and decentralized trials.</span></p></li><li><p><span>Act as an innovator and connector by leveraging emerging technologies and novel data sources to advance evidence generation, introducing modern engineering and analytics practices, and bridging scientific, technical, and business perspectives to unlock multimodal data value, while also serving as a change agent for multimodal data adoption and cultural/operational transformation.</span></p></li></ul><p></p><p><b>Who you are</b></p><p><b>Required Qualifications &amp; Experience</b></p><ul><li><p><span>Bachelor’s or Master’s degree in Computer Science, Biomedical Informatics, Data Engineering, or a related field (PhD is a plus for advanced biomedical applications).</span></p></li><li><p><span>6&#43; years of experience in data engineering or analytics engineering, with exposure to healthcare or life sciences.</span></p></li><li><p><span>Proficiency in SQL, Python, Spark, and workflow orchestration tools\xa0</span></p></li><li><p><span>Hands-on experience with cloud platforms (AWS, Azure, or GCP).</span></p></li><li><p><span>Familiarity with healthcare and biomedical data (EHR, claims, registries, genomics, imaging, digital, PROs) and relevant standards (OMOP, FHIR, CDISC, HL7, DICOM).</span></p></li><li><p><span>Experience building analytics-ready data assets and supporting visualization or statistical modeling workflows.</span></p></li></ul><p></p><p><b>Trave ...
#   'stripped_description': "A healthier future. It’s what drives us to innovate. To continuously advance science and ensure everyone has access to the healthcare they need today and for generations to come. Creating a world where we all have more time with the people we love.\xa0The OpportunityThe Medical Data & Analytics Engineer plays a crucial role in accelerating evidence generation, decision-making, and innovation within USM and beyond, by bridging medical data strategy, engineering, and analytics. This position demands profound technical expertise in clinical data, real-world data (RWD), and scientific literature, coupled with strategic acumen in medical data use cases and their innovative applications.As a systems thinker and a strong collaborator across the R&D enterprise, this individual will contribute to evolving the USM data ecosystem, aligning it with global digital, data, and AI initiatives from Product Development (PD) and early Research and Development (REDs). This role is pivotal in leveraging clinical and real-world data assets to deliver scientific and business value across USM, ultimately making a meaningful impact on patients.Key ResponsibilitiesAssess medical data sources (e.g., clinical trial, RWD, scientific literature) required for medical insights related to clinical trials and evidence planning, and lead the acquisition, transformation, and integration of new data sources into enterprise platforms (when needed).\xa0\xa0Collaborate with data scientists, statisticians, and clinicians to provide analytic-ready datasets for clinical, RWE, and scientific literature, fostering strong partnerships with Medical, Clinical & RWD functions globally.Define and evolve the Medical Operations data strategy to support medical affairs in partnership with other EG and E4A teams. Represent USM on global strategic initiatives related to data foundation, data capabilities, and analytics.Translate scientific and business questions into medical data requirements, tools, and data platforms needed to deliver medical insights for trial design, operational strategy, and evidence planning.Influence R&D enterprise data governance, stewardship, and policies, providing thought leadership on emerging trends including AI/ML applications, data linkage, digital health integration, and decentralized trials.Act as an innovator and connector by leveraging emerging technologies and novel data sources to advance evidence generation, introducing modern engineering and analytics practices, and bridging scientific, technical, and business perspectives to unlock multimodal data value, while also serving as a change agent for multimodal data adoption and cultural/operational transformation.Who you areRequired Qualifications & ExperienceBachelor’s or Master’s degree in Computer Science, Biomedical Informatics, Data Engineering, or a related field (PhD is a plus for advanced biomedical applications).6+ years of experience in data engineering or analytics engineering, with exposure to healthcare or life sciences.Proficiency in SQL, Python, Spark, and workflow orchestration tools\xa0Hands-on experience with cloud platforms (AWS, Azure, or GCP).Familiarity with healthcare and biomedical data (EHR, claims, registries, genomics, imaging, digital, PROs) and relevant standards (OMOP, FHIR, CDISC, HL7, DICOM).Experience building analytics-ready data assets and supporting visualization or statistical modeling workflows.Travel RequirementsThe position is located in South San Francisco but the candidate. The position may require up to an additional 25% time traveling.\xa0The expected salary range for this position based on the primary location of South San Francisco, CA is $143,100 - 265,700.\xa0 Actual pay will be determined based on experience, qualifications, geographic location, and other job-related factors permitted by law.\xa0 A discretionary annual bonus may be available based on individual and Company performance.\xa0 This position also qualifies fo ...
#   'hiddenFromUsers': ['kixSpW8Z0jf2o67IKH9y65221pp1',
#    'yWLmywXPDBZ0ws1Sj6S5gaAi4N63',
#    'jNVxIMTklhNFasI2FoFdmXYzBGJ2'],
#   'viewedByUsers': ['7mVD6RQru6bfokVM6ofCYIOlah43',
#    'hrc9bxZ6v9aebLG4njH3KIoAgxN2',
#    'FXi9TG936HdJcyuaciHFj5J5JfE2'],
#   'appliedFromUsers': ['sBDzKUL8y7TExAkygEAOq2TWUbs2',
#    'hrc9bxZ6v9aebLG4njH3KIoAgxN2']},
#  'v5_processed_job_data': {'core_job_title': 'Medical Data & Analytics Engineer',
#   'requirements_summary': '6+ years in data engineering/analytics; SQL, Python, Spark; cloud platforms (AWS/Azure/GCP); healthcare data (EHR, claims, registries, genomics, imaging, PROs); OMOP, FHIR, CDISC, HL7, DICOM; analytics-ready data assets.',
#   'technical_tools': ['SQL',
#    'Python',
#    'Spark',
#    'Workflow Orchestration',
#    'AWS',
#    'Azure',
#    'GCP',
#    'OMOP',
#    'FHIR',
#    'CDISC',
#    'HL7',
#    'DICOM'],
#   'technical_tools_synonyms': ['sql',
#    'relational databases',
#    'databases',
#    'sql databases',
#    'microsoft sql',
#    'ms-sql',
#    'sql server',
#    'mssql',
#    'sql dbs',
#    'ms sql',
#    'rdbms',
#    'ms sql server',
#    'db sql',
#    'oracle sql',
#    'microsoft sql server',
#    'database',
#    'oracle sql server',
#    'ansi sql',
#    'sql database server',
#    'sql database',
#    'sqlserver',
#    'postgres sql',
#    'sql developer',
#    'database skills',
#    'ms sql database',
#    'sql studio',
#    'sql oracle',
#    'sql scripts',
#    'sql server mssql',
#    'my sql',
#    'ms-sql server',
#    'sql (postgres)',
#    'sql-server',
#    'msql',
#    'ms sql-server',
#    'sql analytics',
#    'sql programming',
#    'rdbms sql',
#    'ms/sql',
#    'structured query language',
#    'sql standard',
#    'sql servers',
#    'ms sqlserver',
#    't/sql',
#    'microsoft sqlserver',
#    'microsoft sql database',
#    'sql express',
#    'sql database infrastructure',
#    'sql lite',
#    'sql query',
#    'sql dba',
#    'advanced sql',
#    'sql language',
#    'sql/rdbms',
#    'sql database administration',
#    'oracle/sql',
#    'sql database management',
#    'sql management tools',
#    'msft sql',
#    'system query language (sql)',
#    'sql scripting',
#    'structured query language (sql)',
#    'sql reports',
#    'sql server database',
#    'sql query writing',
#    'sql anywhere',
#    'basic sql',
#    'sql server db',
#    'ms sql databases',
#    'sql db',
#    'sql procedures',
#    'sql command/server',
#    'mssql database',
#    'microsoft sql databases',
#    'database sql',
#    'sql client',
#    'sql queries',
#    'sql+',
#    'non-stop sql',
#    'nonstop sql',
#    'sql script',
#    'sql dw',
#    'sql (programming language)',
#    'database/sql',
#    'sql/mysql',
#    'sql data server',
#    'windows sql',
#    'sql database management systems',
#    'managed sql',
#    'sql-based databases',
#    'oracle database sql',
#    'open sql',
#    'sql server databases',
#    'ansi-sql',
#    'sql editor',
#    'db skills',
#    'sql query language',
#    'ms sql db',
#    'native sql',
#    'standard sql',
#    'sql dml',
#    'sql viewpoint',
#    'sql proficiency',
#    'sql (mysql)',
#    'python',
#    'python scripting',
#    'python 3',
#    'python programming',
#    'scientific python',
#    'python applications',
#    'python programming language',
#    'python3',
#    'python scripts',
#    'python script',
#    'programming (python)',
#    'cpython',
#    'python (programming language)',
#    'python software development',
#    'scripting languages (python)',
#    'software development - python',
#    'phyton',
#    'python 3.x',
#    'spark',
#    'sparksql',
#    'sparkar',
#    'sparkr',
#    'sparks',
#    'javaspark',
#    'spark streams',
#    'spark builder',
#    'spark api',
#    'spark technology',
#    'sparkstreams',
#    'spark analytics',
#    'spark/ml',
#    'py spark',
#    'spark framework',
#    'workflow orchestration',
#    'workflow orchestration tools',
#    'workflow automation',
#    'workflows',
#    'workflow systems',
#    'workflow platforms',
#    'workflow management',
#    'workflow engines',
#    'workflow system',
#    'workload orchestration',
#    'workflow engine',
#    'workflow orchestrators',
#    'automated workflow orchestration tooling',
#    'process orchestration',
#    'workflow technologies',
#    'aws',
#    'aws iam',
#    'aws s3',
#    'aws lambda',
#    'aws rds',
#    'amazon web services',
#    'aws cloud',
#    'aws ecs',
#    'ec2',
#    'amazon ec2',
#    'amazon s3',
#    'aws services',
#    'amazon aws',
#    'aws cloud services',
#    'aws cloudwatch',
#    'aws cloud security tooling',
#    'aws govcloud',
#    'aws networking',
#    'aws cli',
#    'aws security',
#    'aws insight',
#    'aws tools',
#    'aws ec2',
#    'cloud security (aws)',
#    'cloud (aws)',
#    'aws networking services',
#    'aws eks',
#    'aws vpc',
#    'amazon web services (aws)',
#    'aws cloud wan',
#    'aws pipelines',
#    'cloud (aws or azure)',
#    'aws big data services',
#    'aws mwaa',
#    'aws data services',
#    'aws cloud technologies',
#    'cloud aws',
#    'aws serverless',
#    'aws devops',
#    'aws center',
#    'amazon aws ecs',
#    'amazon aws s3',
#    'aws sdks',
#    'aws api',
#    'amazon web service (aws)',
#    'aws gov cloud',
#    'aws infrastructure',
#    'aws cloud native',
#    'aws code tools',
#    'aws cloudwan',
#    'amazon elastic compute cloud',
#    'aws il6',
#    'amazon cloud services',
#    'amazon cloud technologies',
#    'aws cloud security services',
#    'aws console',
#    'amazon cloud platform',
#    'aws functions',
#    'amazon cloud',
#    'aws cloud systems',
#    'aws database',
#    'aws ace',
#    'aws sdk',
#    'aws cloud data services',
#    'aws ml',
#    'aws cloud iam',
#    'aws cloud platform',
#    'aws cloud infrastructure',
#    'aws ebs',
#    'aws sct',
#    'aws compute',
#    'aws cloud computing',
#    'aws data analytics',
#    'aws developer tools',
#    'aws cloud tools',
#    'aws standards',
#    'aws architecture',
#    'aws storage services',
#    'aws sdlf',
#    'aws security services',
#    'cloud (aws or gcp)',
#    'aws associate',
#    'aws reporting',
#    'aws beanstalk',
#    'aws database services',
#    'cloud technologies (aws)',
#    'aws cloud monitoring',
#    'aws kubernetes',
#    'aws lambdas',
#    'aws applications',
#    'csp (aws)',
#    'aws cloud computing foundation',
#    'amazon cloud hosting',
#    'aws-cli',
#    'aws native services',
#    'aws cloud service',
#    'aws cloud architectures',
#    'aws technologies',
#    'aws big data',
#    'aws platform',
#    'aws solutions architect',
#    'cloud/aws',
#    'aws data & ai',
#    'aws storage s3',
#    'cloud - aws',
#    'aws platforms',
#    'aws storage',
#    'aws cloud storage',
#    'aws administration',
#    'aws cloud operations',
#    'aws development',
#    'aws cloud management',
#    'aws elastic compute service',
#    'cloud platforms (aws/azure)',
#    '" cloud services (aws',
#    'cloud (aws/azure)',
#    'aws-eks',
#    'azure',
#    'azure cloud',
#    'azure devops',
#    'azure ai',
#    'microsoft azure',
#    'azuread',
#    'azure active directory',
#    'azure ad',
#    'azure cli',
#    'azure monitor',
#    'azure cloud services',
#    'azure storage',
#    'azure sql database',
#    'azure security',
#    'azure networking',
#    'azure automation',
#    'azure sql',
#    'azure files',
#    'azure sql db',
#    'azure portal',
#    'microsoft azure devops',
#    'azure dev ops',
#    'azuredevops',
#    'azure powershell',
#    'azure cloud platform',
#    'ms azure',
#    'azure services',
#    'azure monitoring',
#    'azure functions',
#    'azure web services',
#    'azure integration services',
#    'microsoft/azure sql',
#    'azure pipelines',
#    'microsoft azure ad',
#    'azure data analytics',
#    'microsoft azure ai',
#    'azure-ad',
#    'azure ml',
#    'azure app services',
#    'sql azure',
#    'azure data tech stack',
#    'azure git',
#    'azure kubernetes',
#    'azure arm',
#    'azure database',
#    'azure management tools',
#    'microsoft azure services',
#    'azure data',
#    'azure cloud technologies',
#    'azure migrate',
#    'azuredb',
#    'cloud (azure)',
#    'azure repos',
#    'azure sql server',
#    'azure jira',
#    'azure advisor',
#    'azure web apps',
#    'devops azure',
#    'azure analytics',
#    'azure function apps',
#    'azure webapps',
#    'azure cloud stack',
#    'azure bot service',
#    'azure entra',
#    'microsoft cloud',
#    'azure stack',
#    'azure search',
#    'azure gov cloud',
#    'azure-connect',
#    'azure gcc',
#    'azure entraid',
#    'azure virtualization',
#    'azure virtualization infrastructure',
#    'azure cloud security',
#    'microsoft azure sql',
#    'azure aks',
#    'azure fabric',
#    'ms/azure services',
#    'windows azure ad',
#    'azure api apps',
#    'azure paas',
#    'azure iaas',
#    'azure vm',
#    'azure sql services',
#    'azure-active directory',
#    'azure data engineering',
#    'azure pipeline',
#    'ms-azure',
#    'microsoft azure stack',
#    'cloud networking in azure',
#    'ms azure sql database',
#    'azure o365',
#    'azure cloud data storage',
#    'azuresql',
#    'windows azure',
#    'azure integration',
#    'azure data technologies',
#    'azure cloud networking',
#    'azure security solutions',
#    'microsoft azure cloud',
#    'azure infrastructure',
#    'azure technologies',
#    'azure data services',
#    'azure virtual machines',
#    'azure data platforms',
#    'azure devsecops',
#    'azure dashboards',
#    'microsoft azure monitor',
#    'azure database services',
#    'azure cloud environments',
#    'azure data platform',
#    'microsoft azure sql database',
#    'azure app service',
#    'azure paas services',
#    'azure/o365',
#    'msft azure',
#    'azure government',
#    'azure apis',
#    'azure cloud data services',
#    'azure function',
#    'azure sql databases',
#    'microsoft windows azure',
#    'azure/entra',
#    'microsoft cloud services',
#    'azure data & analytics',
#    'azure sqldb',
#    'azure databases',
#    'azure sql management',
#    'microsoft azure fabric',
#    'azure dev-ops',
#    'azure apps',
#    'microsoft azure devops server',
#    'ms azure services',
#    'azure bi',
#    'microsoft sql azure db',
#    'azure security services',
#    'azure development intelligence',
#    'azure/ad',
#    'microsoft/azure',
#    'azure ai cloud platform',
#    'ms azure devops',
#    'azure architecture',
#    'cloud azure',
#    'azure api',
#    'azure bot services',
#    'microsoft azure data services',
#    'microsoft azure analytics services',
#    'microsoft azure functions',
#    'azure storage solutions',
#    'microsoft azuredevops',
#    'azure cloud computing',
#    'azure microsoft sql server',
#    'azure directory',
#    'azure cloud deployment',
#    'azure boards',
#    'devopsazure',
#    'azure cloud solutions',
#    'microsoft dev azure',
#    'azure devops services',
#    'azure native tools',
#    'ms azure suite',
#    'azure development',
#    'azure admin',
#    'azure arc',
#    'microsoft azure iaas',
#    'azure cloud technology',
#    'azure infrastructure services',
#    'azure compute',
#    'azure sql database services',
#    'microsoft azuread',
#    'azure dw',
#    'ms azure ad',
#    'azurebus',
#    'azure platform',
#    'azure hybrid',
#    'azure suite',
#    'azure saas/paas',
#    'azure/m365',
#    'azure stream',
#    'microsoft azure docker',
#    'azure openshift',
#    'azure ci',
#    'azure ado',
#    'azure hosting environment',
#    'azurerm',
#    'ms azure cloud',
#    'azure microservices',
#    'azure warehouse',
#    'ms azure bi ecosystem',
#    'azure sqlserver',
#    'azure ci/cd',
#    'azure board',
#    'azure public cloud',
#    'azure db',
#    'csp (azure)',
#    'azure application services',
#    'azure cloud native services',
#    '" cloud (azure',
#    'azure web app',
#    'azure-cli',
#    'ms cloud services',
#    'cloud azure monitor',
#    'azure virtual machine',
#    'azure frameworks',
#    'microsoft azure data platform',
#    'ms azure sql',
#    'cloud (azure/aws)',
#    'azure serverless',
#    'azure containers',
#    'azure vmware solutions',
#    'azure cloud/devops',
#    'cloud computing tools (azure)',
#    'azure test',
#    'azure data products',
#    'azure data stack',
#    'azure big data services',
#    'azure analytics services',
#    'microsoft azure cloud services',
#    'cloud - azure',
#    'microsoft azure dev ops',
#    'azure-devops',
#    'azure integration tools',
#    'azure solutions architect',
#    'azure management portal',
#    'ms azure networking',
#    'azure cloud architecture',
#    'azure power bi',
#    'microsoft azure storage',
#    'azure devops suite',
#    'azure a/d',
#    'azure data storage',
#    'microsoft azure networking',
#    'azure vms',
#    'azure sdk',
#    'microsoft azure architecture',
#    'azure products',
#    'azure data solutions',
#    '" cloud (azure/aws',
#    'azure rm',
#    'microsoft azure integration services',
#    'azure studio',
#    'azure govcloud',
#    'azure artifacts',
#    'azure rest apis',
#    'azure management console',
#    'microsoft azure paas',
#    'azure as',
#    'azure web-app',
#    'gcp',
#    'google cloud platform',
#    'google cloud',
#    'gcloud',
#    'gcp managed services',
#    'google cloud compute',
#    'google gcp',
#    'gcp services',
#    'google cloud services',
#    'gcp logs',
#    'google cloud (gcp)',
#    'google cloud platform (gcp)',
#    'google cloud environment',
#    'gcp kubernetes engine',
#    'gcp security',
#    'gcp cloud',
#    'google compute cloud',
#    'cloud (gcp)',
#    'googlecloud',
#    'gcp guidelines',
#    'google compute platform',
#    'google compute platform (gcp)',
#    'gcp operations suite',
#    'google cloud platforms',
#    'gcp infrastructure',
#    'gcp data flow',
#    'gcp cloud tasks',
#    'gcp security services',
#    'gcp cloud services',
#    'cloud google',
#    'gcp cli',
#    'cloud gcp',
#    'gcp workflows',
#    'google cloud technologies',
#    'gcp monitoring',
#    'gcp command center',
#    'gcp cloud development',
#    'gcp iam',
#    'google cloud service',
#    'gcp chronicle',
#    'cloud technologies (gcp)',
#    'gcp lb',
#    'gcp dataprocs',
#    'gcp public cloud technologies',
#    'gcp data & ai',
#    'gcp webservices',
#    'cloud - gcp',
#    'gcp data engineering',
#    'gcp architecture',
#    'gcp cloud ecosystem',
#    'omop',
#    'omop data models',
#    'fhir',
#    'smart on fhir',
#    'fhir standards',
#    'hl7 fhir',
#    'fhir api',
#    'hapi fhir',
#    'fhir terminology tools',
#    'cdisc',
#    'cdisc validation software',
#    'cdisc standards',
#    'cdisc sdtm',
#    'cdisc data standards',
#    'hl7',
#    'health level seven (hl7)',
#    'hl7 v2',
#    'hl7 v3',
#    'hl7 integration engine',
#    'hl7 standards',
#    'hl7 protocol',
#    'hl7 interface',
#    'hl7 interfaces',
#    'hl7 cda',
#    'hl7 coding standards',
#    'hl7 messaging',
#    'hl/7',
#    'hl7 apis',
#    'hl7 interfacing standards',
#    'health level seven',
#    'hl7 v3 standards',
#    'hl7v2',
#    'dicom',
#    'dicom devices',
#    'dicom viewers',
#    'dicom imaging software',
#    'dicom web',
#    'dicom standards',
#    'dicom communication',
#    'pydicom'],
#   'licenses_or_certifications': [],
#   'licenses_or_certifications_synonyms': [],
#   'associates_degree_requirement': 'Not Mentioned',
#   'associates_degree_fields_of_study': [],
#   'bachelors_degree_requirement': 'Required',
#   'bachelors_degree_fields_of_study': ['Computer Science',
#    'Biomedical Informatics',
#    'Data Engineering'],
#   'masters_degree_requirement': 'Preferred',
#   'masters_degree_fields_of_study': ['Computer Science',
#    'Biomedical Informatics',
#    'Data Engineering'],
#   'doctorate_degree_requirement': 'Not Mentioned',
#   'doctorate_degree_fields_of_study': [],
#   'licenses_or_certifications_not_mentioned': True,
#   'min_industry_and_role_yoe': 6,
#   '401k_matching': False,
#   'is_min_industry_and_role_yoe_not_mentioned': False,
#   'min_management_and_leadership_yoe': None,
#   'is_min_management_and_leadership_yoe_not_mentioned': True,
#   'job_category': 'Data and Analytics',
#   'role_activities': ['Assess data',
#    'Collaborate analytics',
#    'Define strategy'],
#   'commitment': ['Full Time'],
#   'role_type': 'Individual Contributor',
#   'seniority_level': 'Senior Level',
#   'workplace_countries': ['US'],
#   'boundless_workplace_states': [],
#   'boundless_workplace_countries': [],
#   'boundless_workplace_continents': [],
#   'workplace_continents': ['North America'],
#   'workplace_states': ['California, US'],
#   'workplace_cities': ['South San Francisco, California, US'],
#   'workplace_counties': ['San Mateo County, California, US'],
#   'workplace_type': 'Onsite',
#   'workplace_physical_environment': 'Office',
#   'oral_communication_level': 'Medium',
#   'physical_labor_intensity': 'Low',
#   'physical_position': 'Sitting',
#   'computer_usage': 'High',
#   'cognitive_demand': 'High',
#   'air_travel_requirement': 'None',
#   'land_travel_requirement': 'Moderate',
#   'morning_shift_work': 'Not Indicated',
#   'evening_shift_work': 'Not Indicated',
#   'overnight_work': 'Not Indicated',
#   'formatted_workplace_location': 'South San Francisco, California, United States',
#   'on_call_requirement': 'None',
#   'weekend_availability_required': False,
#   'holiday_availability_required': False,
#   'generous_paid_time_off': False,
#   'four_day_work_week': False,
#   'overtime_required': False,
#   'is_workplace_worldwide_ok': False,
#   'language_requirements': ['English'],
#   'num_language_requirements': 1,
#   'number_of_workplace_cities': 1,
#   'number_of_workplace_counties': 1,
#   'number_of_workplace_states': 1,
#   'number_of_workplace_countries': 1,
#   'number_of_workplace_continents': 1,
#   'yearly_max_compensation': 265700,
#   'yearly_min_compensation': 143100,
#   'monthly_max_compensation': 22141.666666666668,
#   'monthly_min_compensation': 11925,
#   'weekly_max_compensation': 5109.615384615385,
#   'weekly_min_compensation': 2751.923076923077,
#   'hourly_max_compensation': 127.74038461538461,
#   'hourly_min_compensation': 68.79807692307692,
#   'bi-weekly_min_compensation': 5503.846153846154,
#   'bi-weekly_max_compensation': 10219.23076923077,
#   'daily_min_compensation': 550.3846153846154,
#   'daily_max_compensation': 1021.9230769230769,
#   'estimated_publish_date': '2025-10-23T00:00:00.000Z',
#   'estimated_publish_date_millis': 1761177600000,
#   'fair_chance': False,
#   'visa_sponsorship': False,
#   'relocation_assistance': False,
#   'military_veterans': False,
#   'tuition_reimbursement': False,
#   'retirement_plan': False,
#   'generous_parental_leave': False,
#   'is_high_school_required': True,
#   'is_driver_license_required': False,
#   'is_compensation_transparent': True,
#   'listed_compensation_currency': 'USD',
#   'listed_compensation_frequency': 'Yearly',
#   'security_clearance': 'None',
#   'position_employer_type': 'External Position',
#   'company_name': 'Roche',
#   'company_website': 'gene.com',
#   'company_sector_and_industry': 'Healthcare',
#   'company_activities': ['biotechnology', 'biopharma'],
#   'company_tagline': 'Leading biotechnology and drug development company.',
#   'associates_degree_fields_of_study_synonyms': [],
#   'bachelors_degree_fields_of_study_synonyms': ['computer science',
#    'software engineering',
#    'computer engineering',
#    'computer/electrical engineering',
#    'programming',
#    'computer security',
#    'computer graphics',
#    'computing',
#    'computer information systems',
#    'computers',
#    'computer sciences',
#    'computer programming',
#    'computer and information science',
#    'computer system technology',
#    'information and computer science',
#    'information & computer sciences',
#    'information & computer science',
#    'computer science/mis',
#    'computer network',
#    'computer information technology',
#    'computer networking',
#    'computer information science',
#    'computer technology',
#    'computer management',
#    'computer science engineering',
#    'computer and information systems',
#    'computer',
#    'computing science',
#    'computer applications',
#    'computer software',
#    'computer systems',
#    'applied computing',
#    'software programming',
#    'it/computer sciences',
#    'computer and software technology',
#    'data/computer science',
#    'computer technologies',
#    'computer application',
#    'computer/software engineering',
#    'theoretical computer science',
#    'computer science and engineering',
#    'computer systems engineering',
#    'applied computer science',
#    'computer it',
#    'computational sciences',
#    'computing engineering',
#    'computer science/it',
#    'computer software engineering',
#    'computer/business systems',
#    'hci/computer science',
#    'computer engineering technology',
#    'computer systems technology',
#    'system/computer engineering',
#    'cs',
#    'computer design',
#    'computational science',
#    'computer/software',
#    'computer information system',
#    'computing sciences',
#    'it computer engineering',
#    'it computing',
#    'computer studies',
#    'computing systems',
#    'electrical/computer engineering',
#    'computer development',
#    'software/computer engineering',
#    'computer art',
#    'computer architecture',
#    'computer science technology',
#    'computer information',
#    'business computer science',
#    'computers in education',
#    'computers and math',
#    'computer/data science',
#    'computer information systems management',
#    'computer application development',
#    'computer systems design',
#    'computer systems administration',
#    'electronics & computer science',
#    'business computer',
#    'computer science & engineering',
#    'technical computer science',
#    'computer science/engineering',
#    'computer & information sciences',
#    'software engineering/development',
#    'mathematics & computer science',
#    'computer science/technology',
#    'computer programming/software development',
#    'information/computer science',
#    'computer system administration',
#    'science (computer studies)',
#    'technical-computer science',
#    'computer information sciences',
#    'applied computer sciences',
#    'computer software/computer systems engineering',
#    'computer analytics',
#    'computer & information science',
#    'computer science/information technology',
#    'computer system',
#    'programming/systems',
#    'software development/engineering',
#    'data or computer science',
#    'technology and computing',
#    'computer & information technology',
#    'computer systems management',
#    'computer/management information systems',
#    'computing systems engineering',
#    'computer/technology sciences',
#    'computer information systems engineering',
#    'computer and information technology',
#    'computers/informatics',
#    'computer and electrical engineering',
#    'computing technologies',
#    'computer education',
#    'computer linguistics',
#    'biomedical informatics',
#    'bioinformatics',
#    'biomedical sciences',
#    'health informatics',
#    'healthcare informatics',
#    'biomedical science',
#    'medical informatics',
#    'biomedical',
#    'biomed',
#    'health care informatics',
#    'biomedical field',
#    'bio informatics',
#    'biomedical data science',
#    'biomedical discipline',
#    'data engineering',
#    'data science',
#    'data analytics',
#    'data',
#    'big data & analytics',
#    'analytics engineering',
#    'data and analytics',
#    'data sciences',
#    'data & analytics',
#    'data specialization',
#    'data architecture',
#    'data science/analysis',
#    'data science and engineering',
#    'data technology',
#    'big data',
#    'big data analytics',
#    'data science and analytics',
#    'data science/analytics',
#    'data analytics engineering',
#    'big data and analytics',
#    'data science & analytics',
#    'data mining and analytics',
#    'data science engineering',
#    'ai data science engineering',
#    'data science and machine learning',
#    'database engineering'],
#   'masters_degree_fields_of_study_synonyms': ['computer science',
#    'computer sciences',
#    'computer engineering',
#    'software engineering',
#    'computer security',
#    'computer information systems',
#    'computers',
#    'computer graphics',
#    'information and computer science',
#    'information & computer sciences',
#    'information & computer science',
#    'computing',
#    'computer technology',
#    'computer networking',
#    'computer programming',
#    'computer',
#    'computational sciences',
#    'computer applications',
#    'applied computing',
#    'computer systems',
#    'computational science',
#    'theoretical computer science',
#    'computer science engineering',
#    'programming',
#    'computer architecture',
#    'computing engineering',
#    'computer information science',
#    'computer software engineering',
#    'applied computer science',
#    'hci/computer science',
#    'system/computer engineering',
#    'computing science',
#    'electrical/computer engineering',
#    'computer information system',
#    'data/computer science',
#    'mathematics with concentration in computer science',
#    'computer and information science',
#    'computer information',
#    'it/computer science',
#    'computer systems engineering',
#    'computer science & engineering',
#    'business computer',
#    'computer and electrical engineering',
#    'software programming',
#    'computer education',
#    'computer engineering technology',
#    'computer application',
#    'computer information technology',
#    'industrial computer science',
#    'applied computer sciences',
#    'advanced computer science',
#    'information/computer science',
#    'computing and information sciences',
#    'computer software',
#    'computer science/engineering',
#    'computer system',
#    'technical computer science',
#    'computer systems management',
#    'computer art',
#    'computer/management information systems',
#    'generalist computer science',
#    'computer and information science & accounting',
#    'computer management',
#    'computer & information sciences',
#    'computer and information technology',
#    'computers/informatics',
#    'computer studies',
#    'computer/data sciences',
#    'computing technologies',
#    'cs engineering',
#    'biomedical informatics',
#    'bioinformatics',
#    'biomedical data science',
#    'biomedical sciences',
#    'health informatics',
#    'biomedical science',
#    'healthcare informatics',
#    'biomedical discipline',
#    'biomedical',
#    'health care informatics',
#    'medical informatics',
#    'data engineering',
#    'data science',
#    'data analytics',
#    'analytics engineering',
#    'data',
#    'data & ai',
#    'data sciences',
#    'data science/analysis',
#    'big data',
#    'data and analytics',
#    'big data technology',
#    'data science/analytics',
#    'data & analytics',
#    'data infrastructure',
#    'data architecture',
#    'data analytics engineering',
#    'ai data science engineering',
#    'big data analytics',
#    'database engineering',
#    'data expertise'],
#   'doctorate_degree_fields_of_study_synonyms': [],
#   'company_activities_synonyms': ['biotechnology',
#    'bioprocessing',
#    'biotech',
#    'biologics development',
#    'biological research',
#    'biological sciences',
#    'life sciences',
#    'biotechnology tools',
#    'biotherapeutics',
#    'biopharmaceutical development',
#    'biomedical research',
#    'biopharmaceutical',
#    'biological engineering',
#    'biopharmaceutical company',
#    'biopharmaceuticals',
#    'life science',
#    'biopharmaceutical research',
#    'developing biopharmaceuticals',
#    'bioscience',
#    'biopharmaceutical r&d',
#    'biopharmaceutical innovation',
#    'biopharmaceutical manufacturing',
#    'biotechnology research',
#    'biotechnology support',
#    'developing biopharmaceutical products',
#    'biologics',
#    'bioengineering',
#    'biotechnology services',
#    'biopharmaceutical services',
#    'biomedicine',
#    'biopharmaceutical market',
#    'biosciences',
#    'biopharma services',
#    'life science research',
#    'biomedical sciences',
#    'biopharma',
#    'biological product development',
#    'biopharmaceutical support',
#    'biopharmaceutical production',
#    'biotech investment',
#    'diagnostic biotechnology',
#    'biotech startup',
#    'biologics drug development',
#    'biotech support',
#    'biotechnology manufacturing',
#    'biochemistry research',
#    'biochemistry',
#    'biotech innovation',
#    'biopharma innovation',
#    'biotechnology solutions',
#    'bio-pharmaceutical',
#    'biopharmaceutical business',
#    'biopharmaceutical products',
#    'biopharmaceuticals r&d',
#    'biologic manufacturing',
#    'biotech solutions',
#    'life science technology',
#    'biotechnology equipment',
#    'biopharma development',
#    'biotechnological production',
#    'biotech operations',
#    'biotech services',
#    'bio products',
#    'biological innovation',
#    'biotech production',
#    'biotech applications',
#    'biopharma research',
#    'bio-pharmaceuticals',
#    'biological manufacturing',
#    'biopharma production',
#    'biological products',
#    'manufacturing biopharmaceuticals',
#    'biotech product development',
#    'bioproduction',
#    'biopharmaceutical operations',
#    'biomedical industry',
#    'biotech products',
#    'biological-based therapeutics',
#    'biopharmaceuticals manufacture',
#    'biotechnology development',
#    'biologicals',
#    'bioindustry',
#    'biopharma products',
#    'pharmaceuticals',
#    'biopharmaceutical consulting',
#    'biopharmaceutical commercialization',
#    'biopharma solutions',
#    'pharmaceutical industry',
#    'pharmaceutical',
#    'biopharmaceutical systems',
#    'biopharmaceutical solutions',
#    'biopharmaceutical equipment',
#    'biopharmaceutical sales',
#    'biotherapeutics development',
#    'biologics platform',
#    'biopharma facilities',
#    'biopharmaceutical processing',
#    'biopharma manufacturing',
#    'biologics operations',
#    'biopharmaceutical supply',
#    'biopharma growth strategies',
#    'biopharma support',
#    'biopharmaceutical partnerships',
#    'biopharma equipment',
#    'biopharmaceutical education',
#    'biopharmaceutical manufacture',
#    'offering services to biopharma and healthcare',
#    'offering services to biopharma and healthcare industries',
#    'biopharmaceutical testing']},
#  'v5_processed_company_data': {'name': 'Genentech',
#   'image_url': 'https://kg.diffbot.com/image/api/get?fetch=yes&urls=g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FcvBu%3ElS%3ARq%40_%7EI.Kov,g%3Cj7P0Stn8p.%5DjEp9G.Bd%7BkBWM%7Et1R%5D-E1VZ-Zf7m-Dizh-eZqr%3F%5CtOp6U%7EzN_%3Cb4E.A%5Dm,g%3Cj7P0St0DnBJf.x0KwLZrUn.%5B%3CR0Aa4Hh%3B%5Bv738ZqOr7U%3FfvES%3ElS%3ARq%40_%7EIb%3DZsI%7B8_zIw%3E.%7CS%60',
#   'subsidiaries': ['Tanox',
#    'Seragon Pharmaceuticals',
#    'Jecure Therapeutics',
#    'RQx Pharmaceuticals',
#    'AntlerA Therapeutics',
#    'LEADER',
#    'SIPELIA',
#    'GenenTech Europe'],
#   'parent_company': 'Roche',
#   'website': 'gene.com',
#   'linkedin_url': 'linkedin.com/company/genentech',
#   'industries': ['Biotechnology Companies',
#    'Medical Organizations',
#    'Pharmaceutical Companies',
#    'Health Care Companies'],
#   'activities': ['biotechnology',
#    'pharmaceutical',
#    'pharmaceutical preparations',
#    'pharmaceutical manufacturing',
#    'biotechnology product manufacturing',
#    "drugs and druggists' sundries merchant wholesalers",
#    "drugs, drug proprietaries, and druggists' sundries",
#    'medical laboratories',
#    'biological products, except diagnostic substances',
#    'biological product manufacturing',
#    'noncommercial research organizations',
#    'pharmaceutical industry',
#    'pharmaceutical preparation manufacturing',
#    'offices and clinics of doctors of medicine',
#    'offices of physicians',
#    'general contractors-single-family houses',
#    'residential remodelers',
#    'chemicals and allied products',
#    'oncology',
#    'manufacturing',
#    'life science',
#    'private independent foundations',
#    'coworking space',
#    'wholesaler',
#    'distribution center',
#    'warehouse or wholesale store',
#    'event space',
#    'american restaurant',
#    'chemicals and gasses manufacturer',
#    'manufacturer',
#    'health care',
#    'biotech and pharma',
#    'biological labs',
#    'cafeteria',
#    'building',
#    'buildings',
#    'chemicals-wholesale and manufacturers',
#    'chemicals',
#    'pharmaceutical products',
#    'professional engineers',
#    'biomedical engineers',
#    'business and trade organizations',
#    'pharmaceutical products-wholesale and manufacturers',
#    'charitable organization',
#    'voluntarism and grantmaking foundations: private independent foundations',
#    'philanthropy',
#    'grantmaking foundations',
#    'grantmaking organizations',
#    'charities',
#    'private non-operating foundations',
#    'corporate foundations',
#    'private foundations',
#    'no issues found',
#    'research and development labs',
#    'supermarkets and super stores',
#    'research services',
#    'pharmaceutical products manufacturers',
#    'agricultural consultants',
#    'medical information and research',
#    'fire alarm systems',
#    'security control systems and monitoring',
#    'business coaches and consultants',
#    'wholesale of other household goods',
#    'human health activities',
#    'wholesale of perfume and cosmetics',
#    'wholesale of pharmaceutical goods',
#    'wholesale of watches and jewellery',
#    'wholesale of furniture, carpets and lighting equipment',
#    'wholesale of electrical household appliances',
#    'activities of other membership organizations',
#    'educational, religious, and charitable trusts',
#    'activities of other membership organisations',
#    'research and experimental development on biotechnology',
#    'dental practice activities',
#    'general medical practice activities',
#    'medical and dental practice activities',
#    'specialist medical practice activities',
#    'manufacture of basic pharmaceutical products',
#    'manufacture of pharmaceutical preparations',
#    'construction of buildings',
#    'development of building projects',
#    'construction of residential and non-residential buildings',
#    'biotechnology company',
#    'medical company',
#    'disorders of tissue growth and repair',
#    'neuroscience and infectious disease',
#    'biotechnology research',
#    'metabolism',
#    'ophthalmology',
#    'immunology',
#    'telecommunications'],
#   'tagline': "Genentech, Inc. is an American biotechnology corporation headquartered in South San Francisco, California. It became an independent subsidiary of Roche in 2009. Genentech Research and Early Development operates as an independent center within Roche. Historically, the company is regarded as the world's first biotechnology company.",
#   'is_non_profit': False,
#   'is_public_company': True,
#   'is_dissolved': False,
#   'is_acquired': True,
#   'num_employees': 13539,
#   'year_founded': 1976,
#   'headquarters_country': 'United States of America',
#   'total_funding_amount': None,
#   'total_funding_currency': None,
#   'latest_investment_amount': None,
#   'latest_investment_currency': None,
#   'latest_investment_year': 1976,
#   'latest_investment_series': 'Series Unknown',
#   'investors': ['Kleiner Perkins', 'Mayfield Fund'],
#   'stock_exchange': 'New York Stock Exchange (NYSE)',
#   'stock_symbol': 'DNA',
#   'latest_revenue': 26400000000,
#   'latest_revenue_currency': 'USD',
#   'latest_revenue_year': 2020},
#  '_geoloc': [{'lat': 37.66, 'lon': -122.43}],
#  'original_source_id': 'workday___roche-wd3-rog-a2o-gene___medical-data---analytics-engineer_202510-127004-1',
#  'requisition_id': 'diudfs6trmpabwjn',
#  'collapse_key': '61c65203f4f03bfcd120a413a545c47cfe3226da3f3184eda6d0c398b9516864',
#  'is_expired': False,
#  'objectID': 'workday___roche-wd3-rog-a2o-gene___medical-data---analytics-engineer_202510-127004-1'}

# %%
# next_data_dict['props']['__N_SSG']#.keys()
# next_data_dict['query']['requisitionId']#.keys()
# next_data_dict['props']['pageProps']['validThrough']
# next_data_job = next_data_dict['props']['pageProps']['job']
# next_data_job.keys()
# Out:
# dict_keys(['id', 'board_token', 'source', 'apply_url', 'source_and_board_token', 'job_information', 'v5_processed_job_data', 'v5_processed_company_data', '_geoloc', 'requisition_id', 'collapse_key', 'is_expired', 'objectID'])

# %%
from IPython.display import Markdown
from job_search.dataset import md
_next_data_job_description = next_data_job['job_information']['description']
data_job_description = md(_next_data_job_description, heading_style='ATX')
Markdown(data_job_description)
# Out:
# ## ****About the role****
#
# As an early engineer at Galileo, you will play a foundational role in designing, building, and scaling our products and team. We’re looking for an exceptional Senior Software Engineer, interested in solving complex problems at the intersection of Data and ML and passionate about the opportunities in Observability and Reliability for GenAI.
#
# ## What you'll be doing
#
# * ****Technical Design and Architecture**** - you will champion for the right scalable, reliable architecture and obtain buy-in from all the stakeholders
# * ****Planning and Execution -****  you will work with your team to help plan the roadmap and execute it
# * ****PR and Design Reviews -**** you will uphold the engineering excellence/quality bar by reviewing your peer’s PRs
# * ****Collaboration -**** you will collaborate closely with Product Managers, designers and other TLs to ensure we are building the right strategy and leveraging each other’s work.
# * ****Advance Engineering**** - you will participate in design reviews, on-call and support, participate in and present during Tech Talks and learning sessions & help interview other engineering candidates
#
# ## ****What we're looking for****
#
# * 5+ years of experience building Data or AI/ML products
# * Experience building APIs in Python (FastAPI preferred)
# * Experience building large scale distributed systems and familiarity with
# * + Messaging and Pub-Sub systems such as RabbitMQ/Kafka
#   + Storage/database systems similar to Postgres, MongoDB, Cassandra, S3
#   + OLAP systems such as ClickHouse, Pinot
#   + Orchestration systems such as Celery
# * Experience building test suites using frameworks such as PyTest/PyUnit
# * Experience working effectively during the product development process, working cross-functionally with a product manager, designer, user researcher, and data scientist
# * Excellent communication skills for collaborating with cross-functional partners
# * High productivity and care to help teams collaborate more effectively and efficiently
# * A startup mindset, biasing towards thoughtful action with minimal direction.
#
# ## ****Bonus Points****
#
# * Experience working with Docker and Kubernetes.
# * Experience building applications on at least one of AWS, Google Cloud, or Microsoft Azure.
# * Experience building customer facing products with ML frameworks (like PyTorch, Tensorflow, Keras, etc)
# * Experience building agentic applications (like LLMs, rags, agents, etc.) with common frameworks (like OpenAI, langChain, crewAI, etc.)
#
# ## ****Why Galileo****
#
# * Join a seasoned founding team that has previously led product and engineering teams from 0 to $100M+ in revenue and from 0 to 1B+ users globally
# * We obsess over our team’s culture driven by inclusivity, empathy and curiosity
# * We invest in our team’s development and happiness because our employees are the keys to our success and ensuring happy customers – towards that end, we offer:
# * + 🏥 Medical, Dental and Vision Insurance
#   + 🌴 Unlimited PTO
#   + 👶 Parental Leave (birthing & non-birthing) - 100% pay for 8 weeks
#   + 💰 401(k) Retirement Savings Plan
#   + 📈 Pre-IPO Stock Options
#   + 🚌 Commuter Benefits (pre-tax + company sponsored)
#   + 🧘‍♂️ Mental & Physical Wellness Stipend
#   + 🍱 Catered Meals on in-office days
#   + 🏢 HQ in Burlingame + hub in NYC + hub in Bangalore
#   + 🤝 Build the company alongside the Founders
#
# **\*Benefits/perks may vary by state, country and employment type - please reach out to your recruiter for more information**
#
# **Galileo is an equal opportunity employer supporting workforce diversity. We do not discriminate on the basis of race, religion, color, national origin, gender identity, sexual orientation, age, marital status, protected veteran status, disability status, or any other unlawful factor.**
#
# **Galileo is committed to providing any necessary accommodations for individuals with disabilities within our application and interview process. To request accommodation due to a disability, please inform your recruiter.**
#
# Galileo is committed to fair and equitable compensation practices. The pay range for this role is listed below and represents the expected salary range for non-commissionable roles or on-target earnings for commissionable roles. Actual compensation packages are based on several factors that are unique to each candidate, including but not limited to job-related skills, depth of experience, relevant certifications and training, and specific work location. The total compensation package for this position may also include eligibility for commission, equity, and company sponsored benefits/perks.
#
# * The annual pay range for this role is $180,000 - $225,000 USD.
#
# #LI-JF1

# %%
next_data_job['apply_url']
# Out:
# 'https://ats.rippling.com/galileo/jobs/6fef1da5-107b-44cf-8fb9-d8b52dce5342'

# %%
def disp_job(html_description):
    html_output = ("""
        <style>
        #alex {
            background-color: #eee;
            padding: 2rem;
        }
        </style><div id='alex'>
    """ + html_description + "</div>")
    display(HTML(html_output))

disp_job(next_data_job['job_information']['description'])
# Out:
#         <style>
#         #alex {
#             background-color: #eee;
#             padding: 2rem;
#         }
#         </style><div id='alex'>
#     <meta><h2 style="margin:24px 0px 5px;padding:0px;font-family:"Basel Grotesk",Arial,sans-serif;line-height:1.38;font-weight:600;font-size:15pt;"><b><strong style="color:rgb(32,32,34);white-space:pre-wrap;">About the role</strong></b></h2><p style="font-family:"Basel Grotesk",Arial,sans-serif;font-size:11pt;font-weight:400;margin:0px;line-height:1.38;padding:0px;"><span style="color:rgb(32,32,34);white-space:pre-wrap;">As an early engineer at Galileo, you will play a foundational role in designing, building, and scaling our products and team. We’re looking for an exceptional Senior Software Engineer, interested in solving complex problems at the intersection of Data and ML and passionate about the opportunities in Observability and Reliability for GenAI.</span></p><p style="font-family:"Basel Grotesk",Arial,sans-serif;font-size:11pt;font-weight:400;margin:0px;line-height:1.38;padding:0px;"><br></p><h2 style="margin:24px 0px 5px;padding:0px;font-family:"Basel Grotesk",Arial,sans-serif;line-height:1.38;font-weight:600;font-size:15pt;"><span style="color:rgb(32,32,34);white-space:pre-wrap;">What you'll be doing</span></h2><ul data-pattern="discCircleSquare" data-depth="1" style="font-family:"Basel Grotesk",Arial,sans-serif;font-size:11pt;font-weight:400;margin:16px 0px;line-height:1.38;padding:0px 0px 0px 32px;list-style-type:disc;"><li style="color:rgb(41,42,46);margin:0px;font-size:11pt;line-height:1.38;"><b><strong style="color:rgb(41,42,46);white-space:pre-wrap;">Technical Design and Architecture</strong></b><span style="color:rgb(41,42,46);white-space:pre-wrap;"> - you will champion for the right scalable, reliable architecture and obtain buy-in from all the stakeholders</span></li><li style="margin:0px;font-size:11pt;line-height:1.38;"><b><strong style="color:rgb(41,42,46);white-space:pre-wrap;">Planning and Execution - </strong></b><span style="color:rgb(41,42,46);white-space:pre-wrap;"> you will work with your team to help plan the roadmap and execute it</span></li><li style="margin:0px;font-size:11pt;line-height:1.38;"><b><strong style="color:rgb(41,42,46);white-space:pre-wrap;">PR and Design Reviews - </strong></b><span style="color:rgb(41,42,46);white-space:pre-wrap;">you will uphold the engineering excellence/quality bar by reviewing your peer’s PRs</span></li><li style="margin:0px;font-size:11pt;line-height:1.38;"><b><strong style="color:rgb(41,42,46);white-space:pre-wrap;">Collaboration - </strong></b><span style="color:rgb(41,42,46);white-space:pre-wrap;">you will collaborate closely with Product Managers, designers and other TLs to ensure we are building the right strategy and leveraging each other’s work.</span></li><li style="margin:0px;font-size:11pt;line-height:1.38;"><b><strong style="color:rgb(41,42,46);white-space:pre-wrap;">Advance Engineering</strong></b><span style="color:rgb(41,42,46);white-space:pre-wrap;"> - you will participate in design reviews, on-call and support, participate in and present during Tech Talks and learning sessions & help interview other engineering candidates</span></li></ul><h2 style="margin:24px 0px 5px;padding:0px;font-family:"Basel Grotesk",Arial,sans-serif;line-height:1.38;font-weight:600;font-size:15pt;"><b><strong style="color:rgb(32,32,34);white-space:pre-wrap;">What we're looking for</strong></b></h2><ul data-pattern="discCircleSquare" data-depth="1" style="font-family:"Basel Grotesk",Arial,sans-serif;font-size:11pt;font-weight:400;margin:16px 0px;line-height:1.38;padding:0px 0px 0px 32px;list-style-type:disc;"><li style="color:rgb(32,32,34);margin:0px;font-size:11pt;line-height:1.38;"><span style="color:rgb(32,32,34);white-space:pre-wrap;">5+ years of experience building Data or AI/ML products</span></li><li style="margin:0px;font-size:11pt;line-height:1.38;"><span style="color:rgb(32,32,34);white-space:pre-wrap;">Experience building APIs in Python (FastAPI preferred)</span></li><li style="margin:0px;font-size:11pt;line-height:1.38;"><span style="color:rgb(32,32,34);whi ...

# %%
from IPython.display import HTML
# HTML(next_data_job['job_information']['description'])
# next_data_job['v5_processed_job_data']#['requirements_summary']
# next_data_job['v5_processed_job_data']#['company_activities_synonyms']
# next_data_job['v5_processed_job_data']#['company_name']
# next_data_job['v5_processed_job_data']#['estimated_publish_date']
# next_data_job['v5_processed_job_data']#['position_employer_type']
# next_data_job['v5_processed_job_data']#['company_tagline']
# next_data_job['v5_processed_job_data']#['company_activities']
# next_data_job['v5_processed_job_data']#['company_sector_and_industry']
# next_data_job['v5_processed_job_data']#['technical_tools']
# next_data_job['v5_processed_job_data']#['requirements_summary']

# %%
# P_url
com.viewjob('zsugiy65ldqr3xnv')
# Out:
# 'https://hiring.cafe/viewjob/zsugiy65ldqr3xnv'

# %%
# <script src="https://cdn.jsdelivr.net/npm/@tailwindcss/browser@4"></script>
